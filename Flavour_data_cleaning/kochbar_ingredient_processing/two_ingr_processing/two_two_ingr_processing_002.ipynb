# %%
import pandas as pd
import numpy as np
import os
import re
import string

# %%
two_ingr_df=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_ingr_df_003.csv',index_col=0)
two_ingr_df.shape
# Out:
# (3512, 2)

# %%
two_ingrs=list(set(two_ingr_df['parse_ingr'].values.tolist()))
len(two_ingrs)
# Out:
# 3358

# %%
two_ingrs.sort()
two_ingrs
# Out:
# ['aal geräuchert',
#  'ace saft',
#  'aceto balsamico',
#  'aceto bianco',
#  'agar agar',
#  'ahornsirup',
#  'ajowan königskümmelsaat',
#  'ajvar paprikapaste',
#  'ajvar scharf',
#  'ajwar scharf',
#  'akazien honig',
#  'alhokolfreien sirup',
#  'all arabbiatasauce',
#  'allgäuer käse',
#  'alpro soja',
#  'alse semmelmehl',
#  'altbayerischer leberkäse',
#  'amarena kirschlikör',
#  'amarettini mandelkekse',
#  'amaretto likör',
#  'amaretto mandellikör',
#  'amaretto sirup',
#  'amarulalikör afrikanischerwaldfruchtlikör',
#  'american bacon',
#  'amerikan sendwichvolkorn',
#  'amerikan toast',
#  'ammonium hirschhornsalz',
#  'ampulle zitronenaroma',
#  'ancho chili',
#  'anderebrühwürste zbbratwürste',
#  'angel dor',
#  'anis gewürz',
#  'apfel essig',
#  'apfel etw',
#  'apfel fruchtsaft',
#  'apfel gala',
#  'apfel kanzi',
#  'apfel rot',
#  'apfelessig rapsöl',
#  'apfelkuchen gewürz',
#  'apfelmus glas',
#  'apfelschorle',
#  'apollinaris mint',
#  'appenzeller_cheese',
# ...

# %%
ingr_list=[]
for index,row in two_ingr_df.iterrows():
    if re.search(r'^t',row.parse_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['tabasco grün',
#  'taco chips',
#  'taco gewuerz',
#  'taco mais',
#  'tacochips chili',
#  'tafelmeerrettich demgläschen',
#  'tagliolini nerokühlregal',
#  'tai curry',
#  'taleggio käse',
#  'tandori paste',
#  'tandorri pulver',
#  'tasmanischer bergpfeffer',
#  'tasmanisches pfefferöl',
#  'tasty mix',
#  'tellicherry pfeffer',
#  'tempobohnen weiss',
#  'teriyaki sauce',
#  'teriyakisauce zufügen',
#  'texicana salsa',
#  'thai chili',
#  'thai curry',
#  'thai currypulver',
#  'thai redcurrypulver',
#  'thai whiskey',
#  'thaichili pulver',
#  'thaichilisosse sweet',
#  'thaicurry rot',
#  'thaicurrypulver rot',
#  'thaiknoblauch dembastkörbchen',
#  'thailändische chilisosse',
#  'thailändische chilisosseextrascharf',
#  'thommy joghurtcreme',
#  'thymian gewürz',
#  'thymianlavendel öl',
#  'tiko erbsen',
#  'toast käse',
#  'toast vollkorn',
#  'tofu fest',
#  'tofu seiden',
#  'tofugewürz demreformhaus',
#  'tomate passiert',
#  'tomate rot',
#  'tomaten',
# ...

# %%
change_dict={'rübe gelb':'carrot','senfkörner':'mustard_seed','staudensellerie':'celery','süsskartoffeln':'sweet_potato',
'ricotta':'ricotta_cheese','rohzucker':'sugar','rosenkohl':'brussels_sprout','rucola fix':'arugula','rucola salat':'arugula',
'paprika grün':'bell_pepper','paprika orange':'bell_pepper','pute knochen':'turkey','rauke rucola':'arugula',
'paprica rot':'bell_pepper','paprika bunt':'bell_pepper','paprika gelb':'bell_pepper','paprika gruen':'bell_pepper',
'marmelase apfelsine':'apple_jam','meeresfrüchte':'fruit','mehlschwitze':'roux','mungbohnen':'mung bean','nierchen':'Nierchen',
'marmelade apfelsine':'apple_jam','marmelade birnenschmaus':'pear_jam','marmelade erdbeer':'strawberry_jam',
'lollo rosso':'lettuce','maasdamer grosslochkäse':'maasdam_cheese','maasdamer käse':'maasdam_cheese',
'käse gauda':'gouda_cheese','limette fruchtsaft':'lime_juice','lollo bianco':'lettuce','lollo blanco':'lettuce',
'johannisbeer gelee':'currant_jelly','klossteig':'Klossteig','kräuter derprovance':'Herbes_de_Provence',
'hähnchenkeulen':'chicken','hähnchenschenke':'chicken','hähnchenteile':'chicken','hühnerbrüstchen':'chicken',
'grapefruit fruchtsaft':'grapefruit_juice','grelatine':'gelatin','kardamomkapsel':'cardamomum',
'hähnchenbrüste':'chicken','hähnchenbrust':'chicken','hähnchenfilets':'chicken',
'gewürzgurke':'gherkin','gewürzsäckchen':'bay,clove,thyme,parsley,fennel','granny smith':'apple','grano padamo':'grano_padano-cheese',
'gaudakäse':'gouda_cheese','gebratener schw':'roasted_pork','gelantine':'gelatin','perlgraupen':'pearl_barley',
'frischpute':'turkey','frankfurter':'sausage','garnelen':'shrimp','gauda käse':'gouda_cheese',
'essiggurken':'gherkin','maisstärke':'corn_starch','fetakäse':'feta_cheese','feta käse':'feta_cheese',
'erdbeere joghurt':'strawberry_yoghurt','erdbeerjoghurt':'strawberry_yoghurt','erbeersaft':'strawberry_juice',
'eierschwämmchen pfifferlinge':'cantharellus','eierspätzle':'Eierspätzle','emmenthaler käse':'emmentaler_cheese',
'edelsüssen paprika':'paprika_powder','edelsüsser paprika':'paprika_powder','eierschwammerl pfifferlinge':'cantharellus',
'dinkelvollkorn mehl':'wheat','dinkelvollkornmehl':'wheat','rotbarsch':'rose_fish','edelsüss paprika':'paprika_powder',
'cornichon':'gherkin','currypulver':'curry_powder','currysosse':'curry_sauce','demi glacepulver':'demi glace',
'chillisauce':'chili_sauce','chillisosse':'chili_sauce','ciabatta':'ciabatta','clementine fruchtsaft':'clementine_juice',
'champigmons':'mushroom','champignons':'mushroom','chilisosse':'chili_sauce','chilisauce':'chili_sauce',
'brie camembert':'camembert_cheese','broccoli röschen':'broccoli','broccoli gratin':'broccoli','brokkoli röschen':'broccoli',
'bauernspeck':'bacon','beerenm ischung':'berry','beerenmix':'berry','blutwurst':'blood_sausage','blue castello':'castello_cheese',
'bauchfleisch geräuchert':'smoked_pork_belly','bauchspeck geräuchert':'smoked_pork_belly',
'ajowan':'ajwain','ajvar':'ajvar','ajwar':'ajvar','arabbiatasauce':'arrabbiata_sauce','allgäuer käse':'cheese',
'alpro soja':'soy_drink','semmelmehl':'bread_crumbs','leberkäse':'Leberkäse','amaretto':'amaretto',
'amarulalikör':'amarula','ammonium hirschhornsalz':'salt','ancho chili':'poblano_chili','apfel essig':'apple_cider',
'apfel fruchtsaft':'apple_juice','apfel gala':'apple','apfel kanzi':'apple','apfel kanzi':'apple',
'marillenmarmelade':'apricot_jam','aprikosen marillengetrocknet':'apricot',
'marillenmarmelade':'apricot_jam','marmelade marille':'apricot_jam','aprikosenkonfitüre':'apricot_jam',
'arabiata sauce':'arrabbiata_sauce','kreuzkümmel':'cumin','ayvar':'ajvar'}

# %%
change_list=list(change_dict.keys())

# %%
change_list
# Out:
# ['rübe gelb',
#  'senfkörner',
#  'staudensellerie',
#  'süsskartoffeln',
#  'ricotta',
#  'rohzucker',
#  'rosenkohl',
#  'rucola fix',
#  'rucola salat',
#  'paprika grün',
#  'paprika orange',
#  'pute knochen',
#  'rauke rucola',
#  'paprica rot',
#  'paprika bunt',
#  'paprika gelb',
#  'paprika gruen',
#  'marmelase apfelsine',
#  'meeresfrüchte',
#  'mehlschwitze',
#  'mungbohnen',
#  'nierchen',
#  'marmelade apfelsine',
#  'marmelade birnenschmaus',
#  'marmelade erdbeer',
#  'lollo rosso',
#  'maasdamer grosslochkäse',
#  'maasdamer käse',
#  'käse gauda',
#  'limette fruchtsaft',
#  'lollo bianco',
#  'lollo blanco',
#  'johannisbeer gelee',
#  'klossteig',
#  'kräuter derprovance',
#  'hähnchenkeulen',
#  'hähnchenschenke',
#  'hähnchenteile',
#  'hühnerbrüstchen',
#  'grapefruit fruchtsaft',
#  'grelatine',
#  'kardamomkapsel',
#  'hähnchenbrüste',
#  'hähnchenbrust',
#  'hähnchenfilets',
#  'gewürzgurke',
#  'gewürzsäckchen',
#  'granny smith',
#  'grano padamo',
# ...

# %%
ingr_list=[]
for ingr in change_list:
    for index,row in two_ingr_df.iterrows():
        if re.search(ingr,row.parse_ingr)!=None:
            ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ajowan königskümmelsaat',
#  'ajvar paprikapaste',
#  'ajvar scharf',
#  'ajwar scharf',
#  'all arabbiatasauce',
#  'allgäuer käse',
#  'alpro soja',
#  'alse semmelmehl',
#  'altbayerischer leberkäse',
#  'amaretto likör',
#  'amaretto mandellikör',
#  'amaretto sirup',
#  'amarulalikör afrikanischerwaldfruchtlikör',
#  'ammonium hirschhornsalz',
#  'ancho chili',
#  'apfel essig',
#  'apfel fruchtsaft',
#  'apfel gala',
#  'apfel kanzi',
#  'aprikose konfitüre',
#  'aprikosen konfitüre',
#  'aprikosen marillenmarmelade',
#  'aprikosenkonfitüre passiert',
#  'arabiata sauce',
#  'asiatische chilisosse',
#  'auch kreuzkümmel',
#  'ayvar scharf',
#  'bauchfleisch geräuchert',
#  'bauchspeck geräuchert',
#  'bauernspeck',
#  'beerenm ischung',
#  'beerenmix rot',
#  'beerenmix smoothie',
#  'belgische meeresfrüchte',
#  'blue castello',
#  'blutwurst konserve',
#  'blutwurst speckwurst',
#  'bratfeste blutwurstflönz',
#  'braune senfkörner',
#  'brie camembert',
# ...

# %%
def replace_ingr(k,v,ingredient):
    if re.findall(k,ingredient):
        return v
    else:
        return ingredient

# %%
for k,v in change_dict.items():
    two_ingr_df['parse_ingr']=two_ingr_df['parse_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
keep_list=list(change_dict.values())

# %%
two_ingr_keep_004=two_ingr_df[two_ingr_df['parse_ingr'].isin(keep_list)]
two_ingr_keep_004.shape
# Out:
# (260, 2)

# %%
two_ingr_keep_004
# Out:
#                    ingredient_name    parse_ingr
# 12    eierschwämmchen pfifferlinge  cantharellus
# 15                currypulver grün  curry_powder
# 24        thailändische chilisosse   chili_sauce
# 44                  amaretto likör      amaretto
# 62            thaichilisosse sweet   chili_sauce
# ...                            ...           ...
# 3448             champignons weiss      mushroom
# 3457           thai redcurrypulver  curry_powder
# 3483               rohzucker braun         sugar
# 3488                  paprika grün   bell_pepper
# 3508                 gelantine rot       gelatin
#
# [260 rows x 2 columns]

# %%
two_ingr_keep_004.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_done_004.csv')

# %%
two_ingr_keep_004=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_done_004.csv',index_col=0)
two_ingr_keep_004.shape

# %%
two_ingr_df=two_ingr_df[~two_ingr_df['parse_ingr'].isin(keep_list)]
two_ingr_df.shape

# %%
two_ingr_df.reset_index(drop=True,inplace=True)

# %%
whole_delete=['angel dor','etw','glas','ew','je','dr oetkerbackspeisefarben','essbares foto','fleckerln inösterreich',
'freinach schnauze','küchenmaschine mitknethaken','msmpulver fellpflege']

# %%
two_ingr_df=two_ingr_df[~two_ingr_df['parse_ingr'].isin(whole_delete)]
two_ingr_df.reset_index(drop=True,inplace=True)
two_ingr_df.shape
# Out:
# (3245, 2)

# %%
delete_words=['raffiniert','rosa','fassungsvolumen','spritzer','zufügen','geteilt',
'mittelgr','mittelreife','mspgemahlene','n','geschältentsteint','neue','notfalls','demasienladen',
'gräucherter','halbgeschlagene','himalaya','hickory','körnigen','körniger','körniges','mittelgroosse',
'feriebene','selbstgekocht','fluessig','gegartfertigprodukt','französische','füllung','gibtsbei','grobgemehlenen',
'alhokolfreien','akazien','american','amerikan','marille','marillen','augeblasene','babybel','bautzener',
'bautzner','blühender','caotina','ausmilch','cremige','cremigen','cremiger','crushed','doppelrahm','vonphiladelphia',
'dr oetker','droetker','durchter','düsseldorfer','ohnemarmelade','eigenemischung','einweichwasser',
'eltrockene','englischen','englischer','englisches','eigenemanbau','essbare','demdelikatessenladen']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr_df['parse_ingr']=two_ingr_df['parse_ingr'].apply(lambda x:del_words(x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delete_parts=['doppelrahm','´nach bedarf','spritzer']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr_df['parse_ingr']=two_ingr_df['parse_ingr'].apply(lambda x:del_part(part,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
two_ingr_df
# Out:
#               ingredient_name               parse_ingr
# 0               pommes frites            pommes frites
# 1          walnuss panzerotti       walnuss panzerotti
# 2       granatapfel balsamico    granatapfel balsamico
# 3        schwlende geräuchert     schwlende geräuchert
# 4          pökelwaren eisbein       pökelwaren eisbein
# ...                       ...                      ...
# 3240      paprika rotgelbgrün      paprika rotgelbgrün
# 3241  brunch paprikapepperoni  brunch paprikapepperoni
# 3242    asiatisches wokgewürz    asiatisches wokgewürz
# 3243           kle vomschwein           kle vomschwein
# 3244           kalb schnitzel           kalb schnitzel
#
# [3245 rows x 2 columns]

# %%
# translation

# %%
# %env GOOGLE_APPLICATION_CREDENTIALS =/home/IW_student/work/Ingredeints-translation-1d0aa41c5717.json
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/home/IW_student/work/Ingredeints-translation-1d0aa41c5717.json

# %%
from google.cloud import translate_v2 as translate
translate_client = translate.Client() # add environment varibale

# %%
def translation(ingredient):
    results=translate_client.translate(ingredient,target_language='en')
    return results['translatedText']

# %%
two_ingr_df['en_ingr']=two_ingr_df['parse_ingr'].apply(lambda x:translation(x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# two_ingr_df_004 + en_ingr
two_ingr_df.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_001.csv')

# %%
two_ingr_df=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_001.csv',index_col=0)
two_ingr_df.dropna(inplace=True)
two_ingr_df.reset_index(drop=True,inplace=True)
two_ingr_df.shape
# Out:
# (3244, 3)

# %%
two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].str.lower()

# %%
two_ingrs=list(set(two_ingr_df['en_ingr'].values.tolist()))
len(two_ingrs)
# Out:
# 2846

# %%
two_ingrs.sort()
two_ingrs
# Out:
# ['',
#  '&quot;white chocolate',
#  'a spice similar to a cumin',
#  'ace saft',
#  'acid lemon',
#  'add in shots',
#  'air ham',
#  'alarrabiata spice preparation',
#  'almond butter white',
#  'almond flavored cooking pudding powder',
#  'almond sweet',
#  'almonds',
#  'amarena cherry liqueur',
#  'amarettini mandelkekse',
#  'ampoule lemon flavor',
#  'anis',
#  'anise spice',
#  'any bread',
#  'apfelschorle',
#  'apollinaris new',
#  'appenzeller_cheese',
#  'apple',
#  'apple cider vinegar canola oil',
#  'apple pie spice',
#  'apple red',
#  'apple sauce glass',
#  'apple sth',
#  'apples cleaned',
#  'apples coxorange',
#  'apples crumbly',
#  'apples green',
#  'apples red',
#  'apples rubinette',
#  'apples sweet',
#  'apricot',
#  'apricot jam',
#  'apricots',
#  'apricots ew',
#  'arabic bread',
#  'arabic spice',
#  'arabic spice mix',
#  'aranca apricot and passion fruit cream dish',
#  'arancacreme lemon',
#  'aroma buttervanille',
#  'aromatic oil rose oil',
# ...

# %%
# extract cheese data

# %%
cheese_list=[]
for index,row in two_ingr_df.iterrows():
    if re.search('_cheese',row.parse_ingr)!=None:
        cheese_list.append(row.parse_ingr)
cheese_list=list(set(cheese_list))

# %%
cheese_list
# Out:
# ['blue_cheese',
#  'gorgonzola_cheese',
#  'appenzeller_cheese',
#  'gruyere_cheese',
#  'cheddar_cheese',
#  'raclette_cheese',
#  'parmesan_cheese',
#  'greyerzer_cheese',
#  'mozzarella_cheese',
#  'limburge_cheese']

# %%
cheese_data=two_ingr_df[two_ingr_df['parse_ingr'].isin(cheese_list)]
cheese_data.shape
# Out:
# (20, 3)

# %%
cheese_data
# Out:
#                    ingredient_name          parse_ingr             en_ingr
# 81                appenzeller käse  appenzeller_cheese  appenzeller_cheese
# 168            cheddar schmelzkäse      cheddar_cheese      cheddar_cheese
# 301            cremiger gorgonzola   gorgonzola_cheese   gorgonzola_cheese
# 390           bergkäse appenzeller  appenzeller_cheese  appenzeller_cheese
# 398     blauschimmelkäse cambozola         blue_cheese         blue_cheese
# 512          gorgonzola mascarpone   gorgonzola_cheese   gorgonzola_cheese
# 518                 greyerzer käse    greyerzer_cheese    greyerzer_cheese
# 935          reggiano parmesankäse     parmesan_cheese     parmesan_cheese
# 944               mozzarella kugel   mozzarella_cheese   mozzarella_cheese
# 1147    kräftigen blauschimmelkäse         blue_cheese         blue_cheese
# 1663  crème aubleublauschimmelkäse         blue_cheese         blue_cheese
# ...

# %%
two_ingr_keep_004=pd.concat([two_ingr_keep_004,cheese_data],axis=0,ignore_index=True)
two_ingr_keep_004.shape
# Out:
# (300, 3)

# %%
two_ingr_df=two_ingr_df[~two_ingr_df['parse_ingr'].isin(cheese_list)]
two_ingr_df.reset_index(drop=True,inplace=True)
two_ingr_df.shape
# Out:
# (3224, 3)

# %%
two_ingrs=list(set(two_ingr_df['en_ingr'].values.tolist()))
len(two_ingrs)
# Out:
# 2836

# %%
two_ingrs.sort()
two_ingrs
# Out:
# ['&quot;white chocolate',
#  'a spice similar to a cumin',
#  'ace saft',
#  'acid lemon',
#  'add in shots',
#  'air ham',
#  'alarrabiata spice preparation',
#  'almond butter white',
#  'almond flavored cooking pudding powder',
#  'almond sweet',
#  'almonds',
#  'amarena cherry liqueur',
#  'amarettini mandelkekse',
#  'ampoule lemon flavor',
#  'anis',
#  'anise spice',
#  'any bread',
#  'apfelschorle',
#  'apollinaris new',
#  'apple',
#  'apple cider vinegar canola oil',
#  'apple pie spice',
#  'apple red',
#  'apple sauce glass',
#  'apple sth',
#  'apples cleaned',
#  'apples coxorange',
#  'apples crumbly',
#  'apples green',
#  'apples red',
#  'apples rubinette',
#  'apples sweet',
#  'apricot',
#  'apricot jam',
#  'apricots',
#  'apricots ew',
#  'arabic bread',
#  'arabic spice',
#  'arabic spice mix',
#  'aranca apricot and passion fruit cream dish',
#  'arancacreme lemon',
#  'aroma buttervanille',
#  'aromatic oil rose oil',
#  'arrabiata spice mix',
# ...

# %%
ingr_list=[]
for index,row in two_ingr_df.iterrows():
    if re.search(r'^z',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['zartbitterschokolade mitchili',
#  'zbparadies vanilla cream',
#  'zbwiener griessler',
#  'zebröselte biskuits',
#  'zuckermelone charentais']

# %%
two_ingr_df[two_ingr_df['en_ingr']=='zuckermelone charentais']
# Out:
#               ingredient_name               parse_ingr  \
# 1012  zuckermelone charentais  zuckermelone charentais
#
#                       en_ingr
# 1012  zuckermelone charentais

# %%
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='bel paese']='bel_paese_cheese'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='blanc battu']='blanc_battu'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='belper']='belper_cheese'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='krokant']='krokant'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='olio diavolo']='olio_diavolo'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='holländische sosse']='holländische_sauce'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='brausepulver grün']='sherbet'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='brausepulver gelb']='sherbet'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='espresso']='espresso'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='kaki']='persimmon'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='flugente barbarie']='duck'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='brot röstbrot']='bread'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='wssig rot']='vinegar'
two_ingr_df['en_ingr'][two_ingr_df['parse_ingr']=='vin santo']='vin santo'

# %%
whole_delete=['scattered decor hearts','stick sponge','water cup','white sugar color','white sugar script','white sugar pearls',
'add in shots','cake decor flowers','cut yellow ones','cutter knife or kitchen knife','from the','german quality',
'let it cool down again','link in preparation step','outer removed','outer removed','passed to jam',
'per mushroom','powerful aromatic note','praline capsules made of aluminum','red food color','red ribbons']

# %%
two_ingr_df=two_ingr_df[~two_ingr_df['en_ingr'].isin(whole_delete)]
two_ingr_df.dropna(inplace=True)
two_ingr_df.reset_index(drop=True,inplace=True)
two_ingr_df.shape
# Out:
# (3204, 3)

# %%
delete_words=['lengthways','derober','walnut-sized','was','wela','melted','selection',
'scalped','skinned','self-raising','serve','wedges','i','toasted','unload','scratched','pck','requirement',
'any','ampoule','glass','cleaned','crumbly','ew','streaked','barbaric','barilla','mince','minced','preparation',
'debarked','crushed','blanched','brewed','brew','brez´n','candied','canned','coarse','coarse-grained',
'colorful','consistency','cooled','touched','cow&#39;s','crumbled','crumbly','culinary','curd','dried',
'e.g.','etras','exquisa','fat','soft','finesse','flat-leaf','forest','formerly','freshly','cleaned',
'ground','garden','generously','generous','size','german','get','giant','prepared','granulated','grated','gratin',
'imperial','it','körner','know','kandiert','lamb&#39;s','branches','leaf','liquid','unprepared','hardened',
'self-collected','medium','quality','more','nerokühlregal','melt','odorless','older','old','g','long',
'preferably','processed ','spreadable','pulled','strips','yellow-green','red-skinned','ring','roasted']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].apply(lambda x:del_words(x))

# %%
delete_parts=['finely diced','wings of the','with a little',
'side dish','similar to','stock of','tube of','twig of','types of','or white wine','whey of','semi-dry broth',
'a spice similar to a','ball of','balls of','of the leg','on both sides','für muffinblech','according to instructions',
'if necessary','crust of','in the cucumber jar','mini version','in own garden','dr oetker','bottom farming',
'foot of','fresh and smooth','glass of','from the butcher','i put','instead of','it is','it&#39;s a',
'kölln&#39;s','cut up','extra hot','for puree','delicate as flowers','for frying','of happy','optionally frozen',
'from oetker','for decoration','stalks','commercially available','quarter-fat level','three-quarter fat level',
'red and white','raw material','ready to pan','shot glass of','shot glass','shot glasses of']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].apply(lambda x:del_part(part,x))

# %%
two_ingr_df.dropna(inplace=True)
two_ingr_df=two_ingr_df[two_ingr_df['en_ingr']!='']
two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].str.strip()
two_ingr_df.reset_index(drop=True,inplace=True)
two_ingr_df.shape
# Out:
# (3198, 3)

# %%
two_ingrs=list(set(two_ingr_df['en_ingr'].values.tolist()))
len(two_ingrs)
# Out:
# 2672

# %%
# replace now
# roasted_beef, roasted_meat, roasted_turkey, roasted_lamb, roasted_pork, roasted_chicken,
# smoked_sausage,smoked_summer_sausage,smoked_pork,uncured_smoked_pork,smoked_pork_belly,
# fried_chicken,fried_pork,fried_beef,fried_cured_pork,
# grilled_beef,grilled_pork,
# boiled_chicken,uncured_boiled_pork,boiled_meat,boiled_beef,boiled_pork,
# cured_ham,cured_pork,
# baked_potato

# %%
ingr_list=[]
for index,row in two_ingr_df.iterrows():
    if re.search(r'^b',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['bacardi razz',
#  'bacardi rum',
#  'bacchus frankenwein',
#  'bacon',
#  'baharat',
#  'baileys whiskeysahnelikör',
#  'baked ham',
#  'baking oil lemon',
#  'baking powder backin',
#  'balance',
#  'balisto wild berry yogurt',
#  'balsamic',
#  'balsamic balm dark',
#  'balsamic cream white',
#  'balsamic dark',
#  'balsamic light',
#  'balsamic red',
#  'balsamic spray',
#  'balsamic vinegar',
#  'balsamic vinegar atomizer',
#  'balsamic vinegar dark',
#  'balsamic vinegar red',
#  'balsamic vinegar with fig juice',
#  'balsamic white',
#  'balsamic_vinegar',
#  'balsamicoessig hell',
#  'balsamicoessig orange',
#  'balsamicoessig white',
#  'balsamicoglaze white',
#  'bamberger croissant',
#  'bamboo shoots',
#  'banana',
#  'banana_juice',
#  'bananas',
#  'barbecue marinade',
#  'barbeque spice',
#  'barley barley',
#  'barolo red wine',
#  'basil pesto',
#  'basil red',
#  'basil spice',
#  'basil,thyme,lemon',
#  'basilikumzweige tai',
#  'bay',
#  'bay spice',
# ...

# %%
two_ingr_df[two_ingr_df['en_ingr']=='buttervanille baking soda']
# Out:
#               ingredient_name               parse_ingr  \
# 1235  backaroma buttervanille  backaroma buttervanille
#
#                         en_ingr
# 1235  buttervanille baking soda

# %%
whole_change_dict={'buttermilk with fruit':'fruit_buttermilk','buttervanille backaroma':'buttervanille aroma','buttervanille baking soda':'buttervanille aroma',
'bresaola luftsrindfleisch':'beef','buttered ribbon noodles':'pasta','buttermilk strawberry':'strawberry_buttermilk',
'braunschweiger mettwurst':'sausage','bread baking mix farmer&#39;s bread':'bread',
'bouquet of herbs':'bouquet garni','bouquet of herbs, laurel':'bouquet garni,bay','box of cress':'watercress',
'bluccolikochwasser':'broccoli','bolognese fix':'bolognese sauce','bones of the hind leg':'pork',
'black loin with rib bones':'beef','black winemaker&#39;s cheese':'cheese','blockschokolade weiss':'chocolate',
'bissien knobi':'garlic','bitter almond baking oil':'bitter_almond_oil','bittermandelaroma':'almond_aroma',
'biskin special':'Biskin spezial','biskin öl':'oil','biskottenbrösel biscuits':'biscuit','bisque light':'biscuit',
'beverages containing wine':'wine','bharat spice':'baharat','big toast':'bread','biscuitskapseln petitfour':'biscuit',
'beef lamb':'beef,lamb','bernaise sauce':'Bernaise_sauce','berries blueberries':'blueberry',
'beef braised':'boiled_beef','beef brisket bones sawn':'beef','beef calf':'beef','beef goulash':'beef',
'bavaria blu':'cheese','bean potato vegetables rest':'bean,potato','bärlauchnudeln bandnudeln':'Bärlauchnudeln',
'basil thyme lemon thyme':'basil,thyme,lemon','basket schwhähnchenschnitzel':'pork','baumtomaten tamarillos':'tomato',
'banana fruit nectar':'banana_juice','bananas shallots':'onion','bananhas haribo':'gummi',
'balsamiko essig':'balsamic_vinegar','bambussprossen':'bamboo shoots','bambussprossen':'bamboo shoots',
'balsamic orange':'orange_balsamic_vinegar','balsamic orange vinegar':'orange_balsamic_vinegar',
'balsamic essig':'balsamic_vinegar','balsamic figs':'fig_balsamic_vinegar','balsamic honey':'balsamic_vinegar',
'baking flour':'wheat','balkan cheese':'feta_cheese','balsamessig mango':'mango_balsamic_vinegar',
'badisches landbrot':'bread','baked apple chili jelly':'apple_jelly','baking mix multigrain bread':'bread',
'backaroma orange':'orange_aroma','backaroma rum':'rum_aroma','bacon white':'bacon','bacon bacon':'bacon',
'almond butter white':'almond butter','almond flavored cooking pudding powder':'almond_pudding',
'almond sweet':'almond','anise spice':'anis','apple cider vinegar canola oil':'apple_cider,canola_oil',
'aranca apricot and passion fruit cream dish':'Aranca_Aprikose_Maracuja',
'arancacreme lemon':'Aranca_creme_lemon','aroma buttervanille':'vanilla_aroma','aromaöl rosenöl':'oil',
'asia vegetables':'vegetable','asian ribbon noodles':'asian_noodle','asia noodles':'asian_noodle',
'asia sosse':'asian_sauce','asian egg noodles':'asian_noodle','asian sauce sweet and sour':'asian_sauce',
'asian wheat noodles':'asian_noodle','asiasauce süsssauer':'asian_sauce','asiasosse süsssauer':'asian_sauce',
'ausbiskuitmasse biscuits':'biscuit','azora orangengebäck':'cookies'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
contain_change_dict={'boquet garni':'boquet garni','fish fingers':'fish finger',
'biskuittortenboden':'biscuit base','herring':'herring','chilli oil':'chili_oil',
'belly bacon':'smoked_pork_belly','biscuit base':'biscuit base','biscuit floors':'biscuit base',
'beef breast':'beef','beef broth':'beef_broth','beef soup':'beef_broth','beef steak':'beef',
'balsamic vinegar':'balsamic_vinegar','balsamicoessig':'balsamic_vinegar','basilikumzweige':'basil'}

# %%
def replace_contain_ingr(k,v,ingredient):
    if re.findall(k,ingredient):
        return v
    else:
        return ingredient

# %%
for k,v in contain_change_dict.items():
    two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].apply(lambda x:replace_contain_ingr(k,v,x))

# %%
two_ingr_df=two_ingr_df[two_ingr_df['en_ingr']!='bottle dusters flaschenboviste']

# %%
delete_wrods=['mix','wok','air','frankenwein','backin','bamberger','obuschbohnen','hip','leg','slice','shoulder','ok','roulades',
'ausbiskuitmasse','unusual','black-green','boiling','vegetarian','branded','braised','broken','brown','kefir']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].apply(lambda x:del_words(x))

# %%
for index,row in two_ingr_df.iterrows():
    if re.search(r'sweet$',row.en_ingr)!=None:
        #print(row.en_ingr)
        two_ingr_df.loc[index,'en_ingr']=re.sub('sweet','',row.en_ingr)

# %%
delete_parts=['a spice','kernels brown','fillet from','mix with sourdough']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].apply(lambda x:del_part(part,x))

# %%
two_ingr_df.dropna(inplace=True)
two_ingr_df=two_ingr_df[two_ingr_df['en_ingr']!='']
two_ingr_df['en_ingr']=two_ingr_df['en_ingr'].str.strip()

# %%
two_ingr_df.reset_index(drop=True,inplace=True)

# %%
two_ingr_df=two_ingr_df[['ingredient_name','parse_ingr','en_ingr']]

# %%
two_ingr_df
# Out:
#               ingredient_name               parse_ingr  \
# 0               pommes frites            pommes frites
# 1          walnuss panzerotti       walnuss panzerotti
# 2       granatapfel balsamico    granatapfel balsamico
# 3        schwlende geräuchert     schwlende geräuchert
# 4          pökelwaren eisbein       pökelwaren eisbein
# ...                       ...                      ...
# 3192      paprika rotgelbgrün      paprika rotgelbgrün
# 3193  brunch paprikapepperoni  brunch paprikapepperoni
# 3194    asiatisches wokgewürz    asiatisches wokgewürz
# 3195           kle vomschwein           kle vomschwein
# 3196           kalb schnitzel           kalb schnitzel
#
#                        en_ingr
# 0                 french fries
# 1            walnut panzerotti
# 2         pomegranate balsamic
# 3            smoldering smoked
# 4           cured pork knuckle
# ...                        ...
# 3192  red-yellow-green paprika
# 3193  brunch paprika pepperoni
# ...

# %%
two_ingrs=list(set(two_ingr_df['en_ingr'].values.tolist()))
len(two_ingrs)
# Out:
# 2597

# %%
# two_ingr_df.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_002.csv')
