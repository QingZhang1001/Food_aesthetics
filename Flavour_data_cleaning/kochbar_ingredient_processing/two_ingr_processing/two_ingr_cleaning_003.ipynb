# %%
import pandas as pd
import numpy as np
import os
import re
import string

# %%
two_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_ingr_002.csv',index_col=0)
two_ingr.shape
# Out:
# (61710, 4)

# %%
two_ingr.dropna(inplace=True)
two_ingr=two_ingr[two_ingr['ingredient_name']!='']
two_ingr['ingredient_name']=two_ingr['ingredient_name'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)
two_ingr.shape
# Out:
# (61683, 4)

# %%
two_ingr
# Out:
#        recipe_id                                        recipe_href  \
# 0          15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 1          15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 2          15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 3          15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 4          25386                 /rezept/423974/I-Zwiebelsauce.html
# ...          ...                                                ...
# 61678      40552         /rezept/281466/Bueffett-Schinkentorte.html
# 61679      40552         /rezept/281466/Bueffett-Schinkentorte.html
# 61680      40552         /rezept/281466/Bueffett-Schinkentorte.html
# 61681      40552         /rezept/281466/Bueffett-Schinkentorte.html
# 61682      47140                  /rezept/391537/Sauerrahm-Dip.html
#
#                                 name                ingredient_name
# 0                     butter flüssig                         butter
# ...

# %%
# delete punctuation

# %%
puncs=string.punctuation

# %%
def del_punc(part,ingredient):
    no_punc=ingredient.replace(part,'')
    return no_punc

# %%
for punc in puncs:
    two_ingr['ingredient_name']=two_ingr['ingredient_name'].apply(lambda x:del_punc(punc,x))

# %%
whole_delete=['-fertigprodukt','-lauwarm','-tk-ware','-zusammen','/zartweizen','1/2b','1-getrockneter','1rot','1tl','28er grösse',
'alles jeweils']

# %%
two_ingr=two_ingr[~two_ingr['ingredient_name'].isin(whole_delete)]
two_ingr.dropna(inplace=True)
two_ingr=two_ingr[two_ingr['ingredient_name']!='']
two_ingr['ingredient_name']=two_ingr['ingredient_name'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)
two_ingr.shape
# Out:
# (61671, 4)

# %%
# delete numbers

# %%
nums=string.digits

# %%
def del_num(part,ingredient):
    no_num=ingredient.replace(part,'')
    return no_num

# %%
for num in nums:
    two_ingr['ingredient_name']=two_ingr['ingredient_name'].apply(lambda x:del_num(num,x))

# %%
two_ingr.dropna(inplace=True)
two_ingr=two_ingr[two_ingr['ingredient_name']!='']
two_ingr['ingredient_name']=two_ingr['ingredient_name'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)
two_ingr.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (61659, 4)

# %%
two_ingr_list=list(set(two_ingr['ingredient_name'].values.tolist()))
len(two_ingr_list)
# Out:
# 7177

# %%
two_ingr_list.sort()
two_ingr_list
# Out:
# ['aal geräuchert',
#  'ace saft',
#  'aceto balsamico',
#  'aceto bianco',
#  'achtel',
#  'ackerbohnenpuffbohnen',
#  'ackerpille',
#  'advocaat',
#  'agar agar',
#  'agaragar',
#  'agavendicksaft',
#  'ahornsirup',
#  'ajowan königskümmelsaat',
#  'ajvar',
#  'ajvar paprikapaste',
#  'ajvar scharf',
#  'ajwar scharf',
#  'akazien honig',
#  'alaskaseelachs salzen',
#  'alhokolfreien sirup',
#  'all arabbiatasauce',
#  'allgäuer käse',
#  'almkäse',
#  'aloeveradrink',
#  'alpro soja',
#  'alse semmelmehl',
#  'altbayerischer leberkäse',
#  'alufolie',
#  'amaranth',
#  'amarena kirschlikör',
#  'amarenakirschen',
#  'amarettini',
#  'amarettini mandelkekse',
#  'amaretto',
#  'amaretto likör',
#  'amaretto mandellikör',
#  'amaretto sirup',
#  'amarulalikör afrikanischerwaldfruchtlikör',
#  'american bacon',
#  'amerikan sendwichvolkorn',
#  'amerikan toast',
#  'ammonium hirschhornsalz',
#  'ampulle zitronenaroma',
#  'ananas',
#  'anbau',
#  'ancho chili',
#  'anchovis',
# ...

# %%
# delete part

# %%
ingrs_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^h',row.ingredient_name)!=None:
        ingrs_list.append(row.ingredient_name)
ingrs_list=list(set(ingrs_list))
ingrs_list.sort()
ingrs_list
# Out:
# ['habanero chili',
#  'habanero gelb',
#  'habanero lila',
#  'habanerochili',
#  'hachpuderzucker',
#  'hack',
#  'hackbraten',
#  'hackbällchen',
#  'hackepeterthüringer mett',
#  'hackfeisch',
#  'hackfleich halbhalb',
#  'hackfleisch',
#  'hackfleisch gemischtgewürzt',
#  'hackfleisch gemischtrinderhack',
#  'hackfleisch gemsicht',
#  'hackfleisch gewürzt',
#  'hackfleisch halbhalb',
#  'hackfleisch rind',
#  'hackfleisch rindlamm',
#  'hackfleisch schweinrindgewürzt',
#  'hackfleischkalbfleischrindfleisch',
#  'hacksteak',
#  'hafer',
#  'hafer mehl',
#  'hafer schmelzflocken',
#  'hafer vollkornflocken',
#  'haferflocken',
#  'haferflocken blütenzart',
#  'haferflocken kernig',
#  'haferflocken zart',
#  'haferflocken zarte',
#  'haferschokocrunchymüslivon penny',
#  'hagebutten',
#  'hagebuttenmuss',
#  'hagelzucker',
#  'halbenzitrone',
#  'halbgeschlagene sahne',
#  'halbgriffiges mehl',
#  'halbhalb',
#  'halbwasserhalb milch',
#  'halbweissbrot',
#  'hallimasche',
# ...

# %%
# two_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_ingr_003.csv')

# %%
two_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_ingr_003.csv',index_col=0)
two_ingr.shape
# Out:
# (61659, 4)

# %%
two_ingr.dropna(inplace=True)
two_ingr=two_ingr[two_ingr['ingredient_name']!='']
two_ingr['ingredient_name']=two_ingr['ingredient_name'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)

# %%
two_ingr.shape
# Out:
# (61651, 4)

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'\bfertig.*\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        two_ingr.loc[index,'ingredient_name']=re.sub(r'\bfertig.*\b','',row.ingredient_name)

# %%
two_ingr['ingredient_name'][two_ingr['ingredient_name']=='lollo bionda']='lettuce'
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'gehackte',row.ingredient_name)!=None:
        print(row.ingredient_name)
# Out:
# feingehackterdill
# gehackterosmarinnadeln
# gehacktepetersilie
# gehacktebuttermandelkaramellriegel
# fischgehacktes
# gehacktepetersilie
# gehackte tomaten
# feingehacktepetersilie
# feingehackteingwerwurzel
# etwasgehackte kerbel
# lammgehacktes feindurchgedreht
# gehacktekräuter
# gehacktepetersilie
# gehacktenüsse
# gehackterschnittlauch
# feingehacktepetersilie
# gehackterrosmarin
# gehacktekoriander
# gehackteskoriandergrün

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'\bzum.*',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        two_ingr.loc[index,'ingredient_name']=re.sub(r'\bzum.*','',row.ingredient_name)

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'\bfür.*',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        two_ingr.loc[index,'ingredient_name']=re.sub(r'\bfür.*','',row.ingredient_name)

# %%
delete_parts=['tiefgefroren','alternativ','zerstossen','zerbröseln','anderen','anderer','hälften','amsterdam',
              'abgeriebene','abgezupfte','abtropfgewicht','ausgedrückt','ausgenommen','ausgepresste','ausstechen','ausstecher']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr['ingredient_name']=two_ingr['ingredient_name'].apply(lambda x:del_part(part,x))

# %%
ingrs_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^z',row.ingredient_name)!=None:
        ingrs_list.append(row.ingredient_name)
ingrs_list=list(set(ingrs_list))
ingrs_list.sort()
ingrs_list
# Out:
# ['zahnstocher ',
#  'zander',
#  'zanderfilet',
#  'zartbiiter schokolade',
#  'zartbitter kuvertüre',
#  'zartbitter schokotropfen',
#  'zartbittere kuvertüre',
#  'zartbittere schokolade',
#  'zartbitterkuvertüre',
#  'zartbitterkuvertüre mind',
#  'zartbitterschokolade',
#  'zartbitterschokolade anteil',
#  'zartbitterschokolade bzwkuvertüre',
#  'zartbitterschokolade mitchili',
#  'zartbitterschokolade mitcrunch',
#  'zarte haferflocken',
#  'zartes rindfleisch',
#  'zartweizen',
#  'zbchampignons weiss',
#  'zbgetrocknete erbsen',
#  'zbgrana padano',
#  'zbmilch',
#  'zbnoilly prat',
#  'zbparadiescreme vanille',
#  'zbsp vontoppits',
#  'zbvon knorr',
#  'zbwiener griessler',
#  'zebra',
#  'zebröselte löffelbiskuits',
#  'zehefrisch',
#  'zehen knoblauch',
#  'zerklrteoregano',
#  'zerkrümelter ziegenkäse',
#  'zerriebenechili´s',
#  'zerschnibbelt',
#  'ziebel rot',
#  'ziegenfrischkäse',
#  'ziegenfrischkäse buko',
#  'ziegenfrischkäse mitkräutern',
# ...

# %%
delete_whole=['dafür wenigeröl','dekostäbchen schwerter','denensie verb','eingrosses glas','elsässer art','etwaszum einfetten',
'etwaszum garnieren','flache auflaufform','flache','flacher tortenboden','ihrwisst schon','mache esselbst',
'triple sec','ungwers mag','unter hitzeauflösen','weingeist ig']

# %%
two_ingr=two_ingr[~two_ingr['ingredient_name'].isin(delete_whole)]
two_ingr.reset_index(drop=True,inplace=True)

# %%
delete_words=['backpapier','frischgehackt','bevorzugetilda','bemehlt','bereitsget','aushartweizengriess','braunfeinblättrig',
'feiniggeschnitten','chen','schote','getrocknet','fresh','dafür','das','asiamarkt','daumendick','daumennagel',
'davon','dekomaterial','dekor','demasiamarkt','derküchenmaschine','frischwaschen','dkl','doppelte','doppelter',
'doppeltes','dr oetker','dream','duenne','dünnestreifen','wieroquefort','editio','mgrösse','einmachglas','einmachgläser',
'einwegspritzen','tk','erd','erst','es','esrom','essl','etaws','etc','etwa','etwfein','ewas','extrascharfer',
'extrafr','evltfrische','evtlgekörnte','fach','feinabreiben','feingeschnittene','fertigenteig','fertigprodukt',
'festkochenende','fringe','frische','frischgemahlener','fruchtiger','fruchtigen','fruchtiger','inrøllchen',
'frz','frühl','mmgarten','geputztget','köpfefrisch','schräg','zudekorieren','fähnchen','gefro','gesammelt',
'geschleudert','geschnitten','gezupften','glattgerührte','grossechen','grossmutters','grünländer','erweicht',
'hellgrüne','hellgrünes','ohneknochen','ig','in','dünngeklopft','kaltgepresstes','vorwiegendfestkochend',
'kl','kleingeschnittene','klnstreifen','klnstückchen','klportionen','frsichgehackt','evtgetrocknet',
'laktosefreie','feindurchgedreht','möglichstentbeint','ohneknochen','künstlichstill','möglichst','obers',
'extravergine','fruchtig','nativ','geschalt','filetiert','frischgekocht','gepellt','möglkl','weniger',
'ungehärtet','ringegescnitten','ringe','scharfes','scharfen','scharfe','tk','tl','ungeschälte','ungespritzte',
'ungesüsster','ungesüssten','ungesüsstes','ungesüsste','unterschiedlich','unheiliges','ungewürzt','verschiedene',
'vom','vonlindt','weglassen','frischgepresst','halbiert','gedrittelt','frischabziehen','frischgegart','nachbarsgarten',
'frischschälen','ganz','ge','gespickt','grobget','frischabziehen','sommerziebelget']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr['ingredient_name']=two_ingr['ingredient_name'].apply(lambda x:del_words(x))

# %%
delete_parts=['durchwachsenget','durchwachsener','bio','schoten','flocken','schote','stenge','eingelegte','eingelegtod',
'eingeweichtes','eingeweichtu','esslöffel','etwas','gehacktes','gehackter','getrockneter','eventuell',
'evtlweitere','konzentriertes','feingehackter','feingeschnittenen','festkochende','frischer','frischgemahlner',
'gepressten','geriebener','geriebene','geschnittener','geschnittenes','geschnittener','getrockneter','glattgerührtes',
'kleingeschnittener','gehacktes','teelöffel','kleingeschnittten']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr['ingredient_name']=two_ingr['ingredient_name'].apply(lambda x:del_part(part,x))

# %%
delete_parts=['gehackte','feingehackte','frische','gerieben','geschnitten','getrocknete','kleingeschnittene',
              'löffel']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr['ingredient_name']=two_ingr['ingredient_name'].apply(lambda x:del_part(part,x))

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'^tk',row.ingredient_name)!=None:
        two_ingr.loc[index,'ingredient_name']=re.sub(r'tk','',row.ingredient_name)

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'^tl',row.ingredient_name)!=None:
        two_ingr.loc[index,'ingredient_name']=re.sub(r'tl','',row.ingredient_name)

# %%
two_ingr.dropna(inplace=True)
two_ingr=two_ingr[two_ingr['ingredient_name']!='']
two_ingr['ingredient_name']=two_ingr['ingredient_name'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)
two_ingr.shape
# Out:
# (61544, 4)

# %%
two_ingr_list=list(set(two_ingr['ingredient_name'].values.tolist()))
len(two_ingr_list)
# Out:
# 6748

# %%
two_ingr_list.sort()
two_ingr_list
# Out:
# ['aal geräuchert',
#  'ace saft',
#  'aceto balsamico',
#  'aceto bianco',
#  'achtel',
#  'ackerbohnenpuffbohnen',
#  'ackerpille',
#  'advocaat',
#  'agar agar',
#  'agaragar',
#  'agavendicksaft',
#  'agliooliopeperonico',
#  'ahornsirup',
#  'ajowan königskümmelsaat',
#  'ajvar',
#  'ajvar paprikapaste',
#  'ajvar scharf',
#  'ajwar scharf',
#  'akazien honig',
#  'alaskaseelachs salzen',
#  'alhokolfreien sirup',
#  'all arabbiatasauce',
#  'allgäuer käse',
#  'almkäse',
#  'aloeveradrink',
#  'alpro soja',
#  'alse semmelmehl',
#  'altbayerischer leberkäse',
#  'alufolie',
#  'amaranth',
#  'amarena kirschlikör',
#  'amarenakirschen',
#  'amarettini',
#  'amarettini mandelkekse',
#  'amaretto',
#  'amaretto likör',
#  'amaretto mandellikör',
#  'amaretto sirup',
#  'amarulalikör afrikanischerwaldfruchtlikör',
#  'american bacon',
#  'amerikan sendwichvolkorn',
#  'amerikan toast',
#  'ammonium hirschhornsalz',
#  'ampulle zitronenaroma',
#  'ananas',
#  'ananassaft',
# ...

# %%
two_one_ingr=two_ingr[two_ingr['ingredient_name'].str.split().str.len()==1]
two_one_ingr.shape
# Out:
# (40877, 4)

# %%
two_one_ingrs=list(set(two_one_ingr['ingredient_name'].values.tolist()))
len(two_one_ingrs)
# Out:
# 2583

# %%
two_one_ingrs.sort()
two_one_ingrs
# Out:
# ['achtel',
#  'ackerbohnenpuffbohnen',
#  'ackerpille',
#  'advocaat',
#  'agaragar',
#  'agavendicksaft',
#  'agliooliopeperonico',
#  'ahornsirup',
#  'ajvar',
#  'almkäse',
#  'aloeveradrink',
#  'alufolie',
#  'amaranth',
#  'amarenakirschen',
#  'amarettini',
#  'amaretto',
#  'ananas',
#  'ananassaft',
#  'anbau',
#  'anchovis',
#  'anderekräuter',
#  'angebraten',
#  'angeröstet',
#  'anis',
#  'anispulver',
#  'apfel',
#  'apfelbirnen',
#  'apfelbrei',
#  'apfelessig',
#  'apfelin',
#  'apfelkraut',
#  'apfelmus',
#  'apfelringe',
#  'apfelsaft',
#  'apfelschnitze',
#  'apfelsinensaft',
#  'appenzeller',
#  'appenzellerkäse',
#  'aprikose',
#  'aprikosen',
#  'aprikosenhälfte',
#  'aprikosenkonfitüre',
#  'aprikosenmarmelade',
#  'aprikosensaft',
#  'aprokosen',
#  'arborio',
#  'artchinamischung',
#  'artischocken',
#  'artischockenherzen',
#  'asiagemüse',
#  'aubergine',
#  'auberginen',
#  'auch',
#  'auchkochschinken',
#  'auchschmand',
#  'auchzuckerersatzstoff',
# ...

# %%
#two_one_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_one_ingr.csv')

# %%
two_two_ingr=two_ingr[two_ingr['ingredient_name'].str.split().str.len()>1]
two_two_ingr.shape
# Out:
# (20667, 4)

# %%
two_two_ingrs=list(set(two_two_ingr['ingredient_name'].values.tolist()))
len(two_two_ingrs)
# Out:
# 4165

# %%
two_two_ingrs.sort()
two_two_ingrs
# Out:
# ['aal geräuchert',
#  'ace saft',
#  'aceto balsamico',
#  'aceto bianco',
#  'agar agar',
#  'ajowan königskümmelsaat',
#  'ajvar paprikapaste',
#  'ajvar scharf',
#  'ajwar scharf',
#  'akazien honig',
#  'alaskaseelachs salzen',
#  'alhokolfreien sirup',
#  'all arabbiatasauce',
#  'allgäuer käse',
#  'alpro soja',
#  'alse semmelmehl',
#  'altbayerischer leberkäse',
#  'amarena kirschlikör',
#  'amarettini mandelkekse',
#  'amaretto likör',
#  'amaretto mandellikör',
#  'amaretto sirup',
#  'amarulalikör afrikanischerwaldfruchtlikör',
#  'american bacon',
#  'amerikan sendwichvolkorn',
#  'amerikan toast',
#  'ammonium hirschhornsalz',
#  'ampulle zitronenaroma',
#  'ancho chili',
#  'anderebrühwürste zbbratwürste',
#  'angel dor',
#  'anis gewürz',
#  'apfel boskop',
#  'apfel breaburn',
#  'apfel elstar',
#  'apfel essig',
#  'apfel etw',
#  'apfel fruchtsaft',
#  'apfel gala',
#  'apfel johnagold',
#  'apfel kanzi',
#  'apfel rot',
#  'apfelessig rapsöl',
# ...

# %%
two_two_ingr
# Out:
#        recipe_id                                        recipe_href  \
# 2          15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 3          15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 4          25386                 /rezept/423974/I-Zwiebelsauce.html
# 9         100118               /rezept/275058/Tofu-Suess-sauer.html
# 15         88644         /rezept/112415/Bayerischer-Wurstsalat.html
# ...          ...                                                ...
# 61525      87906  /rezept/418474/Backen-Nussiges-Weihnachts-Dink...
# 61526      87906  /rezept/418474/Backen-Nussiges-Weihnachts-Dink...
# 61538      40552         /rezept/281466/Bueffett-Schinkentorte.html
# 61540      40552         /rezept/281466/Bueffett-Schinkentorte.html
# 61542      40552         /rezept/281466/Bueffett-Schinkentorte.html
#
#                                               name  \
# 2                                    hefe granulat
# ...

# %%
two_two_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr.csv')
