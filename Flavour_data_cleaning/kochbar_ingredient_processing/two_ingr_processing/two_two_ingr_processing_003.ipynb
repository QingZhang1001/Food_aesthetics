# %%
import pandas as pd
import numpy as np
import os
import re
import string

# %%
two_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_002.csv',index_col=0)
two_ingr.shape
# Out:
# (3197, 3)

# %%
two_ingr
# Out:
#               ingredient_name               parse_ingr  \
# 0               pommes frites            pommes frites
# 1          walnuss panzerotti       walnuss panzerotti
# 2       granatapfel balsamico    granatapfel balsamico
# 3        schwlende geräuchert     schwlende geräuchert
# 4          pökelwaren eisbein       pökelwaren eisbein
# ...                       ...                      ...
# 3192      paprika rotgelbgrün      paprika rotgelbgrün
# 3193  brunch paprikapepperoni  brunch paprikapepperoni
# 3194    asiatisches wokgewürz    asiatisches wokgewürz
# 3195           kle vomschwein           kle vomschwein
# 3196           kalb schnitzel           kalb schnitzel
#
#                        en_ingr
# 0                 french fries
# 1            walnut panzerotti
# 2         pomegranate balsamic
# 3            smoldering smoked
# 4           cured pork knuckle
# ...                        ...
# 3192  red-yellow-green paprika
# 3193  brunch paprika pepperoni
# ...

# %%
two_ingr[two_ingr['en_ingr']=='sway lightly cured']
# Out:
#                 ingredient_name                 parse_ingr             en_ingr
# 2909  schwrücken leichtgepökelt  schwrücken leichtgepökelt  sway lightly cured

# %%
# replace now
# roasted_beef, roasted_meat, roasted_turkey, roasted_lamb, roasted_pork, roasted_chicken,
# smoked_sausage,smoked_summer_sausage,smoked_pork,uncured_smoked_pork,smoked_pork_belly,
# fried_chicken,fried_pork,fried_beef,fried_cured_pork,
# grilled_beef,grilled_pork,
# boiled_chicken,uncured_boiled_pork,boiled_meat,boiled_beef,boiled_pork,
# cured_ham,cured_pork,
# baked_potato

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'\bbake.*\b',row.en_ingr)!=None:
        print(row.en_ingr)
# Out:
# walnut small baked goods
# wholemeal baked goods with fiber
# fruit tea baked apple
# baked ham

# %%
# cure
two_ingr['en_ingr'][two_ingr['en_ingr']=='cured pork knuckle']='cured_pork'
two_ingr['en_ingr'][two_ingr['en_ingr']=='sway lightly cured']='cured_pork'
# smoke
two_ingr['en_ingr'][two_ingr['en_ingr']=='smoldering smoked']='smoked_pork'
two_ingr['en_ingr'][two_ingr['en_ingr']=='smoked kassler']='smoked_pork'
two_ingr['en_ingr'][two_ingr['en_ingr']=='mettenden smoked']='smoked_sausage'
two_ingr['en_ingr'][two_ingr['en_ingr']=='mettenden smoked']='smoked_sausage'
two_ingr['en_ingr'][two_ingr['en_ingr']=='smoked sausages']='smoked_sausage'
two_ingr['en_ingr'][two_ingr['en_ingr']=='smoked bratwurst']='smoked_sausage'
# roast
two_ingr['en_ingr'][two_ingr['en_ingr']=='roast beef with bones']='roasted_beef'
two_ingr['en_ingr'][two_ingr['en_ingr']=='good pork roast grilled sausages']='sausage'
two_ingr['en_ingr'][two_ingr['en_ingr']=='roast chicken legs fresh']='roasted_chicken'
two_ingr['en_ingr'][two_ingr['en_ingr']=='kassler roast']='roasted_pork'
two_ingr['en_ingr'][two_ingr['en_ingr']=='swell roast']='roasted_pork'

# %%
delete_words=['roasted','smoked','cured','baked']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_words(x))

# %%
two_ingr['en_ingr']=two_ingr['en_ingr'].str.strip()

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'flavor',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['bitter almond flavor',
#  'brunch chili pepper flavor',
#  'cake icing powder with strawberry flavor',
#  'cappuccino powder with hazelnut flavor',
#  'caramel-flavored pudding powder',
#  'cheese garlic flavor',
#  'cherry flavor',
#  'cherry flavored cooking pudding powder',
#  'chocolate flavored cooking pudding powder',
#  'chocolate flavored pudding powder',
#  'cooking pudding powder cream flavor',
#  'cream cheese with chocolate flavor',
#  'cream cheese with flavor',
#  'fine quark, strawberry flavor',
#  'flavored caramel flavor',
#  'flavored mayonaise',
#  'fruttina lemon flavor',
#  'god dish lemon flavor',
#  'icing powder with berry flavor',
#  'lemon flavor',
#  'mushroom-flavored cream cheese',
#  'pear-flavored ice cream',
#  'processed cheese cream flavor',
#  'pudding powder almond flavor',
#  'pudding powder with pistaizen flavor',
#  'rapeseed oil with butter flavor',
#  'rum flavor pudding powder',
#  'strawberry flavored cooking pudding powder',
# ...

# %%
whole_change_dict={'bitter almond flavor':'almond_aroma','brunch chili pepper flavor':'brunch chili',
             'cake icing powder with strawberry flavor':'strawberry_icing_powder',
             'cappuccino powder with hazelnut flavor':'hazelnut_cappuccino',
             'caramel-flavored pudding powder':'caramel_powder','cherry flavored cooking pudding powder':'cherry_pudding',
            'chocolate flavored cooking pudding powder':'chocolate_pudding',
            'chocolate flavored pudding powder':'chocolate_pudding',
            'cooking pudding powder cream flavor':'cream_pudding',
            'cream cheese with chocolate flavor':'chocolate_cream_cheese',
            'fine quark, strawberry flavor':'strawberry_quark',
            'fruttina lemon flavor':'lemon_aroma','icing powder with berry flavor':'berry_icing_powder',
            'lemon flavor':'lemon_aroma','mushroom-flavored cream cheese':'mushroom_cream_cheese',
            'pear-flavored ice cream':'pear_ice_cream','pudding powder almond flavor':'almond_pudding',
            'pudding powder with pistaizen flavor':'pistachio_pudding','rum flavor pudding powder':'rum_pudding',
            'strawberry flavored cooking pudding powder':'strawberry_pudding',
            'strawberry-flavored cake topping':'strawberry_cake_topping','tangerine flavor':'tangerine_aroma',
            'vanilla flavor':'vanilla_aroma','vanilla flavor powder':'vanilla_pudding',
             'vanilla flavored cooking pudding powder':'vanilla_pudding','vegetable cream with butter flavor':'butter_cream'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^d',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['danish gurgle salad',
#  'danish remoulade',
#  'danish turkish vegetables',
#  'dannananas',
#  'danziger goldwasser',
#  'dark chocolate',
#  'dark chocolate chips',
#  'dark chocolate cocoa',
#  'dark chocolate glaze',
#  'dark chocolate icing',
#  'dark chocolate mass',
#  'dark chocolate portion',
#  'dark chocolate sprinkles',
#  'dark chocolate with crunch',
#  'dark sauce',
#  'dauvergue blue',
#  'deer club',
#  'deer shoulder',
#  'dersteinpilze',
#  'dessert cream chocolate',
#  'dessert powder quark fine',
#  'dessert sauce',
#  'dessertsaucenpulver vanilla',
#  'devils ravioli',
#  'dextremadura pepper',
#  'diamond ice magic',
#  'dijon mustard',
#  'dijonsenf',
#  'dill',
#  'dinkelbrot mitkastanienstückchen',
#  'div kitchen herbs',
#  'djuve circle mix of maggie',
#  'dosentomaten',
#  'double cream',
#  'double handle flour',
#  'drink wssig',
#  'duck',
#  'duck breast',
#  'duck breasts',
#  'durum wheat flour',
#  'dusting of powdered sugar',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='drink wssig']
# Out:
#      ingredient_name  parse_ingr      en_ingr
# 1709      ital wssig  ital wssig  drink wssig

# %%
chnage_dict={'durum wheat flour':'wheat','dusting of powdered sugar':'sugar',
    'dosentomaten':'tomato','double handle flour':'wheat','drink wssig':'vinegar',
    'div kitchen herbs':'herb','djuve circle mix of maggie':'Fix_für_Reis_djuvec_art',
    'dijon mustard':'mustard','dijonsenf':'mustard','dinkelbrot mitkastanienstückchen':'wheat',
    'dextremadura pepper':'piment_pepper','diamond ice magic':'Diamant_Eiszauber',
    'dessertsaucenpulver vanilla':'vanilla_sauce','devils ravioli':'Ravioli_Diavoli',
    'dersteinpilze':'mushroom','dessert cream chocolate':'chocolate_cream','dessert powder quark fine':'quark',
    'danish remoulade':'Dänische_Remoulade','dauvergue blue':'bleu_dauvergue_cheese',
    'curryketchup scharf':'curry_ketchup','danish gurgle salad':'Dänischer_Gurgensalat',
    'curacao bar syrup':'curacao blue','curacao schnapps':'curacao blue','curcacao blue':'curacao blue',
    'cremé double':'cream','crescenza bzwstracchinokäse':'crescenza_cheese','crisp chocolate white':'chocolate',
    'cremefine vanilla':'vanilla_cremefine','cremefine whipped cream':'cremefine,whipped cream',
    'creme fresh':'cream','creme fraich':'creme_fraiche','creme fráiche':'creme_fraiche',
    'cream spread herbs':'herb','creme brulee':'Creme_Brulee','creme dessertstatiatella':'dessert',
    'cream condensed milk':'milk','cream layer cheese':'cheese','cream pie cream':'dairy',
    'cream dessert strawberry':'strawberry_cream','cream horseradish dertube':'horseradish_cream',
    'cream cheese tomato':'tomato_cream_cheese','cream cheese with white herbs':'herb_cream_cheese',
    'cream cheese horseradish':'horseradish_cream_cheese','cream cheese mediterranean herbs':'herb_cream_cheese',
    'cream cheese herbal philadelphia':'herb_cream_cheese','cream cheese herbs':'herb_cream_cheese',
    'cous cous':'couscous','cream cheese garlic':'garlic_cream_cheese',
    'coffee with milk':'coffee,milk','coffee chocolate beans':'coffee','confectionery giottos':'snack',
    'cocktailwürstchen':'cocktail sausages','cocoa glaze':'cocoa icing','coconut rusks bahlsen':'coconut_zwieback',
    'citronat demreformhaus':'lemon','citrus senfsosse':'lemon_senf_sauce',
    'chorizo substitute paprika salami':'smoked_sausage','choux pastry guarantee':'Brandteig_garant',
    'chocolate residue with cappuccino':'chocolate_cappuccino','chocolate-coated espresso beans':'espresso',
    'chocolate flakes':'chocolate','chocolate cake icing':'chocolate icing',
    'choco chips':'chocolate_chip','choco crossie':'chocolate_chip','choco crossis':'chocolate_chip',
    'chinese sprout vegetables':'vegetable','chinese sweet and sour':'chili_sauce','chocko kusse':'chocolate',
    'chillies red':'chili','chin':'spice','chin huajiao':'pepper','chin mix':'spice',
    'chili rosmarinsalz':'chili,rosemary,salt','chilitomatensosse chilitomatensosse':'chili_tomato_sauce',
    'chicken soup paste or broth':'chicken_broth','chickpea flour':'chickpea','chicoree rot':'cabbage',
    'chester processed cheese':'cheese','chester rahmstufeschmelzkäse':'cheese','chicken pork with saddle':'chicken',
    'cherry flavor':'cherry_aroma','cherry tommaten':'cherry_tomato','chervil tarragon':'chervil,tarragon',
    'cheese pineapple skewers':'pineapple_cheese','cherries sour':'sour_cherry','cherry date tomatoes':'cherry_tomato',
    'cheese goude':'gouda_cheese','cheese milk':'cheese','cheese mmentaler':'emmentaler_cheese',
    'chayenne pfeffer':'cayenne_pepper','chayota milk':'chayote','cheese garlic flavor':'garlic_cheese',
    'chakalakasauce curry':'chakalaka','champagne obalsami':'vinegar','champions brown':'mushroom',
    'carbonara sosse':'carbonara_sauce','cenovis broth':'broth','ch spice mixes':'spice',
    'capri drink powder orange':'orange_drink','caramb mix':'caramb_spice','caramel wore':'caramel',
    'caper anchovies':'caper,anchovy','cappuccino powder vanilla':'vanilla_cappuccino_powder',
    'cake viennese mass':'cake','camembert geramontcremigwürzig':'Géramont_cremig_würzig',
    'camembert pepperoni':'chili_camembert_cheese','cannelloni nudelröhrchen':'pasta',
    'cafe latte':'cafe','cafe oriental':'cafe','calamansi balsamessig':'balsamic_vinegar',
    'biscuit base':'biscuit_cake_base','cookies biscuits':'cookie','minioreo biscuits':'biscuit',
    'obsttortenboden biscuits':'biscuit_cake_base','oreo biscuits':'biscuit','speculoos biscuits':'biscuit',
    'swedish double oat biscuits with chocolate':'chocolate_biscuit','wholemeal biscuits':'biscuit',
    'cake cream powder vanilla':'vanilla_cream','cake cream vanilla':'vanilla_cream',
    'cake cream strawberry':'strawberry_cream','call milk rice':'milk rice',
    'chocolate eggs from all of me':'chocolate','chocolate kisses or kisses':'chocolate',
    'chocolate x whole milk x nut':'chocolate,milk,nut','citrus pulp zest lemon':'citrus,lemon_zest',
    'cut salad in own':'lettuce'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
delete_words=['bratfett','miree','double','fit','kochsahne','dark','portion','double','breast','breasts',
'go','mixes','drained','fillet','ger','glasses','processed','rotfrisch','wok','fresh rolls','off-dry','cute',
'capsules','grafschafter','ceylon','ger','odtabasco','balls','call','letters','nicholas','mixture',
'condensed','cook','cooked','cooking','odblattpetersili','corned','crownberries','bruschetta','grainy']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_words(x))

# %%
delete_parts=['with crunch','as a splash of color','own stock','nut core','granulate own','optional white vegetable broth','the tube',
'own stock','cherry glasses','breast filletfresh','breast fillets','fresh rolls','bar bounty',
'decor marzipan roses','droplets','kisses or kisses','stick ceylon','clean parried','as candles',
'with chives','with flavor','fine chocolate','to beat','culinesse vegetable','danish turkish']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_part(part,x))

# %%
whole_delete=['chocolate writing brown','chocolate writing white','clean parried','casserole lid','coarsely black',
'conchiglie snail shell','confetti dembackchop','core arms']

# %%
two_ingr=two_ingr[~two_ingr['en_ingr'].isin(whole_delete)]
two_ingr=two_ingr[two_ingr['en_ingr']!='']
two_ingr['en_ingr']=two_ingr['en_ingr'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)

# %%
en_ingrs=list(set(two_ingr['en_ingr'].values.tolist()))
len(en_ingrs)
# Out:
# 2506

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^h',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['hackfleich halbhalb',
#  'hackfleisch halbhalb',
#  'haferschokocrunchymüslivon penny',
#  'hake place',
#  'halibut',
#  'ham',
#  'ham cracker paprika',
#  'ham meat sausage',
#  'ham poland poland',
#  'hamburger buns',
#  'hamburger meat',
#  'handle flour',
#  'hard bun',
#  'haribo flowers',
#  'harissa chiligewürz',
#  'harissa chiligewürzmischung',
#  'harissa powder',
#  'harissa würzmischung',
#  'harz red sausage',
#  'harzer cheese',
#  'hash browns',
#  'hazelnut brittle',
#  'hazelnut cake glaze',
#  'hazelnut flour',
#  'hazelnut glaze',
#  'hazelnut glaze schwartau',
#  'hazelnut kernels',
#  'hazelnut or almond',
#  'hazelnut_cappuccino',
#  'hearty meat rolls a&#39;lamanfred',
#  'hearty rye bread',
#  'heavenly peppery ziron thyme vinegar',
#  'heavy chicken',
#  'hefeweizenbier obergärig',
#  'heidelbeere',
#  'herb',
#  'herb balance',
#  'herb butter baguette',
#  'herb chanterelles or chanterelles',
#  'herb greek style',
#  'herb mix italian',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='hollow spheres white']
# Out:
#       ingredient_name        parse_ingr               en_ingr
# 589  hohlkugeln weiss  hohlkugeln weiss  hollow spheres white

# %%
whole_change_dict={'hot dogs':'hot_dog','hot sauce':'hot_sauce','hänchen oberkeule':'chicken','hänchenfleischmit mismuscheln':'chicken',
    'herbal mix singapore':'singapore_herb','herbs italian':'italian_herb','hijack':'caper',
    'herb greek style':'greek_herb','herb mix italian':'italian_herb','herb tkitalian':'italian_herb',
    'haribo flowers':'gummi','hash browns':'Rösti','heidelbeere':'blueberry',
    'hake place':'fish','ham cracker paprika':'ham','ham meat sausage':'sausage','handle flour':'wheat',
    'hackfleich halbhalb':'meat','hackfleisch halbhalb':'meat','haferschokocrunchymüslivon penny':'chocolate',
    'gypsy grill sauce homan':'Zigeunersauce','gyros würzer':'gyros spice','gøtterspeise red':'götterspeise',
    'green hot peppers':'chili','green paparika':'bell_pepper','green paprika':'bell_pepper','gypsy sse':'Zigeunersauce',
    'green core':'Grünkern','green core shot':'Grünkern','green green beans':'green bean',
    'green bean dec':'green bean','green broad beans':'broad bean','green chilli':'chili','green chillies':'chili',
    'goldmaismexiko mix':'corn','graham krackers':'graham crackers','grammkalte butter':'butter_cracker',
    'gods dish lemon':'lemon_götterspeise','gods dish with taste':'götterspeise',
    'god food strawberry':'strawberry_götterspeise','god food waldmeister':'galium_odoratum_götterspeise',
    'god food green':'götterspeise','god food raspberry':'raspberry_götterspeise',
    'god dish lemon flavor':'lemon_götterspeise','god dish raspberry':'raspberry_götterspeise',
    'goat cream cheese buko':'goat_cheese',
    'ginger powder':'ginger','glasnudeln ausmungobohnenmehl':'glass noodle','glucose syrup light':'Glukosesirup',
    'ghee butter':'butter','ghee clarified butter':'butter','ghee indian':'ghee',
    'getes citronat':'succade','gewùrfelt upholstery':'celery','gewürz chillies':'chili',
    'gelfix super':'gelfix','gelierfix etra':'gelfix','geterrinderschmorbraten derschulter':'roasted_beef',
    'garlic leek':'garlic','garlic salt pepper white':'garlic_salt,pepper','garlic with lemon thyme':'garlic,lemon_thyme',
    'galetta cremepuddingpulvervanillegeschmack':'vanilla_pudding',
    'fruit tea apple':'apple_tea','fruits churches':'cherry','fussili nudeln':'fussili_noodle','fussili':'fussili_noodle',
    'fried schwfleisch':'fried_pork','frosting hearts':'sugar','fruit of the vinegar bread tree':'fruit',
    'french country bread':'bread','fried chicken spice':'fried_chicken','fried lightly':'roasted_pork',
    'flowerhoney':'honey','flusskrebse':'crab','fondant orange':'orange_fondant','franconian sauerkaut':'Sauerkaut',
    'flanksteak auchbauchlappensteak':'beef,pork_bauch','flower desel':'salt','flower powergewürzblütenmischung':'tea',
    'franz schafscamembert':'camembert_cheese','fine cream':'fine_cream','fine creams':'fine_cream',
    'eating strings':'gummi','edelpilzkäse cambozola':'cheese','efaschingskrapfen':'Bombolone',
    'ehrmann fruit quark':'quark','eiermayonaiseodellikatessmayonaise thomy':'mayonnaise',
    'einrotes gelee':'jelly','eisbergsalat from':'cabbage','eisfix caramel':'caramel_ice_cream',
    'eisfix chocolate':'chocolate_ice_cream','emit chiliwürzcreme':'chili_cream',
    'entenschlegel edeka':'duck','entrcote between ribs':'beef','entrecotes steaks':'beef',
    'eskastanien vakunumiert':'chestnut','espelette pepper':'chili','espresso powder':'espresso'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
#two_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_003.csv')

# %%
two_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_003.csv',index_col=0)
two_ingr.shape
# Out:
# (3189, 3)

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^m',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['macadamia syrup',
#  'macis muscatblüte',
#  'macis spice',
#  'mackerel',
#  'made red',
#  'madeirawein',
#  'magarine dictate',
#  'magaritenblüten',
#  'maggi hot',
#  'maggi lemon butter sauce',
#  'maggi mashed potatoes',
#  'maggi sausage goulash',
#  'maggi seasoning mix',
#  'maggi spice mix',
#  'maggi sugar',
#  'maggi wort',
#  'maggifix',
#  'mahonhartkäse manchego',
#  'mais',
#  'maisgriess polenta',
#  'maiskolben sauerkonserve',
#  'maismehl gelb',
#  'male aroma',
#  'malibu kokoslikör',
#  'malibu rum',
#  'malt',
#  'mandarine',
#  'mandarinen á',
#  'mandarinorangen',
#  'mandel',
#  'mango',
#  'mango fruit nectar',
#  'mango seif',
#  'mango_balsamic_vinegar',
#  'mangochutney süsssauer',
#  'maple syrup',
#  'maracuja yogurt',
#  'maraschino cherry liqueur',
#  'margarine',
#  'margarine butter',
#  'margarine corn oil',
#  'margarine dictate',
#  'margarine semi-fatty linoleic acid',
#  'margarine vegetable',
#  'margere ham',
#  'marinierte rotepaprika',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='my dear']
# Out:
#      ingredient_name  parse_ingr  en_ingr
# 2676      mon cherie  mon cherie  my dear

# %%
whole_change_dict={'mustard worcester sauce':'worcestershire_sauce','my dear':'Mon_Cherie',
    'mustard seed black':'mustard_seed','mustard seeds brown':'mustard_seed',
    'mushrooms chanterelles':'chanterelles','muskasnus':'nutmeg','mussels ready to':'mussel',
    'mushroom soaking filled with vegetable broth':'mushroom,vegetable_broth',
    'munsterkäsevacherolstalbray among others':'munster_cheese','muschelnudeln shells':'shell_pasta',
    'mu errpilze':'mushroom','multigrain bread mix':'bread','mung beans green':'mung_bean',
    'mortadella north':'mortadella_sausage','mou meatballs':'meat','mozart cremelikör':'liqueur',
    'mohnfix backfertigemohnmasse':'poppy','mondamin pulverized':'corn_starch','mondamin cornstarch':'corn_starch',
    'mohn back':'poppy','mohn fix':'poppy','mohnback backfertigemohnfüllung':'poppy',
    'misopaste hell':'miso','mitelscharf peppers':'chili','mocha beans chocolate':'chocolate','mocha chocolate':'chocolate',
    'mirabellen red':'plum','mirin travel':'rice_vinegar','mirin white wine':'rice_vinegar',
    'mint cayena':'cayenne_pepper','minutes of steak':'beef','mirabelle vinegar apple cider vinegar':'apple_cider',
    'minioreo biscuits':'biscuit','minis pens':'pasta','minischokoeier mitzuckerglasur':'chocolate',
    'mini dumplings potato dumplings':'potato_dumpling','mini hanuta':'snack',
    'milka tender':'chocolate','milchmädchen gezuckertekodensmilch':'milk','milky':'milk',
    'milka alpine whole milk':'milk_chocolate','milka delicately':'chocolate',
    'middle ages gauda':'gouda_cheese','mil saft':'juice','milk candy caramel':'milk_caramel',
    'mexican spice mix':'mexican_spice','mexican spice pepper':'mexican_spice',
    'mexican corn mix':'corn','mexican grill sauce':'mexican_barbecue_sauce',
    'merrettichfrischkäse cantadou':'merrettich_cream_cheese','mett seasoned':'pork',
    'mediterranean vegetable broth':'mediterranean_broth',
    'mediterranean herbal':'mediterranean_herbs','mediterranean herbal salt':'mediterranean_herbs',
    'meat sausage poultry':'sausage','meat tortelloni':'tortelloni',
    'mazola öl':'rapeseed_oil','mccain pompoms':'Pom_Poms','meat sausage garlic':'garlic_sausage',
    'mascarpone italfrischkäse':'mascarpone_cheese','masoor dal':'lentil','mayoran dost':'marjoram',
    'maroni':'chestnut','marzipan niederegger white bread':'white_bread','masala green':'masala',
    'margere ham':'ham','marinierte rotepaprika':'bell_pepper','marjoram spice':'marjoram',
    'maracuja yogurt':'passion_fruit_yoghurt','maraschino cherry liqueur':'maraschino',
    'mandel':'almond','mango fruit nectar':'mango_juice','mango seif':'mango','mangochutney süsssauer':'mango_chutney',
    'malibu kokoslikör':'coconut_liqueur','mandarine':'mandarin','mandarinen á':'mandarin','mandarinorangen':'mandarin',
    'mais':'corn','maisgriess polenta':'corn','maismehl gelb':'corn','male aroma':'arrak aroma',
    'magaritenblüten':'leucanthemum','maggi wort':'spice','mahonhartkäse manchego':'mahon_cheese',
    'macis muscatblüte':'nutmeg','macis spice':'nutmeg','madeirawein':'madeira','magarine dictate':'margarine',
    'little pens':'pasta','little champagner':'piccolo champagner','lovage seeds ajwan':'ajwain','lovage spice':'lovage',
    'light baking malt':'grain','lime peel zest':'lime_zest','liqueur wine':'liqueur','liqueurs coffee liqueur':'coffee liqueur',
    'lemony javacurry':'lemon_curry','lettuce green':'lettuce','licorice snails':'gummi',
    'lemonade fanta':'fanta_drink','lemonjelly lemon jam':'lemon_jam','lemons juilienne':'lemon_zest',
    'lemon sugar uvanilla sugar':'lemon_sugar,vanilla_sugar','lemon vanilla':'lemon,vanilla',
    'leek garlic':'garlic','lemon lemon aroma':'lemon_aroma','lemon shower zb fanta':'fanta_drink',
    'nussnougat cream':'nut nougat cream','nussnougat zbschwartau':'nut nougat cream','nutmeg salt':'nutmeg,salt',
    'nudeln shells':'shell_noodle','nut nougat mass':'nut nougat cream','nussnougat':'nut nougat cream',
    'nudel butterflies':'pasta','nudeln conchiglioni':'conchiglie_noodle','nudeln fussili':'fussili_noodle',
    'not teelzucker':'sugar','nougat mass had nougat chocolate':'nougat,chocolate',
    'norderneyer sea air ham':'ham','north houses grain':'Nordhäuser_Doppelkorn',
    'noble cream cream cheese':'cream_cheese','noodle croissant':'pasta','noodle dough noodle dough':'pasta',
    'nester pappardelle':'pasta','nitrite curing salt from the meat':'salt',
    'owner':'egg','nasigoreng spice':'nasi_goreng_spice','neapolitan waffles':'wafer',
    'kokoskugeln raffaello':'coco_ball','krakauer ham sausage':'herb_sausage','krakauer sausages':'herb_sausage',
    'kochpudding mitzitronengeschmack':'lemon_pudding','kokoskonfektkugeln zbraffaellos':'coco_ball',
    'kle vomschwein':'pork','knackwürstchen brühwürstchen':'sausage',
    'kelloggs cockies':'cookies','kellogs trio':'snacks','kieler sprats':'fish','klaffmuscheln':'clam',
    'kakaogetränkepulverlöslich kaba':'cocoa','kat ham magerget':'ham','kekse cantuccini':'cantuccini',
    'jalapeño sauce':'jalapeño sauce','jamaican jerk':'jerk','jelly red':'red_jelly',
    'jogurette maracuja':'passion_fruit_yoghurt_chocolate','selleriesalat julienne':'salad',
    'juniper belly meat':'pork_belly','juniper berries seasoning mix':'juniper berry'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^r',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['radish garnish',
#  'radishes',
#  'rama cremefine',
#  'rama culinesse',
#  'rama cullinesse',
#  'ramacreme fine',
#  'ramaculinesse',
#  'rapeseed oil',
#  'rapeseed oil with butter flavor',
#  'rapunzel lettuce',
#  'raselhanoutgewürzmischung morocco',
#  'raspberries',
#  'raspberry chilli bagclr devil tea',
#  'raspberry fruit juice',
#  'raspberry jam schwartauextr',
#  'raspberry_götterspeise',
#  'raw milk cheese resin roller',
#  'red apple',
#  'red apples',
#  'red beans',
#  'red beet sprouts',
#  'red berries',
#  'red berry juice',
#  'red berry salt',
#  'red cabbage',
#  'red cake icing powder',
#  'red cake topping',
#  'red caviar',
#  'red chard',
#  'red cherries',
#  'red chili',
#  'red chilli powder',
#  'red chillies',
#  'red clover',
#  'red currant jam',
#  'red currants',
#  'red decorative font',
#  'red fruit jelly',
#  'red fruit sauce',
#  'red gooseberries',
#  'red grape jelly',
#  'red groats powder',
#  'red jam',
#  'red juice',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='rye shot']
# Out:
#      ingredient_name     parse_ingr   en_ingr
# 1442   roggen schrot  roggen schrot  rye shot

# %%
whole_change_dict={'roggenbrötchen':'rye_bread','rye whole wheat flour':'rye_flour','rübli marzipan':'marzipan',
'rougette landkäse':'cheese','rumaroma weisses':'rum_aroma','rumpsteak charoluxe':'beef',
'rose sheep paprika powder':'paprika_powder','rote paparika':'bell_pepper','rum backaroma':'rum_aroma',
'rosas chiliknoblauchbutter':'chili_garlic_butter','rose flour wienergriess':'wheat',
'rolled suckling pig back':'pork','root vegetables leek celery parsley root':'leek,celery,parsley',
'roll':'bread','roll of yesterday':'bread','romanosalat salatherz':'cabbage',
'rice indian':'rice','rind filet steak':'beef','rind steak':'beef','rinderhackfleisch tappies':'beef',
'rhenish cutting beans':'sour_bean','rhubarb fruit juice':'rhubarb_juice','ribeye steak':'beef',
'raw milk cheese resin roller':'cheese','regensburg sausage':'sausage',
'himbeerchiliteebeutelklr teufeltee':'raspberry_chili_tea','resin roller':'hazer_cheese',
'quimiq vanilla':'qimiq vanilla','raselhanoutgewürzmischung morocco':'ras_el_hanout',
'quesomanchego cheese':'queso_manchego_cheese','quimick vanilla':'qimiq vanilla',
'pizza cheese':'cheese','pizza margherita':'margherita_pizza','pizza-ready mid-tomato sauce':'pizza_sauce',
'puddingpulver mitsahnegeschmack':'cream_pudding','puddingpulver mitvanillegeschmack':'vanilla_pudding',
'puddingcreme backfest':'cream_pudding','puddingpulver mandel':'almond_pudding',
'pudding powder vanilla':'vanilla_pudding',
'pudding powder cream':'cream_pudding','pudding powder strawberry':'strawberry_pudding',
'paprika rotgrün':'bell_pepper','pudding powder chocolate':'chocolate_pudding_powder',
'papika powder':'paprika_powder','paprika candle':'paprika_powder','paprika rotgelborange':'bell_pepper',
'pak choi':'pakchoi','palatinate liver sausage':'sausage','panko flour asian breading flour':'bread_crumbs',
'paellagewürz mitkurkuma':'paella_spice','paidol wheat semolina':'wheat',
'nutty oil':'peanut_oil','obsttortenboden biscuits':'biscuit_cake_base',
'oil clarified butter':'butter','oil mazola':'rapeseed_oil','oktoberfestbier zbpaulaner':'beer',
'orange fruit':'orange','orange fruit juice':'orange_juice','orange fruit nectar':'orange_juice', 
'orange juice with pulp':'orange','orange paprika':'bell_pepper','orange yellow red':'bell_pepper',
'orangenlikör cointreau':'orange_liqueur','orangenlimonade fanta':'fanta_drink','oranges oranges':'orange',
'oroll roast':'pork','other boiled sausages, bratwurst':'boiled_sausages','oven cheese spicy':'cheese',
'oven fries':'french_fries'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^s',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['s maggikraut',
#  'saddlery',
#  'saffron powder',
#  'saffron spice',
#  'sage spice',
#  'sahne meerettich',
#  'sahnekäse milkana',
#  'sahnepudding powder',
#  'sahneschmelzkäse',
#  'sahneschmelzkäse mitkräutern',
#  'salad',
#  'salad coronation chili herbs',
#  'salad cucumber',
#  'salad dressing italian herbs',
#  'salad mix',
#  'salad spice gartenkreuter',
#  'salami',
#  'salami poultry',
#  'salanaise salatcreme',
#  'salatmajonaise balance',
#  'salatsauce',
#  'salatsauce joghurtkräuter',
#  'salsa sauce',
#  'salsa sauce hot',
#  'salt',
#  'salt chives',
#  'salt fiery fruity',
#  'salt nutmeg',
#  'salt pepper',
#  'salt pepper mill',
#  'salt pepper oregano',
#  'salt pepper white',
#  'salt peppercheyenne pepper',
#  'salt sugar',
#  'salt water',
#  'salt wild garlic salt',
#  'salted dill cucumber lactic sour',
#  'salted popcorn',
#  'sambali liqueur kaufland',
#  'san apart',
#  'sandwich ementalerkäse',
#  'sandwich toast',
#  'sarawakpfeffer',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='sweet chestnut cream']
# Out:
#         ingredient_name         parse_ingr               en_ingr
# 2695  maronencreme süss  maronencreme süss  sweet chestnut cream

# %%
whole_change_dict={'süssliche chillies':'chili','süssrhababerkonfitür':'rhubarb_jam','süsssaure asiasosse':'asian_sauce',
'swiss hard cheese':'swiss_cheese','syrup waldmeister':'galium_odoratum_syrup','süsskirsche food':'cherry',
'sweet paprika':'sweet_paprika','sweet paprika powder':'sweet_paprika','sweetsourchillisoucesüsssaure asiasosse':'asian_sauce',
'sweet potato starch':'starch','sweet peppers':'bell_pepper','sweet mini peppers':'bell_pepper',
'sweet apple':'apple','sweet apples':'apple','sweet butter':'butter','sweet potato':'sweet_potato',
'sweet almonds':'almond','sweet and sour sauceasia department':'sweet_sour_chili_sauce',
'sumak essigbaumgewürz':'sumak_spice','sun kiss spice blossom mix':'Sonnenkuss_spice','swam ok':'pork','swedish oat biscuits with chocolate':'biscuit',
'sugar salt':'sugar,salt','sugar sprinkles':'sugar','sugar water':'sugar','sugar white':'sugar',
'sugar coriander':'sugar,coriander','sugar honey':'honey','sugar kandis':'sugar','sugar powder':'sugar',
'stufea':'cream_cheese','suesse sahne':'cream','sugar brown':'sugar','sugar cinnamon':'sugar,cinnamon',
'strawberry jelly sugar':'strawberry_jelly','strawberry limes':'strawberry','streaky rumpstick':'Kasseler','strudel dough':'Gezogener_strudelteig',
'stewed cucumber odsalat cucumber':'cucumber','stilt':'Eisbein','straw around':'rum','strawberry bar syrup':'strawberry_syrup',
'spring onions with green':'spring onion','spritz pastry batter':'cracker','ssab':'baharat','steak':'beef',
'spiral pasta durum wheat':'spiral_pasta','split peas green':'split pea','spring onion spring onions':'spring_onion',
'spicy vegeta':'vegeta','spicy vegetable broth':'vegetable broth','spiral noodles':'spiral_pasta',
'spicy paprika pulp':'chili','spicy provolone':'provolone_cheese','spicy remulade':'Würzige_Remoulade','spicy sangrita':'Sangria_picante',
'spicy goat cheese zbcharolais':'spicy_goat_cheese','spicy herb salad sauce':'spicy_herb_salad_sauce',
'spices powder':'spice','spices thyme':'thyme','spicy breadcrumbs':'bread_crumbs','spicy brotgewürz':'spice',
'spices chilli':'chili','spices herbs':'herb_spice','spices oregano':'oregano','spices paprika':'paprika',
'spice paste paprika':'paprika_paste','spice powder asian shop':'asian_spice','spice singapore':'singapore_spice',
'spice cinnamon':'cinnamon','spice grains pimento':'pimento','spice paste italian':'italian_spice',
'spanish paprika sausage':'sausage','spare ribs':'beef','spelled flour':'wheat','spice christmas mix':'spice',
'soy milk chocolate':'chocolate_soy_milk','soya stucke':'soybean','soyananda cream cheese with pepper':'pepper_cream_cheese',
'sour creme':'sour_creme','sour fries':'gummi','south tyrolean bacon':'bacon','south tyrolean ham':'ham',
'souce hollondaise':'hollandaise_sauce','soup beef':'beef','sour apples':'apple','sour confectionery':'sour_jam',
'sossen pulverized vanillegeschmack':'vanilla_sauce','sossenpulver vanilla':'vanilla_sauce','sossenpulver vanillie':'vanilla_sauce',
'sore throat':'pork','sosse hell':'hell_sauce','sosse hollandaise':'hollandaise_sauce','sossen pulverized schoko':'chocolate_sauce',
'soiree props':'sour_cream','solber meat salted meat':'meat','soloknolle knobiart':'Soloknolle_knobiart',
'sliced gyros art':'pork','small rabbit fromi':'cheese','smear cheese herbs':'herb_cheese','snack paprika':'paprika',
'silesian cucumber bites':'gherkin','silesian white sausages':'sausage',
'shittake mushrooms':'shiitake','shoulder piece of the pig':'pork','shrimps crabs':'crab','shrimps crayfish tails':'shrimp',
'schaschlik spiesse':'Schaschlik','shish kebab spice ketchup':'schaschlik_spice_ketchup',
'sea fish sea bass':'sea bass','sherry chamomile':'sherry','shimeji buchenpilze':'mushroom',
'sea buckthorn jelly':'sanddorn_jelly','sellerieknolle':'celery','selleriesalat sauerkonserve':'vegetable',
'schwnetz net':'pork','sesame beer':'sesame_oil','sea buckthorn balsamic':'balsamic_vinegar',
'schwartau orangeback':'orange_aroma','schwfilet':'pork','schwhack seasoned':'pork','schwhaxen':'pork',
'schupfnudeln':'pasta','schw goulash':'pork','schw schnitzel':'pork','schw steaks':'pork',
'schnitzel naturally fried':'pork','schnitzel on the back':'pork','schuhbeck&#39;s sex spice':'sex spice',
'schaschliksosse derflasche':'schaschlik_sauce','schmelzkäse mexikana':'cheese','schnitzel all over':'meat',
'scampisalz':'shrimp_salt','scene':'cream','sch truffle ham':'ham','schaschlikgewürz ketchuppikant':'spice_ketchup',
'sauerkirsche ensteint':'sour_cherry','saure sahe':'sour_cream','savory spice':'savory',
'sandwich toast':'bread','sarawakpfeffer':'pepper','sauce gourmet sauce':'sauce_spice','sauce powder dutch style':'dutch_sauce',
'salted popcorn':'popcorn','sambali liqueur kaufland':'sambalita_liqueur','sandwich ementalerkäse':'emmental_cheese',
'salt sugar':'salt,sugar','salt water':'salt','salt wild garlic salt':'salt,garlic','salted dill cucumber lactic sour':'gherkin',
'salt pepper oregano':'salt,pepper,oregano','salt pepper white':'salt,pepper','salt peppercheyenne pepper':'salt,pepper,cayenne_pepper',
'salt nutmeg':'salt,nutmeg','salt pepper':'salt,pepper','salt pepper mill':'salt,pepper',
'salanaise salatcreme':'salad_cream','salatmajonaise balance':'mayonnaise','salz schnittlauch':'salt,garlic',
'salad mix':'vegetable','salad spice gartenkreuter':'spice,herb','salami poultry':'salami',
'salad coronation chili herbs':'Salat_krönung','salad cucumber':'cucumber','salad dressing italian herbs':'italian_herbs',
'sahnepudding powder':'cream_pudding_powder','sahneschmelzkäse':'cream_cheese','sahneschmelzkäse mitkräutern':'herb_cream_cheese',
's maggikraut':'lovage','saddlery':'celery','sahne meerettich':'horseradish_cream','sahnekäse milkana':'cream_chees'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
en_ingrs=list(set(two_ingr['en_ingr'].values.tolist()))
len(en_ingrs)
# Out:
# 2207

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^w',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['wachtelbohn borlottibohngemischt',
#  'wafer',
#  'wafer rolls with chocolate',
#  'waffle cup with chocolate coating inside',
#  'wagenrädernudeln wheels',
#  'waldpilze hattemaronen',
#  'waldpilze mix',
#  'walnut ginger',
#  'walnut nougat speaks',
#  'walnut panzerotti',
#  'walnut small goods',
#  'walnuts',
#  'wammerl',
#  'wan tanreisteignudel',
#  'wasabi paste',
#  'wash paprika',
#  'wash parsley smooth fresh',
#  'water',
#  'water garlic',
#  'water salt',
#  'water vegetable bouillon',
#  'watercress',
#  'we had a trap',
#  'weinbrand rum',
#  'weintraube weiss',
#  'weissbrot',
#  'weissbrot giabatta',
#  'weissbrotbackmischung mithefe',
#  'weisse cuvertüre',
#  'weisser wermuth',
#  'weisswurst munich',
#  'weizenbier obergärig',
#  'well in neuwulmstorf',
#  'western steak spice',
#  'wfl yeast',
#  'what beans',
#  'wheat',
#  'wheat flour',
#  'wheat grain',
#  'wheat meal',
#  'wheat semolina',
#  'wheat wraps',
#  'wheel pasta tricolore',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='vogelbeere eberesche']
# Out:
#            ingredient_name            parse_ingr               en_ingr
# 1416  vogelbeere eberesche  vogelbeere eberesche  vogelbeere eberesche

# %%
whole_change_dict={'vinegar raspberry':'raspberry_vinegar','vogelbeere eberesche':'rowan',
'vienna floors':'cake','viennese biscuit floor':'cake','vinaigrette salt':'vinaigrette','vinegar balsamic':'balsamic_vinegar',
'veget':'vegetable','veget broth':'vegetable_broth','vegeta vegetable broth':'vegeta','vienna floor':'cake',
'vanillinzucker buorbon':'vanilla_sugar','vannille mark':'vanilla_sugar','vd nut':'meat',
'vanilla salt salt':'vanilla_salt','vanilla soyjoghurt':'vanilla_yoghurt','vanillin zucker':'vanilla_sugar',
'vanilla kochpuddingpulver':'vanilla pudding','vanilla paradiescreme':'vanilla_cream','vanilla sahnepudding':'vanilla_cream_pudding',
'vanile sugar':'vanilla','vanilla back':'vanilla_aroma','vanilla back aroma':'vanilla_aroma',
'tuscan bacon':'bacon','tzaziki quark':'quark','universal seasoning mix':'spice',
'tupperhappy snack':'snack','turmeric powder':'turmeric','turnip oil for dough binding':'turnip_oil',
'tostbrot entrindet':'bread','travel wild trip':'rice','trip':'rice','tube pasta tortigloni':'tortiglioni_pasta',
'tortilla fladen':'corn_tortilla','tortilla wraps':'corn_tortilla','tortillas of wheat flour':'corn_tortilla',
'tooastbrot entrindet':'bread','tortiglioni tube pasta':'tortiglioni_pasta','tortill':'corn_tortilla',
'tomatoes hot':'tomato','tomatoes red':'tomato','tomatoes with basil':'tomato,basil','tomatoes without spices':'tomato',
'tomaten strauchtomate':'tomato','tomatoalgusto basilikum':'Tomato_al_gusto_Basilikum','tomatoes':'tomato',
'tomato happens':'Toamto_passiert','tomato pepper':'bell_pepper','tomato seasoning salt':'toamto_spice_salt',
'tomatenstückchen':'toamto','tomato chilli bread spread':'tomato,chilli,bread','tomato egg bush':'tomato',
'tomatensosse angry':'toamto_sauce','tomatensosse basilikumflasche':'toamto_sauce','tomatensosse ntomaten':'toamto_sauce',
'toast cheese':'cheese','tofu spice demreformhaus':'tofu_spice','tomatenletscho sauce':'toamto_sauce','tomaten':'tomato',
'thommy yogurt cream':'cream_yoghurt','ticino grappa':'grappa ticinese','toast':'bread',
'teriyakisauce':'teriyaki_sauce','thaichili pulver':'chili_powder','thaicurry red':'curry','the lemon effervescent':'lemon_aroma',
'tasmanischer bergpfeffer':'pepper','tellicherry pfeffer':'pepper','tempo beans white':'Tempobohnen',
'tabasco green':'tabasco','tabascosauce':'tabasco','taco chips':'corn_tortilla','taco chips chili':'corn_tortilla',
'tafelmeerrettich demgläschen':'horseradish','tagiatelli':'tagliatelle_pasta','tagliatelle':'tagliatelle_pasta',
'tagliatelle green':'tagliatelle_pasta','tagliolini':'taglierini_pasta','tasmanian pepper oil':'pepper_oil'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
# two_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_004.csv')

# %%
two_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_004.csv',index_col=0)
two_ingr.shape
# Out:
# (3189, 3)

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^w',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['wachtelbohn borlottibohngemischt',
#  'wafer',
#  'wafer rolls with chocolate',
#  'waffle cup with chocolate coating inside',
#  'wagenrädernudeln wheels',
#  'waldpilze hattemaronen',
#  'waldpilze mix',
#  'walnut ginger',
#  'walnut nougat speaks',
#  'walnut panzerotti',
#  'walnut small goods',
#  'walnuts',
#  'wammerl',
#  'wan tanreisteignudel',
#  'wasabi paste',
#  'wash paprika',
#  'wash parsley smooth fresh',
#  'water',
#  'water garlic',
#  'water salt',
#  'water vegetable bouillon',
#  'watercress',
#  'we had a trap',
#  'weinbrand rum',
#  'weintraube weiss',
#  'weissbrot',
#  'weissbrot giabatta',
#  'weissbrotbackmischung mithefe',
#  'weisse cuvertüre',
#  'weisser wermuth',
#  'weisswurst munich',
#  'weizenbier obergärig',
#  'well in neuwulmstorf',
#  'western steak spice',
#  'wfl yeast',
#  'what beans',
#  'wheat',
#  'wheat flour',
#  'wheat grain',
#  'wheat meal',
#  'wheat semolina',
#  'wheat wraps',
#  'wheel pasta tricolore',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='work naturreinwildpreiselbeeren']
# Out:
#                       ingredient_name                        parse_ingr  \
# 241  darbo naturreinwildpreiselbeeren  darbo naturreinwildpreiselbeeren
#
#                              en_ingr
# 241  work naturreinwildpreiselbeeren

# %%
whole_change_dict={'worchester sosse':'worcestershire_sauce','worchestershire sauce':'worcestershire_sauce','darbo naturreinwildpreiselbeeren':'berry_jelly',
'with mediterranean herbs':'mediterranean_herb','worcestersosse n':'worcestershire_sauce','worchester sauce':'worcestershire_sauce',
'winzersekt weiss':'wine','winzerwurst treberwurst':'sausage','wiser around':'rum','with beechwood aroma':'oak_aroma',
'wine white':'white_wine','wine-spicy vinegar':'vinegar','wintercappuccinopulver typröstmandel':'cappuccino',
'wilde raukesalat':'Kraukesalat','wildreis':'rice','williams christ':'pear','wine rose':'rose_wine',
'wild garlic salt angelinaskb':'garlic','wild thyme':'thyme','wild trip mixlangkorn':'rice',
'wiener tortenboden':'cake_base','wihte wheaties':'white_wheaties','wild garlic igloo':'garlic',
'wholemeal goods with fiber':'grain,ballaststoffen','wiener griessler':'wheat','wiener sausages':'sausage',
'whole wheat spelled flour':'wheat','wholegrain oat':'oat','wholegrain oat flakes':'oat','wholemeal biscuits':'biscuit',
'whole milk chocolate':'milk_chocolate','whole wheat cookies':'cookie','whole wheat flour':'wheat',
'whiter smoky':'vinegar','whole grain rusks':'wheat_bread','whole grain toast':'wheat_bread',
'white wine cabinet':'riesling','white wine riesling':'riesling','white wine vinegar':'vinegar','white wine water':'white wine',
'white turnips':'turnip','white vermouth':'vermouth','white vinegar':'vinegar','white watery':'vinegar',
'white stages':'navy_bean','white sugar':'sugar','white truffle oil':'truffle_oil','white turnip':'turnip',
'white ribbon noodles':'pasta','white rum':'rum','white sauce':'white_sauce','white sausages munich':'sausage',
'white onion':'onion','white onions':'onion','white pepper':'pepper','white radi':'radish','white radish':'radish',
'white fish':'fish','white fondant':'fondant','white grapes':'grape','white mushroom':'mushroom',
'white cocoa liqueur':'cocoa_liqueur','white cocoa powder':'cocoa','white covature':'chocolate',
'white candy':'candy','white canelloni fresh':' canelloni','white champingnons':'mushroom',
'white cake icing':'cake_icing','white cake icing lemon':'lemon_cake_icing','white cake topping':'cake_topping',
'white balsamic':'balsamic_vinegar','white basil vinegar':'balsamic_vinegar','white cabbage':'cabbage',
'wachtelbohn borlottibohngemischt':'pinto_bean','wafer rolls with chocolate':'chocolate_wafer',
'waffle cup with chocolate coating inside':'chocolate_wafer','wagenrädernudeln wheels':'pasta',
'waldpilze hattemaronen':'mushroom','waldpilze mix':'mushroom','walnut nougat speaks':'walnut_nougat_taler',
'walnut small goods':'walnut_snack','wammerl':'roasted_beef','wan tanreisteignudel':'wonton_dough',
'water garlic':'garlic','water salt':'salt','water vegetable bouillon':'vegetable_broth',
'we had a trap':'farfalle_pasta','weinbrand rum':'brandy','weintraube weiss':'grape',
'weissbrot':'white_bread','weissbrot giabatta':'white_bread','weissbrotbackmischung mithefe':'white_bread',
'weisse cuvertüre':'chocolate','weisser wermuth':'weisse','weizenbier obergärig':'beer',
'what beans':'navy_bean','wheat flour':'wheat','wheat grain':'wheat','wheat meal':'wheat','wheat semolina':'semolina',
'wheel pasta tricolore':'pasta','whey proteinpulver':'proteian_powder'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^z',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['zartbitterschokolade mitchili',
#  'zbparadies vanilla cream',
#  'zbwiener griessler',
#  'zebröselte biskuits',
#  'zuckermelone charentais']

# %%
two_ingr[two_ingr['en_ingr']=='zuckermelone charentais']
# Out:
#               ingredient_name               parse_ingr  \
# 1001  zuckermelone charentais  zuckermelone charentais
#
#                       en_ingr
# 1001  zuckermelone charentais

# %%
whole_change_dict={'zbwiener griessler':'wheat','zebröselte biskuits':'biskuit','zuckermelone charentais':'melon',
'zartbitterschokolade mitchili':'chili_chocolate','zbparadies vanilla cream':'vanilla_cream',
'yam root powder':'yam','yeast dough garant':'yeast,wheat','yellow beets':'beet','yellow carrots':'carrot',
'yellow mustard seeds':'mustard','yellow paparika':'bell_pepper','yellow peppers':'bell_pepper',
'yellow plums':'plum','yellow turnip':'turnip','yogurette lime':'lime_yogurette','yogurette strawberry':'strawberry_yogurette',
'yogurt coffee':'coffee_yoghurt','yogurt herbs':'herb_yoghurt','yogurt peach maracuja':'maracuja_peach_yoghurt',
'yogurt tzatziki':'tzatziki_yoghurt','yogurt vanilla':'vanilla_yoghurt'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
contain_change_dict={'whiskey':'whiskey','white bean':'navy_bean','white beets':'beet','white bread':'white bread','white chocolate':'white_chocolate',
'vanilla sugar':'vanilla_sugar','veal':'veal','vegetable broth':'vegetable_broth','whipped cream':'cream',
'tomato paste':'tomato_paste','vanilla pudding':'vanilla_pudding','vanilla sauce':'vanilla_sauce',
'tart apple':'apple','tart apples':'apple','thaikgarlauch dembast basket':'garlice','ketchup':'ketchup',
'sparerib':'beef','speck':'bacon','sugar flowers':'sugar','tandori paste':'tandoori_spice','tandorri powder':'tandoori_spice',
'schwschnitzel':'pork','schwschulter':'pork','sossenbinder':'sauce_thickener','spagettini':'pasta',
'salatsauce':'salad_sauce','salsa sauce':'salsa_sauce','sauce binder':'sauce_thickener','savoy':'savoy',
'harissa':'harissa','kasseler':'smoked_pork','reisnudeln':'rice_noodle','lamb':'lamm','lamm':'lamb',
'schwfleisch':'pork','wild boar':'pork','margarine':'margarine','martini':'martini','maultaschen':'Maultasche',
'oregano spice':'oregano','paprika sauce':'paprika_sauce','paprika würzpaste':'paprika_paste',
'risottoreis':'risotto_rice','rosemary':'rosemary','saffron':'saffron'}

# %%
def replace_ingr(k,v,ingredient):
    if re.findall(k,ingredient):
        return v
    else:
        return ingredient

# %%
for k,v in contain_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
delete_words=['culinesse','iger','wash','wfl','wildfang',
'spiced','tender','thai','thawed','tiko','firm','seiden','concassee','tricolor','tropical','turkish',
'broken','happens','vonriemerschmid','substitute','sugary','summer','sun','swabian','sweetened','sweet'
'shrub','sized','smoke','smooth','ntsteint','content','soyananda','span','speculoos','bed','stable',
'rocket','roma','roten','blond','brown','knows','sarotti','schwarfes','scruffy','shot','extract',
'pink','pointy','content','garnish','rapunzel','schwartauextr','red-yellow-green','ripe','reiskugeln',
'mixed','approx','mondamin','mountain','bavarian','hearty','of','sun','oreo','mix','philadelpia','philadephia',
'meggle','meitai','microwave','mikado','sticks','milan','vonmüller','milkana','leaves','model',
'markr','maroka','dessertwein','stick','mashed','may','meadow','stock','mecklenburger','medallion','original',
'köfke','little','leavened','fresh','light','lightpur','lion','loose','dictate','maggi','malibu',
'king','kiri','zbvonschladerer','kissupfen','klen','chinalauch','kokosette','kotányi','kremser','köstritzer',
'poland','hamburger','hard','harzer','kernels','hearty','heavenly','heavy','matjesart','homemade','hot',
'entrahmte','es of','essence','farmer','fine','fresh','dertüte','mix','fruity','mono','genoese','tuber','zerstampt',
'glazed','bears','good','hungarian','gourmet','tube','gray','minis','seasonal','weeping','grilled']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_words(x))

# %%
delete_parts=['mix juice','mix mexico','smooth fresh','late harvest',
'square of','steamed with','light brown','sun ripened','sweet and sour','sweet fresh','turnip-fresh',
'soft-boiling','ready to','from the door glue trade','spicy, reduced-fat hard','sprigs of','curled up',
'sliced hunting sausage','hattewiener','scoops of','shish kebab skewers wood','shot of','small fresh',
'lactose free','with butter flavor','roma vine','high percentage','fiery fruity','or ham leftovers',
'medeiterran stewed','base powder','minute steak','pickles pickled','to grease','foam herb ricottegnocchi',
'extra fine','fresh green','fresh alternative','from the','bulb asian','roll cafingerdick','harz red',
'naturally hot','knight sport','new shape of','raw mass','etc mixed','decor “fruit mix','raw mass']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_part(part,x))

# %%
two_ingr
# Out:
#               ingredient_name               parse_ingr  \
# 0               pommes frites            pommes frites
# 1          walnuss panzerotti       walnuss panzerotti
# 2       granatapfel balsamico    granatapfel balsamico
# 3        schwlende geräuchert     schwlende geräuchert
# 4          pökelwaren eisbein       pökelwaren eisbein
# ...                       ...                      ...
# 3184      paprika rotgelbgrün      paprika rotgelbgrün
# 3185  brunch paprikapepperoni  brunch paprikapepperoni
# 3186    asiatisches wokgewürz    asiatisches wokgewürz
# 3187           kle vomschwein           kle vomschwein
# 3188           kalb schnitzel           kalb schnitzel
#
#                        en_ingr
# 0                 french fries
# 1            walnut panzerotti
# 2         pomegranate balsamic
# 3                  smoked_pork
# 4                   cured_pork
# ...                        ...
# 3184                   paprika
# 3185  brunch paprika pepperoni
# ...

# %%
whole_delete=['white decorative beads','wood chips','wooden stick toothpick','yellow sugar pearls',
'sternaniszur suit','sugar pearls','sweet sour','to decorate','to hurry up','well in neuwulmstorf',
'silicone heart','silver sugar pearls','skewers of wood','specialty of our area','sprinkles',
'minis','minni','red decorative font','rote u','rosenwasser derapotheke','rote back','shower powder cushions',
'event sauce binder','flower fabric','fond brown','franconian silk clover','green allro','green color powder',
'grünohne st','hollow spheres white','johannamaierösterreich','over night soaked','little','made red',
'mason jars with contents','max','merlin lockets','mitküchenschnur born','monte gesa','mortar wood',
'muffin cases paper','outside around','over night soaked','shish kebab skewers']

# %%
two_ingr=two_ingr[~two_ingr['en_ingr'].isin(whole_delete)]

# %%
two_ingr.dropna(inplace=True)
two_ingr=two_ingr[two_ingr['en_ingr']!='']
two_ingr['en_ingr']=two_ingr['en_ingr'].str.strip()
two_ingr.reset_index(drop=True,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
two_ingr.shape
# Out:
# (3149, 3)

# %%
en_ingrs=list(set(two_ingr['en_ingr'].values.tolist()))
len(en_ingrs)
# Out:
# 1536

# %%
en_ingrs.sort()
en_ingrs
# Out:
# ['Aranca_Aprikose_Maracuja',
#  'Aranca_creme_lemon',
#  'Bernaise_sauce',
#  'Biskin spezial',
#  'Bombolone',
#  'Eisbein',
#  'Gezogener_strudelteig',
#  'Glukosesirup',
#  'Grünkern',
#  'Kasseler',
#  'Kraukesalat',
#  'Maultasche',
#  'Mon_Cherie',
#  'Nordhäuser_Doppelkorn',
#  'Pom_Poms',
#  'Rösti',
#  'Salat_krönung',
#  'Sangria_picante',
#  'Sauerkaut',
#  'Soloknolle_knobiart',
#  'Sonnenkuss_spice',
#  'Tempobohnen',
#  'Toamto_passiert',
#  'Tomato_al_gusto_Basilikum',
#  'Würzige_Remoulade',
#  'Zigeunersauce',
#  'a cumin',
#  'ace saft',
#  'acid lemon',
#  'air ham',
#  'ajwain',
#  'alarrabiat',
#  'almond',
#  'almond butter',
#  'almond_aroma',
#  'almond_pudding',
#  'almonds',
#  'alternative vegetable',
#  'amarena cherry liqueur',
#  'amarettini mandelkekse',
#  'anis',
#  'apfelschorle',
#  'apollinaris new',
#  'apple',
#  'apple pie spice',
#  'apple red',
#  'apple sauce',
#  'apple sth',
#  'apple_cider',
#  'apple_cider,canola_oil',
#  'apple_jelly',
# ...

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^c',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['cabanossi sausages',
#  'cabbage',
#  'cafe latte',
#  'cafe oriental',
#  'cajun spice',
#  'cake',
#  'cake base biscuit',
#  'cake base bright',
#  'cake base chocolate',
#  'cake batter',
#  'cake cream powder vanilla',
#  'cake cream strawberry',
#  'cake cream vanilla',
#  'cake glaze lemon',
#  'cake icing',
#  'cake jelly red',
#  'cake viennese mass',
#  'cake_base',
#  'cake_icing',
#  'cake_topping',
#  'calamansi balsamessig',
#  'caliston pepper',
#  'calms',
#  'camembert geramontcremigwürzig',
#  'camembert pepperoni',
#  'camembert_cheese',
#  'candy',
#  'candy sugar',
#  'candy sugar white',
#  'cane sugar',
#  'canelloni',
#  'cannelloni nudelröhrchen',
#  'cantuccini',
#  'caper',
#  'caper anchovies',
#  'cappuccino',
#  'cappuccino powder vanilla',
#  'capri drink powder orange',
#  'caramb',
#  'caramel coffee',
#  'caramel dessert sauce',
#  'caramel syrup',
#  'caramel wore',
#  'caramel_ice_cream',
#  'caramel_powder',
#  'caramelized nuts',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='cut salad in own']
# Out:
#                  ingredient_name                  parse_ingr           en_ingr
# 1803  schnittsalat eigenemgarten  schnittsalat eigenemgarten  cut salad in own

# %%
two_ingr['en_ingr'][two_ingr['en_ingr']=='schw']='pork'
two_ingr['en_ingr'][two_ingr['en_ingr']=='melange noir']='Melange_noir'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:1020: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
whole_change_dict={'cut salad in own':'vegetable',
'curcacao blue':'curacao blue','currant black':'black_currant','currant red':'red_currant','currants red':'red_currant',
'cucumber relish':'gherkin','cucumber vegetable juice':'gherkin','cucumber water':'gherkin','cucumbers green':'cucumber',
'croissant noodle':'pasta','croissant noodles':'pasta','crémant chocolate':'chocolate',
'cremé':'cream','crescenza bzwstracchinokäse':'crescenza_cheese','crisp chocolate white':'chocolate',
'creme fraich':'creme_fraiche','creme fráiche':'creme_fraiche','cremefine vanilla':'vanilla_cremefine',
'cream_pudding_powder':'cream_pudding','creamy cheese':'cheese','creamy cheese':'cream',
'cream layer cheese':'cheese','cream pie cream':'cream','cream spread herbs':'herb_cream','cream_chees':'cream_cheese',
'cream dessert strawberry':'strawberry_cream','cream herbs':'cream,herb','cream horseradish dertube':'horseradish_cream',
'cream cheese with herbs':'herb_cream_cheese','cream cheese with white herbs':'herb_cream_cheese',
'cream cheese mediterranean herbs':'herb_cream_cheese','cream cheese tomato':'tomato_cream_cheese',
'cream cheese herbs':'herb_cream_cheese','cream cheese horseradish':'horseradish_cream_cheese',
'cream cheese garlic':'garlic_cream_cheese','cream cheese herbal philadelphia':'herb_cream_cheese',
'corn flour wheat flour':'corn flour,wheat','corn grains':'corn','corners cheese':'cheese',
'coffee with milk':'coffee,milk','cookies biscuits':'cookie','cookies with chocolate chips':'cookie,chocolate chip',
'cocktailwürstchen':'cocktail_sausage','cocoa glaze':'cocoa icing','coffee chocolate beans':'chocolate_coffee',
'citrus zest lemon':'lemon_zest','cloves juniper berries':'juniper berries','cocktail hugo':'cocktail',
'citronat demreformhaus':'succade','citrus pulp zest lemon':'citrus,lemon_zest','citrus senfsosse':'citrus_senf_sauce',
'cinnamon cream topping':'cinnamon_cream','cinnamon powder':'cinnamon','citroback orange':'orange_citroback','citro back':'citroback',
'chorizo paprika salami':'chorizo_sausage','cinnamon blossom spice':'cinnamon_spice',
'chocolate viennese soil':'cake_base','chocolate-coated espresso beans':'chocolate_espress',
'chocolate residue with cappuccino':'chocolate_cappuccino','chocolate x whole milk x nut':'chocolate,milk,nut','chocolate syrup white':'chocolate_syrup',
'chocolate eggs from all me':'chocolate','chocolate glaze':'chocolate icing','chocolate mass':'chocolate',
'chocko kusse':'chocolate','choco cookies':'cookie','choco crossie':'chocolate_snack','chocolate almond pudding powder':'chocolate_almond_pudding',
'chinese vegetables':'vegetable','chinese vinegar':'vinegar','chives parsley':'chives,parsley',
'chinese noodle sauce from zwergenwiese':'chinese_noodle_sauce','chinese noodles':'noodle','chinese sprout vegetables':'soybean_sprout',
'chinese egg noodles':'egg_noodle','chinese garlic':'garlic','chinese mushrooms':'mushroom',
'chin garlic':'garlic','chin huajiao':'sichuan_pepper','chinese':'chinese_sweet_sour_sauce',
'chilli salt':'chili_salt','chillibohnen hell':'chili_bean','chillies red':'chili','chin':'chinese_spice',
'chilli':'chili','chilli green':'chili','chilli honey':'chili_honey','chilli rot':'chili',
'chili rot':'chili','chilibohnen':'chili_bean','chilitomatensosse chilitomatensosse':'chili_tomato_sauce',
'chili burp':'pimento','chili green':'chili','chili peppers':'chili','chili rosmarinsalz':'chili_rosemary_salz',
'chicken meat':'chicken','chicken pork with saddle':'chicken','chickens':'chicken','chicoree rot':'chicory',
'chicken beef':'chicken_beef_broth','chicken bouillon':'chicken_broth','chicken broth powder':'chicken_broth',
'chervil tarragon':'chervil,tarragon','chester rahmstufeschmelzkäse':'chester cheese',
'cherry flavor':'cherry_aroma','cherry juice cherry':'cherry_juice','cherry tommaten':'cherry_tomato',
'cherries sour':'sour_cherry','cherry brandy':'brandy','cherry date tomatoes':'cherry_tomato',
'cheese milk':'milk','cheese mmentaler':'emmental_cheese','cheese mushrooms':'mushroom_cheese','cheese paprika':'paprika_cheese',
'cheese garlic flavor':'garlic_cheese','cheese goude':'gouda_cheese','cheese herbs':'herb_cheese',
'cheese cream flavor':'cream_cheese','cheese creme brunch peppers':'pepper_cream_cheese',
'champions':'mushroom','chayenne pfeffer':'cayenne_pepper','chayota milk':'chayote','cheese brunch peppers':'chili_cream_cheese',
'celery yellow beet':'celery,carrot','ch spice':'chinese_spice','chakalakasauce curry':'Chakalaka',
'caramb':'caramba_spice','caramel wore':'caramel','carbonara sosse':'carbonara_sauce','carrot peas':'carrot,pea',
'caper anchovies':'capers,anchovies','cappuccino powder vanilla':'vanilla_cappuccino','capri drink powder orange':'orange_drink',
'cane sugar':'sugar','canelloni':'cannelloni_pasta','cannelloni nudelröhrchen':'cannelloni_pasta',
'calamansi balsamessig':'balsamic_vinegar','caliston pepper':'chili','camembert geramontcremigwürzig':'spice_cheese',
'cake glaze lemon':'lemon_cake_icing','cake jelly red':'red_cake_jelly','cake viennese mass':'cake',
'cake cream powder vanilla':'vanilla_cream','cake cream strawberry':'strawberry_cream','cake cream vanilla':'vanilla_cream',
'cajun spice':'cayenne_spice','cake base biscuit':'biscuit_cake_base','cake base chocolate':'chocolate_cake_base',
'buttermilk kefir':'buttermilk','buttervanille aroma':'butter_vanilla_aroma','beer stark beer':'beer',
'burger rolls with sesame':'sesame_bread','buter pepper':'pepper_butter','butter vanilla':'vanilla_butter',
'buko herbs':'herb_cream_cheese','buko toscana':'toscana_cream_cheese','bun':'bread','buns':'bread',
'bruschett':'Bruschetta','brüh':'broth','buckwheat grain':'buckwheat','buko cheese herbs':'herb_cream_cheese',
'breakfast meat':'meat','broth mediteran':'mediteran_broth','broth powder':'broth','brunch clssic':'brunch classic',
'bread cracker herb taste':'bread','bread roll':'bread','bread spread paprika from brunch':'brunch_paprika',
'braised sausage bratwurst':'sausage','branded butter':'butter','bratwurst':'pork_sausage',
'bolognaise sauce':'bolognese_sauce','boquet garni':'bouquet garni','bourbonvanille aroma':'vanilla_aroma',
'black tea':'black_tea','black whole grain rice':'black_rice','boar ribs':'pork','boar shoulder':'pork',
'black currant nectar':'black_currant_juice','black currants':'black_currant','black garlic':'black_garlic',
'black back steak':'meat','black chops':'pork','black salsify':'pork','black currant liqueur':'black_currant_liqueur',
'biskuit':'biscuit','bitterschokolade mithimbeeren':'chocolate','bitttermandelaroma':'bitter_almond_aroma',
'bear garlic noodles tagliatelle':'bear_garlic_pasta','bel_paese_cheese':'bell_paese_cheese','biscuit base':'biscuit',
'beans green':'french_bean','beans obuschbohnen':'bean','beans red':'red_bean','beans white':'navy_bean',
'balisto wild berry yogurt':'berry yoghurt','basil red':'basil','bbq marinade':'barbecue marinade','bbq sosse':'barbecue_sauce',
'apple red':'apple','apple sth':'apple','apples green':'apple','baking oil lemon':'lemon_oil',
'alarrabiat':'arabic_spice','apollinaris new':'mint_drink','acid lemon':'lemon','apfelschorle':'Apfelschorle',
'aromatic oil rose oil':'rose_oil','arrabia seasoning':'arabic_spice','amarettini mandelkekse':'cookie',
'red beans':'red_bean','red mullet':'red_mullet','red pepper berries':'pepper','red pepper powder':'pepper',
'red pepper spice':'pepper','red peppercorns':'pepper','red peppers':'pepper','red vinegar':'vinegar',
'red watery':'vinegar','alarrabiat':'arabic_spice','asi':'asian_spice','asiasalat glas':'asian_salad'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^h',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['halibut',
#  'ham',
#  'harissa',
#  'hazelnut',
#  'hazelnut brittle',
#  'hazelnut cake glaze',
#  'hazelnut flour',
#  'hazelnut glaze',
#  'hazelnut glaze schwartau',
#  'hazelnut_cappuccino',
#  'hazer_cheese',
#  'hell_sauce',
#  'herb',
#  'herb balance',
#  'herb butter',
#  'herb butter baguette',
#  'herb cheese',
#  'herb salt,wild garlic salt',
#  'herb spaetzle',
#  'herb_cheese',
#  'herb_cheese_bread',
#  'herb_cream',
#  'herb_cream_cheese',
#  'herb_cream_cheese,yoghurt',
#  'herb_creme_fraiche',
#  'herb_creme_legere',
#  'herb_salt_chili',
#  'herb_sausage',
#  'herb_spice',
#  'herb_yoghurt',
#  'herbs',
#  'herbs by buko',
#  'herings',
#  'herring',
#  'hoisin sauce',
#  'hollandaise_sauce',
#  'honey',
#  'honey biscuit cake base',
#  'horse',
#  'horseradish',
#  'horseradish naturally',
#  'horseradish sauce',
#  'horseradish_cream',
#  'horseradish_cream_cheese',
#  'hot_dog',
#  'hot_sauce',
#  'hour']

# %%
two_ingr[two_ingr['en_ingr']=='honey spicy']
# Out:
#      ingredient_name    parse_ingr      en_ingr
# 2607    honig würzig  honig würzig  honey spicy

# %%
two_ingr['en_ingr'][two_ingr['ingredient_name']=='pflaumen konfitüre']='plum_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='brombeere konfitüre']='black_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='zwetschge konfitüre']='plum_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='sauerkirsche konfitüre']='sour_cherry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='erdbeerrhabarber konfitüre']='strawberry_rhubarb_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='preiselbeer konfitüre']='cowberry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='preiselbeere konfitüre']='cowberry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='pfirsich konfitüre']='peach_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='rote konfitüre']='red_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='süssbirnenkonfitüre mitmirabelle']='pear_plum_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='rote marmeladekonfitüre']='red_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='himbeere konfitüre']='raspberry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='pfirsichmaracuja konfitüre']='peach_passion_fruit_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='schwartau aprikosenkonfitüre']='apricot_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='konfitüre sauerkirsch']='sour_cherry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='aprikosen konfitüre']='apricot_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='samtkonfitüre erdbeer']='strawberry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='konfitüre preiselbeer']='cowberry_jam'
two_ingr['en_ingr'][two_ingr['ingredient_name']=='aprikose konfitüre']='apricot_jam'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:1020: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
whole_change_dict={'holländische_sauce':'hollandaise_sauce','honey spicy':'spicy_honey','horse meat':'horse',
'herbs parsley':'parsley','herbs zbbasilikum':'basil','hibiscus curry red':'curry','hirsch steak':'deer',
'herbs chives':'chive','herbs deep':'herb','herbs herbal':'herb','herbs mediterranean':'mediterranean_herb',
'herbal lingitalian':'italian_kräuterlinge','herben cider':'apple_cider','herbs basil':'basil',
'herbal cream cheese zbbresso':'herb_cream_cheese','herbal cream fraiche':'herb_creme_fraiche',
'herbal cream casual':'herb_creme_legere','herbal cream cheese with yogurt':'herb_cream_cheese,yoghurt',
'herbaceous spring herbs':'spring herb','herbal cheese bread from devil':'herb_cheese_bread',
'herb salt chilli':'herb_salt_chili','herb salt wild garlic salt':'herb salt,wild garlic salt',
'herb chanterelles or chanterelles':'chanterelle','herb parsley':'parsley','herb pepper':'pepper',
'griess':'semolina','grünkern whole grain':'grain','hazelnut or almond':'hazelnut','hefeweizenbier obergärig':'beer',
'green tabasco':'tabasco_pepper','green tabasco sauce':'tabasco_sauce','green tagliatelle':'tagliatelle_pasta',
'green seed flour':'green seed flour','green soup':'green_soup','green spinach ribbon noodles':'pasta',
'green pepperoni':'chili','green peppers':'bell_pepper','green pesto':'pesto','green salad':'vegetable',
'graupen':'barley','green bacon':'bacon','green pasta':'green_pasta','green pepper':'bell_pepper',
'ginger root':'ginger','gingerbread':'ginger_bread','glaze lemon':'lemon_icing','goulash beef':'beef',
'fussili_noodle':'fussili_pasta','garlic chinese':'garlic','garlice':'garlic','gewürzslz ztomato seasoning salt':'toamto_spice_salt',
'fruits blueberries':'blueberries','fruits cherries':'cherries','fruits fix':'fruit','fusilli':'fusilli_pasta',
'fruit juice berry fruit':'berry_juice','fruit pudding banana':'banana_pudding','fruchtmolke':'fruit_juice',
'flaxseed sesame':'flaxseed,sesame','flour tortillas':'corn_tortilla','flour':'wheat','french beans green':'french_bean',
'five spices powder':'five_spices','flake butter':'butter','flavored caramel flavor':'caramel_aroma','flavored mayonaise':'mayonnaise',
'fish halibut':'halibut','fish sauce squid':'fish_sauce','fish sauce thail':'fish_sauce',
'fettuccine tagliatelle':'fettuccine_pasta','fettuccine tagliatelle':'fettuccine_pasta','fig green':'fig',
'feline salami':'salami','fenchelkraut':'fennel','fennel seed powder':'fennel','ferrero rocher':'chocolate',
'danish gurgle salad':'danish_cucumber_salad','dannananas':'pineapple','deer club':'deer','deer shoulder':'deer',
'dersteinpilze':'boletus','dessert cream chocolate':'chocolate_cream','dessert powder quark':'quark',
'dessertsaucenpulver vanilla':'vanilla_sauce','devils ravioli':'ravioli_diavoli','dextremadura pepper':'pepper',
'dijon mustard':'mustard','dijonsenf':'mustard','dinkelbrot mitkastanienstückchen':'bread',
'div kitchen herbs':'herb','djuve circle maggie':'Fix_für_Reis_Djuvec_Art','dosentomaten':'tomato',
'drink wssig':'vinegar','durum wheat flour':'wheat','dusting powdered sugar':'sugar','einrotes located':'red_jelly',
'emmi pfännlichäsprovencale':'Pfännlichäsprovencale','endivien chiccoreesalat':'endive'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^r',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['radish',
#  'radishes',
#  'rama',
#  'rama cremefine',
#  'rama cullinesse',
#  'ramacreme',
#  'ramaculinesse',
#  'rapeseed oil',
#  'rapeseed_oil',
#  'ras_el_hanout',
#  'raspberries',
#  'raspberry chilli bagclr devil tea',
#  'raspberry fruit juice',
#  'raspberry jam',
#  'raspberry liqueur',
#  'raspberry_götterspeise',
#  'raspberry_jam',
#  'raspberry_vinegar',
#  'ravioli',
#  'ravioli_diavoli',
#  'red apple',
#  'red apples',
#  'red beet sprouts',
#  'red berries',
#  'red berry juice',
#  'red berry salt',
#  'red cabbage',
#  'red cake icing powder',
#  'red cake topping',
#  'red caviar',
#  'red chard',
#  'red cherries',
#  'red chili',
#  'red chilli powder',
#  'red chillies',
#  'red clover',
#  'red currant jam',
#  'red currants',
#  'red fruit jelly',
#  'red fruit sauce',
#  'red gooseberries',
#  'red grape jelly',
#  'red grapes',
#  'red groats powder',
#  'red jam',
#  'red juice',
#  'red muffin glaze',
#  'red multivitamin juice',
#  'red olives',
# ...

# %%
two_ingr[two_ingr['en_ingr']=='rummsteaks']
# Out:
#     ingredient_name  parse_ingr     en_ingr
# 527    rummsteaks a  rummsteaks  rummsteaks

# %%
whole_change_dict={'pumpernickel speaks':'Pumpernickel_taler','put rinderhack':'beef',
'pressack white':'pressack_sausage','prosciuttoschinken':'prosciutto ham',
'potatoes red':'potatoes','potatoes small fried potatoes':'potato','pressack root':'pressack_sausage',
'plums yellow':'plum','polenta griess':'semolina_polenta','potato red':'potato','potato starch flour':'potato_starch',
'pizzateig grosspackung':'pizza_dough','pizzsitalian herbs herbs':'italian_herb','plums plums':'plum',
'pfeffer tellicherry':'tellicherry_pepper','pfefferkorn weiss':'pepper','pizza seasoning':'pizza_spice',
'pfanni kartoffelteig':'potato_dough','pfeffer':'pepper','pfeffer curry':'pepper,curry',
'pesto rot':'pesto','peteresilie':'parsley','peterilie':'parsley','petersilie maggikraut':'parsley',
'pesto green':'pesto','pesto herbs':'herb_pesto','pesto rossotomatebasilikum':'rosemary_tomato_basil_pesto',
'pepperoni oil':'chili_oil','pepperoni pickled':'pickled_chili','peppery ziron thyme vinegar':'peppery_lemon_thyme_vinegar',
'pepper salt':'pepper,salt','pepper white':'pepper','pepper-like spice':'pepper',
'pepper sugar':'pepper,sugar','pepper umajoran':'pepper,marjoram','pepper up paprika powder':'pepper,paprika_powder',
'pepper pulp':'paprika_mark','pepper red':'bell_pepper','pepper rosamarine':'pepper rosemary',
'pepper pizz':'pepper_pizza_spice','pepper pointed':'chili','pepper powder':'paprika_powder',
'pepper paprika powder tabasco':'pepper,tabasco_pepper','pepper olive oil':'pepper,olive_oil',
'pepper nutmeg':'pepper,nutmeg','pepper paprika':'pepper,paprika','pepper paprika powder':'pepper,paprika',
'pepper forage':'sweet_paprika_powder','pepper green':'bell_pepper','pepper marjoram':'pepper,marjoram',
'pepper cheese zbbonifaz':'pepper_cheese','pepper cores':'pepper','pepper chives':'pepper,chive',
'peas green':'pea','peas carrots':'pea,carrot','penne':'pasta','penne pasta':'pasta','peperonie rot':'chili',
'pasta spirelli':'pasta','pastis anisschnaps':'pastis','peach fruit juice':'peach_juice','peach fruit nectar':'peach_juice',
'pasta orecchiette':'orecchiette_pasta','pasta penne':'penne_pasta','pasta rigatoni':'rigatoni_pasta',
'pasta bucatini':'bucatini_pasta','pasta croissant':'croissant_pasta','pasta farfalle':'farfalle_pasta',
'paruren vomperhuhn':'chicken','passionsfrucht maracuja':'passion',
'parsley chives tarragon':'parsley,chives,tarragon','parsley dill':'parsley,dill','parsley french':'parsley',
'paprikamark':'paprika_mark','paprikasalami chorizo':'chorizo_sausage','parika charcoal':'sweet_paprika_powder',
'paprika preservative vegart':'paprika','paprikagew parsley':'parsley','paprikagewürz edelsüss':'sweet_paprika_powder',
'paprika nobles':'sweet_paprika_powder','paprika peppers':'chili','paprika pesto pestocalabrese':'paprika_pesto',
'paprika edelsüss':'sweet_paprika_powder','paprika grind':'paprika_powder','paprika mariniert':'pickled_paprika',
'palatinate thorn fields':'Dornfelder_wein','palm sugar':'sugar','pan spice zb tree life':'spice',
'paradiescreme vanillegeschmack':'vanilla_paradiescreme','paradiescremepulver vanilla':'vanilla_paradiescreme',
'orange orange':'orange','orange thyme':'orange,thyme',
'onion red':'onion','onion white':'onion','onions red':'onions','onions white':'onion','onions yellow':'onion',
'olive oil salt':'olive_oil,salt','olives black':'olive','olives green':'olive','onion cucumber':'onion,cucumber',
'olive kalamat':'olive','olive oil lemon':'lemon_olive_oil','olive oil orange':'orange_olive_oil',
'narrow ribbon noodles':'pasta','nudeln ditalini':'pasta','olive black':'olive','olive casablancaprovencale':'olive',
'mexicomais':'corn','milch':'milk','milkmaid code milk':'milk','mustard flour':'mustard powder',
'kräuter oragano':'oregano','krakauer':'krakauer_sausage','mediterranean_herb':'mediterranean_herbs',
'kirschwasser':'cherry','klmaiskolben':'corn','knobiwurst':'garlic_sausage','knolauch':'garlic',
'jalapeño sauce':'jalapeno_sauce','julienne saddlery':'vegetable','kaltcrem losiatela':'straciatela',
'ice chocolate drink powder':'ice_chocolate','ingrids salad dressing':'salad_sauce','ingwer insirup':'ginger,syrup',
'is apricot':'apricot','ital herbal':'italian_herb','ital herbs':'italian_herb','italian back':'bacon',
'italian seasoning':'italian spice','italian spice napoli':'italian spice','italienischerweinbrand':'brandy',
'italian white wine':'white_wine','italian pasta seasoning':'pasta_spice'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#two_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_en_005.csv')

# %%
ingr_list=[]
for index,row in two_ingr.iterrows():
    if re.search(r'^w',row.en_ingr)!=None:
        #print(row.ingredient_name)
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['wafer',
#  'walnut ginger',
#  'walnut panzerotti',
#  'walnut_nougat_taler',
#  'walnut_snack',
#  'walnuts',
#  'wasabi paste',
#  'water',
#  'watercress',
#  'weisse',
#  'western steak spice',
#  'wheat',
#  'wheat wraps',
#  'wheat_bread',
#  'whiskey',
#  'white bread',
#  'white cheese',
#  'white wine',
#  'white wine jelly',
#  'white_bread',
#  'white_chocolate',
#  'white_sauce',
#  'white_wheaties',
#  'white_wine',
#  'wine',
#  'wonton_dough',
#  'wooden toothpick',
#  'worcestershire sauce',
#  'worcestershire_sauce']

# %%
two_ingr[two_ingr['en_ingr']=='walnut panzerotti']
# Out:
#       ingredient_name          parse_ingr            en_ingr
# 1  walnuss panzerotti  walnuss panzerotti  walnut panzerotti

# %%
whole_change_dict={'walnut ginger':'walnut,ginger',
'rude':'drink','rummsteaks':'beef','rye':'rye_flour','salt chives':'salt,chive','savory':'summer_savory',
'scene ufrischkäse':'cream_cheese','schwarzbier vonschwabenbräu':'beer','schwgulasch derbrustspitze':'pork',
'sea-salt':'salt','seasoned with knofi':'garlic','seasoning':'spice','seasoning individually':'spice',
'sendwichvolkorn':'wheat_bread','senf djon':'mustard','senfgurken inx':'mustard_cucumber',
'serranoschinken hattebacon':'serano ham','senfmehl':'mustard',
'sesame voice':'sesame_seed','sesame white':'sesame_seed','sesampaste tahina':'tahini','sesampaste tahini':'tahini',
'shallots shallots':'shallot','shell_noodle':'shell_pasta','sheep cheese':'spicy_cheese','sheep cheese seasoning':'spicy_cheese',
'sherry weiss':'sherry','soup noodles mussels':'muscheln_pasta','soup noodles':'noodle',
'sour celery':'celery','spaghetti':'pasta','spaghetti bolognese':'bolognese_sauce','spaghetti bolognesesosse':'bolognese_sauce',
'spaghetti noodles':'pasta','spaghetti spice from herrmann spices':'pasta_spice','spice orient':'oriental_spice',
'spice piquant mill':'pikant_spice','spice powder':'spice','spice singapore':'singapore_spice',
'spices curry':'curry','spices salt':'salt','spicy, reduced-fat cheese':'spicy_cheese',
'sprigs parsley':'parsley','sugar cinnamon':'sugar,cinnamon','sweet chestnut flour':'chestnut',
'tarragon spice':'tarragon','thyme spice':'thyme','tomato rot':'tomato','tomato vine tomato':'cherry_tomato',
'tortelloni':'tortelloni_pasta','vegetable mexico':'vegetable','vegetables carrot pea corn':'carrot,paa,corn',
'vine tomatoes':'cherry_tomato','worcester sauce':'worcestershire_sauce','work naturreinwildpreiselbeeren':'cowberry_jam',
'weisswurst munich':'sausage','yellow paprikashoe':'bell_pepper','yellow pepper':'bell_pepper'}

# %%
for k,v in whole_change_dict.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
contain_change_list={'red wine':'red_wine','cayenne pepper':'cayenne pepper','bacardi':'bacardi','bacchus':'bacchus',
'bacon':'bacon','baking powder':'baking powder','beetroot':'beet','hirsch':'deer','black pepper':'black pepper',
'bolognese sauce':'bolognese sauce','candy':'candy','cardamom':'cardamom','cayenne pepper':'cayenne pepper',
'chickpea':'chickpea','chili powder':'chili_powder','chinese spice':'chinese spice','chocolate mocca':'chocolate mocca',
'choux pastry':'choux pastry','corn starch':'corn_starch','cornstarch':'corn_starch','eggplant':'eggplant',
'goat cheese':'goat cheese','icing powder':'icing powder','italian herb':'italian herb','kassler':'Kassler',
'paradise cream':'paradisecream','peppercorn':'pepper','poultry sausage':'poultry_sausage',
'powdered sugar':'sugar','seasoned gyro':'seasoned gyro','sesame seeds':'sesame_seed'}

# %%
def replace_ingr(k,v,ingredient):
    if re.findall(k,ingredient):
        return v
    else:
        return ingredient

# %%
for k,v in contain_change_list.items():
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:replace_ingr(k,v,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
delete_words=['popping','purple','powidl','prepare','prse','backfest','krispies','fiery','shrub','small',
'grow','schwartau','naturally','italian','etc','minni','r','curled','crowd','tricolore','kernel','mill',
'filletfresh','nuggets','thighs','wings','cl','odblattpetersilie','cox','extra','fried','danish','toe',
'lights','multivitamin','red','a','air','alternative','coxorange','rubinette','bamberger','barolo','ausbiskuitmasse',
'unusual','black-green','boil','boiled','boiling','bonduelle','black','bright','cenovis','obalsami',
'scoops','sharp','sweet']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_words(x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delete_parts=['red vegetable','three-quarter level','chicken fillets','seasoning with herbs','by buko','italian country',
'rolls a&#39;lamanfred','new shape','italian style','compote pitted','soup vegetables']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    two_ingr['en_ingr']=two_ingr['en_ingr'].apply(lambda x:del_part(part,x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
whole_delete=['red sugar pearls','red sugar script','crispies','icing sugar to decorate','or curry','or streusel dough',
'praline fork praline spiral','skewers wood','specialty our area','wooden toothpick','weisse']

# %%
two_ingr=two_ingr[~two_ingr['en_ingr'].isin(whole_delete)]

# %%
two_ingr.reset_index(drop=True,inplace=True)

# %%
two_ingr
# Out:
#               ingredient_name               parse_ingr  \
# 0               pommes frites            pommes frites
# 1          walnuss panzerotti       walnuss panzerotti
# 2       granatapfel balsamico    granatapfel balsamico
# 3        schwlende geräuchert     schwlende geräuchert
# 4          pökelwaren eisbein       pökelwaren eisbein
# ...                       ...                      ...
# 3135      paprika rotgelbgrün      paprika rotgelbgrün
# 3136  brunch paprikapepperoni  brunch paprikapepperoni
# 3137    asiatisches wokgewürz    asiatisches wokgewürz
# 3138           kle vomschwein           kle vomschwein
# 3139           kalb schnitzel           kalb schnitzel
#
#                        en_ingr
# 0                 french fries
# 1            walnut panzerotti
# 2         pomegranate balsamic
# 3                  smoked_pork
# 4                   cured_pork
# ...                        ...
# 3135                   paprika
# 3136  brunch paprika pepperoni
# ...

# %%
# ^beef,^carrot,^curry,^grapes,glaze-->icing,^kiwi,^pig,^pork,

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'^\bbeef\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        #print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='beef'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if re.search(r'^\bcurry\b',row.en_ingr)!=None:
        # print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='curry'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'^\bcarrot\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        #print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='carrot'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'^\bgrapes\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        #print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='grape'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'^\bkiwi\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        #print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='kiwi'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'^\bpig\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        #print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='pork'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'^\bpork\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        # print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']='pork'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for index,row in two_ingr.iterrows():
    if (re.search(r'\bglaze\b',row.en_ingr)!=None) & (re.search(r',',row.en_ingr)==None):
        # print(row.en_ingr)
        two_ingr.loc[index,'en_ingr']=re.sub('glaze','icing',row.en_ingr)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
two_ingr
# Out:
#               ingredient_name               parse_ingr  \
# 0               pommes frites            pommes frites
# 1          walnuss panzerotti       walnuss panzerotti
# 2       granatapfel balsamico    granatapfel balsamico
# 3        schwlende geräuchert     schwlende geräuchert
# 4          pökelwaren eisbein       pökelwaren eisbein
# ...                       ...                      ...
# 3135      paprika rotgelbgrün      paprika rotgelbgrün
# 3136  brunch paprikapepperoni  brunch paprikapepperoni
# 3137    asiatisches wokgewürz    asiatisches wokgewürz
# 3138           kle vomschwein           kle vomschwein
# 3139           kalb schnitzel           kalb schnitzel
#
#                        en_ingr
# 0                 french fries
# 1            walnut panzerotti
# 2         pomegranate balsamic
# 3                  smoked_pork
# 4                   cured_pork
# ...                        ...
# 3135                   paprika
# 3136  brunch paprika pepperoni
# ...

# %%
two_ingr=two_ingr[two_ingr['en_ingr']!='']
two_ingr['en_ingr']=two_ingr['en_ingr'].str.strip()
two_ingr.dropna(inplace=True)
two_ingr.reset_index(drop=True,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
two_ingr.shape
# Out:
# (3136, 3)

# %%
en_ingrs=list(set(two_ingr['en_ingr'].values.tolist()))
len(en_ingrs)
# Out:
# 1283

# %%
two_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_two_ingr_done_005.csv')
