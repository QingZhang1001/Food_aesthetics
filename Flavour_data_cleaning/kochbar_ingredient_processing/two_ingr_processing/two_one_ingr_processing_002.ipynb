# %%
import pandas as pd
import numpy as np
import os
import re
import string

# %%
one_ingr_df=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_one_ingr_en_002.csv',index_col=0)
one_ingr_df.shape
# Out:
# (2244, 2)

# %%
one_ingr_df
# Out:
#              ingredient_name                 en_ingr
# 0                      milka               chocolate
# 1          trüffelbandnudeln  truffle ribbon noodles
# 2                 rumrosinen             rum rosinen
# 3                rmuskatnuss                  nutmeg
# 4                     salbei                    sage
# ...                      ...                     ...
# 2239           kräuterbutter             herb butter
# 2240  indischegewürzmischung            indian spice
# 2241             orangensaft            orange juice
# 2242                 zbmilch                   milch
# 2243          trüffelravioli         truffle ravioli
#
# [2244 rows x 2 columns]

# %%
one_ingrs=list(set(one_ingr_df['en_ingr'].values.tolist()))
len(one_ingrs)
# Out:
# 1141

# %%
one_ingrs.sort()
one_ingrs
# Out:
# ['Amarettini',
#  'Bauernpüree',
#  'Bismarckhering',
#  'Bratwurst',
#  'Brunch legere',
#  'Brunoise',
#  'Bruschetta',
#  'Eierspätzle',
#  'Eisbein',
#  'Götterspeise galium odoratum',
#  'Götterspeise lemon',
#  'Hefezopf',
#  'Jagdwurst',
#  'Karree',
#  'Kasseler',
#  'Klossteig',
#  'Knödel',
#  'Krustenbraten',
#  'Leberhack',
#  'Leberkäs',
#  'Lebkuchen_spice',
#  'Linsen Buchweizen Tomatensauce',
#  'Maggi würze',
#  'Makronen',
#  'Mandelsplitter',
#  'Marzipan',
#  'Maultasche',
#  'Mohrenköpfe',
#  'Pferderouladen',
#  'Puszta salat',
#  'Quar Sahne Torten Hilfe',
#  'Ratatouille',
#  'Ratluk',
#  'Rippchen',
#  'Roulade',
#  'Röstis',
#  'Sanella',
#  'Sauerbraten',
#  'Sauerkraut',
#  'Schaschlik',
#  'Schnitzel',
#  'Schweinerollbraten',
#  'Sepiatinte',
#  'Spätzle',
#  'Streusel',
#  'Strudel',
#  'Surschnitzel',
#  'Tatar',
#  'Torteletts',
#  'Toscana mix',
#  'Wacholderbauch',
#  'advocaat',
#  'agar-agar',
#  'agavendicksaft',
#  'ajvar',
#  'allspice',
# ...

# %%
# cleaning for the second time

# %%
change_dict={'Eisbeib':'Eisbein','Euphorbia lathyris':'euphorbia lathyris','Götterspeisewaldmeister':'Götterspeise galium odoratum',
             'Hassenkeulen':'rabbit','Kasslerkotelett':'Kasseler','Krokant':'krokant','Lebkuchengewürz':'Lebkuchen_spice',
             'Piper cubeba':'piper cubeba','Rösti ecken':'Röstis','Tahini':'tahini','Waldmeistersirup':'galium odoratum syrup'}

# %%
def replace_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in change_dict.items():
    one_ingr_df['en_ingr']=one_ingr_df['en_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
en_ingrs=[]
for index, row in one_ingr_df.iterrows():
    if re.search(r'^u',row.en_ingr)!=None:
        en_ingrs.append(row.en_ingr)
en_ingrs=list(set(en_ingrs))
en_ingrs.sort()
en_ingrs
# Out:
# ['udon noodles']

# %%
one_ingr_df[one_ingr_df['en_ingr']=='write']
# Out:
#      ingredient_name en_ingr
# 2008           kakau   write

# %%
one_ingr_df['en_ingr'][one_ingr_df['ingredient_name']=='salatcreme']='salat_cream'
one_ingr_df['en_ingr'][one_ingr_df['ingredient_name']=='salatmajo']='mayonnaise'
one_ingr_df['en_ingr'][one_ingr_df['ingredient_name']=='kochsalat']='vegetable'
one_ingr_df['en_ingr'][one_ingr_df['ingredient_name']=='schnittsalat']='vegetable'

# %%
change_dict={'windbeutel':'cream puff',
    'vanilla dessert sauve':'vanilla dessert sauce','vegetable broth powder':'vegetable broth',
    'toast':'bread','treasure morels':'sour cherry','turkey breast':'turkey','turkey breast fine':'turkey',
    'spring leek':'spring onion','spring onion rolls':'spring onion','swordfish steaks':'swordfish',
    'snackchili':'chili','soup green':'vegetable','sour dough':'sourdough','soy technetzel':'soybean',
    'soy':'soybean','speakers':'Kalbsjus','spicy':'pikantje_cheese','sport wine':'port wine',
    'schwhaxe':'Schweinshaxe','schwkamm':'pork','screech':'shrimps','skreifilet':'codfish',
    'salmon ham':'salmon','schinckenwurst':'sausage','schupfnudeln':'Schupfnudeln',
    'salary':'lettuce','salat':'vegetable','salatkopf':'lettuce','salatmayonaise':'mayonnaise',
    'rose flour':'wheat','rotepeperoncino':'chili','rotus':'vinegar','salads':'vegetable',
    'romanasalatherzen':'romaine lettuce','romanosalat':'romaine lettuce','romatomat':'cherry tomato',
    'rump steak':'beef','rumpsteaks':'beef','romacherrytomatenfrisch':'cherry tomato','roman dialect':'broccoli',
    'rice grains':'rice','roasted han':'roasted ham','rum rosinen':'rum raisin',
    'rahmcamembert':'camembert cheese','reggiano':'parmesan cheese','reisbandnudeln':'rice noodle',
    'pastagewürz':'pasta spice','paste':'Pastetli','pastry sheets':'pastry','pepperonida':'chili',
    'packet speculum spice':'Spekulatiusgewürz','paprikamix':'paprik powder','pasta flavor':'Nudelngeschmacksrichtung',
    'of garlic':'garlic','onionsoup':'onion soup','orange pepper':'bell pepper','ostrich steaks':'ostrich',
    'meatsoup':'meat broth','met':'mead','milch':'milk','morchella elata':'morchella','no':'egg',
    'meat boullion':'meat broth','meat cheese mass':'meat cheese','minz':'mint','meat roast':'meat',
    'long grain rice':'rice','marachinokirschen':'maraschino_cherry','marzipan raw mass':'marzipan',
    'agavendicksaft':'agave_syrup','apple cabbage':'apple butter','baconfein':'bacon',
    'balsamico creme':'balsamic cream','beef rump steak':'beef','beef store':'beef',
    'beef tomato':'tomato','beef tomatoes':'tomato','beetle beans':'butter bean',
    'beetroot juice':'beet_juice','berd bear':'strawberry','bitter almond aroma':'almond aroma',
    'black beer':'beer','blue poppy':'poppy','brine':'brining','buttermandelkaramellriegel':'butter almond caramel bar',
    'buttermargarine':'butter','cassis iqueur':'cassis liqueur','celeriac':'celery',
    'chick':'chicken','chicken breast':'chicken','chicken soup':'chicken broth','chicken chicken':'chicken',
    'chilies':'chili','chinese cabbage':'cabbage','chives garlic':'garlic','chives rolls':'garlic',
    'chocolate bunny':'chocolate','chocolate cake bottom see':'chocolate cake base','chocolate couverture':'chocolate',
    'chocolate glasses':'chocolate icing','chocolate glaze':'chocolate icing','chocolate mocca beans':'mocca bean',
    'chocolate shavings':'chocolate','chocolate stars':'chocolate','chocolateglaze':'chocolate icing',
    'chop':'meat','gesäubertesteinpilze':'boletus','clove':'nelke','clove of garlic':'garlic',
    'clove powder':'nelke','club':'meat','cod':'codfish','condensed milk':'milk','conversion':'chocolate',
    'corinth':'raisin','creamy':'gulash_cream','crrot':'carrot','currybutter':'curry butter',
    'dark chocolate couverture':'chocolate','dashibrühe':'dashi broth','duck breast':'duck',
    'elcappuccinopulver':'cappuccino_powder','expresspulver':'espresso_powder','feta':'feta_cheese',
    'figures':'cucumber','frsemmelbrösel':'bread_crumbs','garlic clove':'garlic','gauda hand':'gouda_cheese',
    'gemnüsebrühe':'vegetable broth','glasnudeln':'glass noodle','glaze':'icing',
    'goat cheese roll':'goat cheese','granatäpfel':'apple','granulated sugar':'sugar',
    'hagebutten':'rose hip','hartkasegreyerzer':'greyerzer cheese','her':'chicken','huehnerbrust':'chicken',
    'hummer':'lobster','increasing':'croissant','jam fruit':'fruit jam','johannisbeersaft':'currant juice',
    'knuckle of':'Eisbein','kokosn':'coconut','kürbis':'pumpkin','learner':'leerdammer cheese',
    'leave':'quince jelly','leerdammer':'leerdammer cheese','lendenkasseler':'Kasseler'}

# %%
def replace_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in change_dict.items():
    one_ingr_df['en_ingr']=one_ingr_df['en_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
one_ingrs=list(set(one_ingr_df['en_ingr'].values.tolist()))
len(one_ingrs)
# Out:
# 1040

# %%
whole_delete=['black','cold','leg','mahoran','rear ice','red','rib','ribs','rlimates','torties','write']

# %%
one_ingr_df=one_ingr_df[~one_ingr_df['en_ingr'].isin(whole_delete)]
one_ingr_df.reset_index(drop=True,inplace=True)

# %%
delete_words=['ring','chops','clarified','cured','chops','breast','slice','limfjord','blanket','slices','pelleted','chop',
'filets']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
one_ingr_df['en_ingr']=one_ingr_df['en_ingr'].apply(lambda x:del_words(x))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df.dropna(inplace=True)
one_ingr_df=one_ingr_df[one_ingr_df['en_ingr']!='']
one_ingr_df['en_ingr']=one_ingr_df['en_ingr'].str.strip()
one_ingr_df.reset_index(drop=True,inplace=True)

# %%
one_ingrs=list(set(one_ingr_df['en_ingr'].values.tolist()))
len(one_ingrs)
# Out:
# 1013

# %%
one_ingr_df.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_one_ingr_en_003.csv')

# %%
one_ingr_df_001=one_ingr_df[one_ingr_df['en_ingr'].str.split().str.len()==1]
one_ingr_df_001.shape
# Out:
# (1513, 2)

# %%
# lemmatization

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/IW_student/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
one_ingr_df_001['tag']='n'
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
lemmatizer = WordNetLemmatizer()

# %%
one_ingr_df_001['ingr_lemma']=one_ingr_df_001.apply(lambda x:lemmatizer.lemmatize(x.en_ingr,x.tag),axis=1)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df_001
# Out:
#       ingredient_name    en_ingr tag ingr_lemma
# 0               milka  chocolate   n  chocolate
# 3         rmuskatnuss     nutmeg   n     nutmeg
# 4              salbei       sage   n       sage
# 8                bier       beer   n       beer
# 9              schoko  chocolate   n  chocolate
# ...               ...        ...  ..        ...
# 2222           vegeta     vegeta   n     vegeta
# 2223        sardellen    anchovy   n    anchovy
# 2224  steinpilzkappen    boletus   n    boletus
# 2225  gemischtebeeren    berries   n      berry
# 2229          zbmilch       milk   n       milk
#
# [1513 rows x 4 columns]

# %%
one_ingr_df_002=one_ingr_df[one_ingr_df['en_ingr'].str.split().str.len()>1]
one_ingr_df_002.shape
# Out:
# (718, 2)

# %%
one_ingr_df_002['last_ingr']=one_ingr_df_002['en_ingr'].str.split().str[-1]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df_002['tag']='n'
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df_002['last_ingr']=one_ingr_df_002.apply(lambda x:lemmatizer.lemmatize(x.last_ingr,x.tag),axis=1)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df_002
# Out:
#              ingredient_name                 en_ingr last_ingr tag
# 1          trüffelbandnudeln  truffle ribbon noodles    noodle   n
# 2                 rumrosinen              rum raisin    raisin   n
# 5             bambussprussen           bamboo shoots     shoot   n
# 6                  lammleber              lamb liver     liver   n
# 7             rostbratwürste        toasted sausages   sausage   n
# ...                      ...                     ...       ...  ..
# 2221       marillenmarmelade             apricot jam       jam   n
# 2226           kräuterbutter             herb butter    butter   n
# 2227  indischegewürzmischung            indian spice     spice   n
# 2228             orangensaft            orange juice     juice   n
# 2230          trüffelravioli         truffle ravioli   ravioli   n
#
# [718 rows x 4 columns]

# %%
# https://stackoverflow.com/questions/54395056/drop-last-word-in-pd-dataframe
one_ingr_df_002['en_ingr']=one_ingr_df_002.en_ingr.str.rsplit(' ',1).str[0]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
one_ingr_df_002['ingr_lemma']=one_ingr_df_002['en_ingr']+' '+one_ingr_df_002['last_ingr']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df_002['en_ingr']=one_ingr_df_002['en_ingr']+' '+one_ingr_df_002['last_ingr']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
one_ingr_df_002.drop('last_ingr',axis=1,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
one_ingr_df_002.head()
# Out:
#      ingredient_name                en_ingr tag             ingr_lemma
# 1  trüffelbandnudeln  truffle ribbon noodle   n  truffle ribbon noodle
# 2         rumrosinen             rum raisin   n             rum raisin
# 5     bambussprussen           bamboo shoot   n           bamboo shoot
# 6          lammleber             lamb liver   n             lamb liver
# 7     rostbratwürste        toasted sausage   n        toasted sausage

# %%
one_ingr_df_001.head()
# Out:
#   ingredient_name    en_ingr tag ingr_lemma
# 0           milka  chocolate   n  chocolate
# 3     rmuskatnuss     nutmeg   n     nutmeg
# 4          salbei       sage   n       sage
# 8            bier       beer   n       beer
# 9          schoko  chocolate   n  chocolate

# %%
one_ingr_df=pd.concat([one_ingr_df_001,one_ingr_df_002],axis=0,ignore_index=True)
one_ingr_df.shape
# Out:
# (2231, 4)

# %%
one_ingr_df
# Out:
#              ingredient_name          en_ingr tag       ingr_lemma
# 0                      milka        chocolate   n        chocolate
# 1                rmuskatnuss           nutmeg   n           nutmeg
# 2                     salbei             sage   n             sage
# 3                       bier             beer   n             beer
# 4                     schoko        chocolate   n        chocolate
# ...                      ...              ...  ..              ...
# 2226       marillenmarmelade      apricot jam   n      apricot jam
# 2227           kräuterbutter      herb butter   n      herb butter
# 2228  indischegewürzmischung     indian spice   n     indian spice
# 2229             orangensaft     orange juice   n     orange juice
# 2230          trüffelravioli  truffle ravioli   n  truffle ravioli
#
# [2231 rows x 4 columns]

# %%
long_ingr=long_ingr.assign(ingredient_name=long_ingr['ingredient_name'].str.split(',')).explode('ingredient_name')

# %%
one_ingr_df=one_ingr_df.assign(ingr_lemma=one_ingr_df['ingr_lemma'].str.split(',')).explode('ingr_lemma')

# %%
one_ingr_df.shape
# Out:
# (2242, 4)

# %%
one_ingr_df.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/')

# %%
one_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_one_ingr.csv',index_col=0)
one_ingr.shape
# Out:
# (40877, 4)

# %%
one_ingr.head()
# Out:
#    recipe_id                                        recipe_href  \
# 0      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 1      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...
# 5      25386                 /rezept/423974/I-Zwiebelsauce.html
# 6      43997         /rezept/342019/schneller-Apfelbiskuit.html
# 7      43997         /rezept/342019/schneller-Apfelbiskuit.html
#
#                               name ingredient_name
# 0                   butter flüssig          butter
# 1                        salz grob            salz
# 5  mittelgrosse zwiebeln,gewürfelt        zwiebeln
# 6                  mandeln gehackt         mandeln
# 7                     äpfel frisch           äpfel

# %%
one_ingr=pd.merge(one_ingr,one_ingr_df,on='ingredient_name',how='inner')
one_ingr.shape
# Out:
# (39267, 7)

# %%
one_ingr.drop(['en_ingr','tag'],axis=1,inplace=True)

# %%
one_ingr_keep=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_one_ingr_keep.csv',index_col=0)
one_ingr_keep.shape
# Out:
# (41, 4)

# %%
one_ingr_keep['ingr_lemma']=one_ingr_keep['ingredient_name']

# %%
one_ingr=pd.concat([one_ingr,one_ingr_keep],axis=0,ignore_index=True)
one_ingr.shape
# Out:
# (39308, 5)

# %%
one_ingr.sort_values('recipe_id',inplace=True)
one_ingr.reset_index(drop=True,inplace=True)
one_ingr.shape
# Out:
# (39308, 5)

# %%
one_ingr
# Out:
#        recipe_id                                  recipe_href  \
# 0             25  /rezept/419371/Spaghettata-alla-Hannah.html
# 1             25  /rezept/419371/Spaghettata-alla-Hannah.html
# 2             25  /rezept/419371/Spaghettata-alla-Hannah.html
# 3             46  /rezept/250930/Kuerbis-Kartoffel-Suppe.html
# 4             46  /rezept/250930/Kuerbis-Kartoffel-Suppe.html
# ...          ...                                          ...
# 39303     118116              /rezept/4765/Bananen-Shake.html
# 39304     118118             /rezept/108120/Suelze-Salat.html
# 39305     118128               /rezept/457273/Eierkuchen.html
# 39306     118142       /rezept/252663/Fleischwurstpfanne.html
# 39307     118142       /rezept/252663/Fleischwurstpfanne.html
#
#                                               name ingredient_name  \
# 0                                  zwiebel gehackt         zwiebel
# 1                            knoblauchzehe gehackt   knoblauchzehe
# ...

# %%
one_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/two_ingr_data/two_one_ingr_done.csv')
