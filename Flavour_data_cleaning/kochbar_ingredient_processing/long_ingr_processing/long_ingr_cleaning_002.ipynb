# %%
# aim of this page: delete all non-ingredient in ingredient_name column

# %%
import pandas as pd
import numpy as np
import re

# %%
data=pd.read_csv('datasets/long_ingr_data/long_ingr_002.csv',index_col=0)
data.shape
# Out:
# (8304, 4)

# %%
data.head()
# Out:
#    recipe_id                                        recipe_href  \
# 0      11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 1      11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 2       2761  /rezept/478153/Auberginenroellchen-mit-Kaese.html
# 3      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
# 4      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
#
#                                              name  \
# 0                     pfeffer aus der mühle weiss
# 1         paprikaschote frisch rotklein gewürfelt
# 2              evtl. schwarze oliven zumgarnieren
# 3                             butter für die form
# 4  gelb flossen thunfischtranchen a ca. 150 gramm
#
#                            ingredient_name
# 0                  pfeffer der mühle weiss
# 1  paprikaschote frisch rotklein gewürfelt
# 2       evtl. schwarze oliven zumgarnieren
# 3                                   butter
# 4         gelb flossen thunfischtranchen a

# %%
# E

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\be\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ebuttercreme siehe meineanderen rezepte',
#  'eckerlkäs',
#  'edamer gerieben',
#  'edamer od. anderer käse',
#  'edeka',
#  'edelgard bitte verzeih mir',
#  'egerlinger',
#  'eier',
#  'eierlikör in den teig',
#  'eierstich frisch gemacht inkleine würfel geschnitten',
#  'eigelegtin öl mit kräutern',
#  'eigenanbau',
#  'eigene tk',
#  'eigeneherst.',
#  'eiklar',
#  'eimach',
#  'ein bisschen für den fisch',
#  'ein blech für 12 muffins',
#  'ein geschenk',
#  'ein gestr. teel. salz',
#  'ein halber tlgerösteter knoblauch ausder dose',
#  'ein mittleres sieb war knappgefüllt',
#  'ein muss',
#  'ein paar blätter kopfsalat',
#  'ein paar blätter pilzkraut',
#  'ein paar chiliflöckchennach gemschmack',
#  'ein paar frische erdbeerenzum verzieren',
#  'ein paar ganze haselnüsse',
#  'ein paar grob gehacktepistazien',
#  'ein paar kirschtomaten zumgarnieren',
#  'ein paar scheibchen speckdurchwachsen',
#  'ein paar schluckemineralwasser mitkohlensäure',
#  'ein paar spritzer maggi',
# ...

# %%
# D

# %%
data.to_csv('datasets/long_ingr_data/long_ingr_003.csv')

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bd\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['dany sahne nuss nougatgeschmack',
#  'dass cocktailsaucewegen der scampis sehrpassend ist',
#  'datteltomaten',
#  'datteltomaten der doseohne saft',
#  'decke mit dem embleme vom fc',
#  'deko',
#  'deko erdbeere minzblattgebräunte mandeln',
#  'deko nach eigenem geschmack röschen kleineherzchen',
#  'deko scheiben vonfrühlingszwiebeln basilikumblatt',
#  'deko zum garnieren obst',
#  'deko zum verzieren für diepupse',
#  'dessert',
#  'dessertsosse vanillegeschmack zum kochen',
#  'diabetiker nehmen stattpuderzucker flüssigensüssstoff',
#  'diamant',
#  'dicedtomatoes',
#  'dickblättriggeschnitten',
#  'dicke kartoffel',
#  'dicke rippe in würfelgeschitten',
#  'dicke rippe vom schwein',
#  'dijon senf mit grünempfeffer',
#  'dijonaise',
#  'dille',
#  'dille frisch hatte nur tk',
#  'dinkel mehl weiss glatt',
#  'dinkel mehl zum binden',
#  'dinkel wie reis%x2c ersatzweiseebly zartweizen',
#  'dinkelmehl',
#  'dinkelnudeln roh ich hattehörnchen',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bdürfen\b',row.ingredient_name)!=None) or (re.search(r'^\bdem\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bder\b',row.ingredient_name)!=None) or (re.search(r'^\bder\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bdenn\w+',row.ingredient_name)!=None) or (re.search(r'^\bdenn\b',row.ingredient_name)!=None) or (re.search(r'^\bdie\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bdabei\w+',row.ingredient_name)!=None) or (re.search(r'^\bdann\w+',row.ingredient_name)!=None) or (re.search(r'^\bdeine\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bden\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['den bodenmit backpier auslegen',
#  'den bratensatz von denschaschliks',
#  'den geleertensauerrahmbecher alsmessbecher für dierestlichen zutatenverwenden',
#  'den habe ich ja imgarten',
#  'den kochsud vom rosenkohl',
#  'den krausen',
#  'den ofen auf 160 gr umluftvorheizen',
#  'den pudding mitsuesstoff kein zucker',
#  'den rest für das gemüe',
#  'den rest vom feta käse',
#  'den saft davon',
#  'den saft von 2bio',
#  'den saft von dieser',
#  'den saft von sauereingelegten paprika',
#  'den stiel']

# %%
for index, row in data.iterrows():
    if (re.search(r'\bden saft von 2 zitronen\b',row.ingredient_name)!=None) or (re.search(r'\bden saftaus der pfirsichdose\b',row.ingredient_name)!=None):
        print(row.ingredient_name)
# Out:
# den saftaus der pfirsichdose
# den saft von 2 zitronen

# %%
for index, row in data.iterrows():
    if re.search(r'\bden saft von 2 zitronen\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Zitronen'

# %%
for index, row in data.iterrows():
    if re.search(r'\bden saftaus der pfirsichdose\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Pfirsich'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bden\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# dotter = Eigelb

# %%
for index, row in data.iterrows():
    if re.search(r'\bdotter\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Ei'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bdie beeren\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Beeren'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bdie crespelle\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Crepe'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bdie\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bdu\b',row.ingredient_name)!=None) or (re.search(r'^\bdurch\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bdazu\b',row.ingredient_name)!=None) or (re.search(r'^\bdavon\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# start with den, delete manually

# %%
# C

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bc\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ca lau warme milch',
#  'ca. 6el brauner zucker',
#  'ca. ein halberkürbis',
#  'ca. einachtel',
#  'ca. nussgross',
#  'ca.3',
#  'cachaca',
#  'cafe de paris',
#  'café de paris gewürz',
#  'candurin goldpulver hierhatte ich daskaramellfarbene',
#  'cappuccino',
#  'cappuccinopulver vonnescafé für 1 tasse',
#  'cappucinopuler milkaweisse schokolade von jacobs',
#  'captain morgan',
#  'caramel schokoriegel von gut',
#  'castel franco la rossa',
#  'cd mit fetziger musik z. b.mamma mia',
#  'champignonköpfe',
#  'champions mit ganzen köpfen',
#  'chateau de mornag wein zumsteak',
#  'chen knollenselleriein grobe e geschnitten',
#  'chen rote paprikasehr klein geschnitten',
#  'cherrytomaten fuer die deko',
#  'chicoreeblätter',
#  'chili',
#  'chili bitte nur  nach geschmackhot',
#  'chili der mühle nacheuren geschmack',
#  'chili frisch fein gehackt',
#  'chili frisch gelbe habanero',
#  'chili gemahlen',
#  'chili getrocknet habaneromit kerne grob gemörsert',
# ...

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'\b...\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# [' gr blaue weintraubenhalbiert',
#  ' kl milch',
#  ' min. ved',
#  ' tl salz',
#  '%x2c',
#  '* schmecktaber auch miter gut',
#  '*räusper hab ich noch imschrank gef',
#  '1 1',
#  '1 flasche für denschweinebraten',
#  '1 flaschefür den koch',
#  '1 glasfür den koch %x2c',
#  '1 mürbteigaus dem kb',
#  '1 pck',
#  '1 tl sambal oelek',
#  '1 z.b. rùf',
#  '10 blätter',
#  '10 stueckohe haut  nehme sieohne knochen',
#  '15 minuten bei 180 grad',
#  '15 ohne kopf',
#  '15 schalotten',
#  '15 stueck',
#  '16 dünne scheiben',
#  '16 l wasser od. suppe',
#  '1zerdrückte= 3 ganze',
#  '2 l mich',
#  '2 l milch',
#  '2 l milch %x2c',
#  '2 l milch%x2c ohne kochen',
#  '2 l wasser',
#  '2 lflüssigkeit zum kochen',
#  '2 lmilch%x2c zum kochen',
#  '2 tl kurkuma',
#  '2 tl oregano',
#  '2 tl paprikapulver',
#  '2 tl pesto',
#  '2 tl thymian',
#  '2 to  stuecke',
#  '200 gr. jenach appetit',
#  '2l milch',
#  '2l milch%x2c zum kochen',
#  '2x rot',
#  '3 min. kochzeit',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\bcognac\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='cognac'
# Out:
# cognac [ .♥.bei kindern evtl. etwasapfelsaft

# %%
for index, row in data.iterrows():
    if re.search(r'^\bcm\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'\b%x22\w+',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']=re.sub('%x22','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'\b%x22\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']=re.sub(r'\b%x22\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'\bchiliflocken\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bchiliflocken\b','')
# Out:
# chiliflocken rot
# chiliflocken rot
# chiliflocken rot

# %%
# cd mit fetziger musik z. b.mamma mia

# %%
ingr_list=[]
for index, row in data.iterrows():
    if (re.search(r'^\bca. [0-9]+\b',row.ingredient_name)!=None) or (re.search(r'^\bca [0-9]+\b',row.ingredient_name)!=None):
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# []

# %%
for index, row in data.iterrows():
    if re.search(r'^\bca. [0-9]+\b',row.ingredient_name)!=None:
        #ingr_list.append(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bca. [0-9]+\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bca [0-9]+\b',row.ingredient_name)!=None:
        #ingr_list.append(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bca [0-9]+\b','',row.ingredient_name)

# %%
# B

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bb\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['baby spinat ineiner tuete',
#  'babybel',
#  'back ... s.o',
#  'back trenn spray für dieform',
#  'backfertige mohnfüllung vondr. oetker',
#  'backfertiger frischteig 6croissants von kühlregeal',
#  'backfester vanillepuddingvon dr oetker',
#  'backkakao kein kaba',
#  'backmischung%x22schokoflockenkuchen%x22 vomdem onkel bielefeld',
#  'backpflaumen ohne stein 1',
#  'backpulver 300 gr mehl',
#  'backpulver u.eine prise salz',
#  'backzeit im umluftofen ca.12',
#  'baconscheiben duenne',
#  'badreichenhaller',
#  'bagetid',
#  'baguettes zum aufbacken à',
#  'baiser',
#  'baisergebäck',
#  'baking powder muss sein',
#  'baking soda = natron',
#  'balsamico',
#  'balsamico essig',
#  'balsamico rot',
#  'bambussprossen der dosewer mag',
#  'bambussrösslinge',
#  'bananas nehme diese wo schonschwarze punket habe aberfest sind',
#  'banane',
#  'barbecuesosse',
#  'barbeque gewürz zum grillen',
#  'basic',
#  'basilikum',
#  'basilikumsauce mitcrème fraîche',
#  'basilkum',
# ...

# %%
# basic,basisch,bautzener,bayern,beim,bekannt,bekommt, beutel, besser,bildfolgt,bitte

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bbesser\b',row.ingredient_name)!=None) or (re.search(r'^\bbildfolgt\b',row.ingredient_name)!=None) or (re.search(r'^\bbitte\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bbekannt\b',row.ingredient_name)!=None) or (re.search(r'^\bbekommt\b',row.ingredient_name)!=None) or (re.search(r'^\bbeutel\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bbeim\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bbayern\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bbautzener\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bbasic\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bbasisch\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# delete manually: bei anderenkürbisarten siehebeschreibung,bei tk auftauen lassen, beibedarf auch etwas mehr,beigrösserem hunger auch mehr,
# beisaison... natürlich diefrischen himbeeren,

# %%
# A

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\ba\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list.sort()
ingr_list
# Out:
# ['aber es botsich an ich war ko',
#  'abervorsicht',
#  'abger. schale einer halbenzitrone',
#  'abgeriebende schale von 1orange',
#  'abgeriebene zitonenschale .gibt es auch zu kaufen',
#  'abgetropft',
#  'abgetropft',
#  'abgiesen',
#  'abgiessen',
#  'abrieb von einer halbenzitrone',
#  'abrieb von einer limette',
#  'abrieb von einer limette',
#  'abschnitte vom ende derstangen',
#  'abtropfgewicht etwa350',
#  'abtropfgewicht etwa350',
#  'abtropfgewicht je',
#  'abtropfgewicht je',
#  'achat',
#  'achtung !!! siehe rezept',
#  'achtung bei kindernnicht',
#  'achtung feurig scharf',
#  'aci biber',
#  'aepfel grosse',
#  'african zulu dipp',
#  'afrikanischer peppersgefüllt mit frischkäsemango',
#  'aglio olio de peperoncino',
#  'aglio olio e peperoncino',
#  'aioli 2 im kb',
#  'aioli siehe im kochbuch',
#  'al gusto mit kräutern',
#  'alaska',
#  'alba öl[gibt es bei rewe',
#  'albaöl = rapsöl mitbuttergeschmack',
#  'alles für denerdbeersalat',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bam abend\b',row.ingredient_name)!=None) or (re.search(r'^\bam kb\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bausstechen\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bausgekratztes mark von\b',row.ingredient_name)!=None:
        #print(row)
        data.loc[index,'ingredient_name']=re.sub('ausgekratztes mark von','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bauf\b',row.ingredient_name)!=None:
        #print(row)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bauch',row.ingredient_name)!=None:
        #print(row)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bansonsten',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\banzahl',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\baber',row.ingredient_name)!=None:
        #print(row)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\babgetropft\b',row.ingredient_name)!=None) or (re.search(r'^\babgiesen\b',row.ingredient_name)!=None) or (re.search(r'^\babgiessen\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\babschnitte\b',row.ingredient_name)!=None) or (re.search(r'^\babtropfgewicht\b',row.ingredient_name)!=None) or (re.search(r'^\bachat\b',row.ingredient_name)!=None) or (re.search(r'^\bachtung\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\balles',row.ingredient_name)!=None:
        #print(row)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bam besten',row.ingredient_name)!=None:
        #print(row)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)
