# %%
import pandas as pd
import numpy as np
import re

# %%
data=pd.read_csv('datasets/ingr_del_ich.csv',index_col=0)
data.shape
# Out:
# (280123, 4)

# %%
data.head()
# Out:
#    recipe_id                                        recipe_href      name  \
# 0      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      salz
# 1      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    zucker
# 2      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      mehl
# 3      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...  olivenöl
# 4      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    wasser
#
#   ingredient_name
# 0            salz
# 1          zucker
# 2            mehl
# 3        olivenöl
# 4          wasser

# %%
long_ingr=data[data['ingredient_name'].str.split().str.len()>3]
long_ingr.shape
# Out:
# (6782, 4)

# %%
long_ingr.head()
# Out:
#      recipe_id                                        recipe_href  \
# 56       11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 59       11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 99        2761  /rezept/478153/Auberginenroellchen-mit-Kaese.html
# 113      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
# 118      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
#
#                                                name  \
# 56                      pfeffer aus der mühle weiss
# 59          paprikaschote frisch rotklein gewürfelt
# 99               evtl. schwarze oliven zumgarnieren
# 113                             butter für die form
# 118  gelb flossen thunfischtranchen a ca. 150 gramm
#
#                              ingredient_name
# 56                   pfeffer der mühle weiss
# 59   paprikaschote frisch rotklein gewürfelt
# 99        evtl. schwarze oliven zumgarnieren
# 113                      butter für die form
# ...

# %%
long_ingr[long_ingr['recipe_id']==25386]
# Out:
# Empty DataFrame
# Columns: [recipe_id, recipe_href, name, ingredient_name]
# Index: []

# %%
long_ingr.reset_index(drop=True,inplace=True)

# %%
long_ingr_list=list(set(long_ingr['ingredient_name'].values.tolist()))

# %%
len(long_ingr_list)
# Out:
# 5197

# %%
long_ingr_list.sort()

# %%
long_ingr_list
# Out:
# ['*räusper hab ich noch imschrank gef',
#  '1 % 19 kcal',
#  '1 knolle inolivenöl 14 tage dunkelstellen',
#  '1 knolle knobiin öl 14 tage dunkelstehen lassen',
#  '100% saft ohne zuckerzusatz',
#  '1in dünne ringe geschnitten',
#  '1zimtstange u. 4 weitere zurdekoration',
#  '2 - 3 p',
#  '3 böden- 28 ø',
#  '4 eier herstellen[doppeltes rezept schnellerbiskuitboden',
#  '6 scheiben für diemuffinform',
#  'a.d. glas- abtropfgewicht etwa350-',
#  'aber dannist es nicht meh fettarm',
#  'aber die hungrige meuteliess es nicht zu',
#  'aber drin sein sollte schonwas',
#  'aber es geht auch normalerdunkler balsamico',
#  'aber keins ausdem supermarkt',
#  'aber nur beinormaler sahne',
#  'aber nur weres mag',
#  'aberdas ist so lecker so',
#  'abger. schale einer halbenzitrone',
#  'abger. schale einer zitrone',
#  'abgerieb. schale einerunbeh. zitrone',
#  'abgeriebende schale von 1orange',
#  'abgeriebene schale 1 zitrone',
#  'abgeriebene schale 1unbehandelten zitrone',
# ...

# %%
long_ingr.to_csv('datasets/long_ingr_data/long_ingr_001.csv')

# %%
data=pd.read_csv('datasets/long_ingr_data/long_ingr_001.csv',index_col=0)
data.shape
# Out:
# (6721, 4)

# %%
data[data['recipe_id']==44837]
# Out:
#       recipe_id                                        recipe_href  \
# 3450      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 3451      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 3452      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 3453      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 3454      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
#
#                                                    name  \
# 3450  aepfel grosse -nehme aepfelwo gut backen -scha...
# 3451  butter - eisskalt - lege inein gefierfach fuer...
# 3452      zucker dunkelbraun - gut indie tasse druecken
# 3453  cheddar kaese gehobelt -kalter kaese- kann auc...
# 3454  pie kruste-********* mach 2steuck - zum ueberd...
#
#                                         ingredient_name
# 3450  aepfel grosse -nehme aepfelwo gut backen -scha...
# 3451                                             butter
# ...

# %%
long_ingr_list=list(set(data['ingredient_name'].values.tolist()))

# %%
len(long_ingr_list)
# Out:
# 4781

# %%
long_ingr_list.sort()

# %%
long_ingr_list
# Out:
# ['*räusper hab ich noch imschrank gef',
#  '1/2zitrone',
#  '1biozitrone',
#  '1orange',
#  '1zitrone',
#  '2zitronen',
#  'a.d. glas- abtropfgewicht etwa350-',
#  'abger. schale einer halbenzitrone',
#  'abgeriebende schale von 1orange',
#  'abgeriebene zitonenschale .gibt es auch zu kaufen',
#  'abgetropft - wer mag',
#  'abgiessen-macht sichprima im dampfgarer',
#  'abrieb von einer halbenzitrone',
#  'abrieb von einer limette',
#  'abschnitte vom ende derstangen',
#  'achat - schnecken in einergemüsekräutersauce',
#  'achtung !!! siehe rezept',
#  'achtung feurig scharf -evtl. 1 chili nur',
#  'aci biber - türkischepaprikapaste siehe foto',
#  'aepfel grosse -nehme aepfelwo gut backen -schaelen',
#  'african zulu dipp - enthältauch salz',
#  'afrikanischer peppersgefüllt mit frischkäsemango/curry von orto mio',
#  'aglio olio de peperoncino',
#  'aglio olio e peperoncino',
#  'aioli 2 im kb',
#  'aioli siehe im kochbuch',
#  'al gusto mit kräutern',
# ...

# %%
data.to_csv('datasets/long_ingr_data/long_ingr_002.csv')

# %%
data=pd.read_csv('datasets/long_ingr_data/long_ingr_002.csv',index_col=0)
data.shape
# Out:
# (8304, 4)

# %%
data[data['recipe_id']==44837]
# Out:
#       recipe_id                                        recipe_href  \
# 4238      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4239      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4240      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4241      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4242      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4243      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4244      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4245      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4246      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
# 4247      44837  /rezept/278110/Apfel-Pie-Echt-Amerikanisch-mit...
#
#                                                    name  \
# 4238  aepfel grosse -nehme aepfelwo gut backen -scha...
# 4239  aepfel grosse -nehme aepfelwo gut backen -scha...
# 4240  aepfel grosse -nehme aepfelwo gut backen -scha...
# ...

# %%
# split(explode) ingredient_name with '/' and '-'

# %%
data['ingredient_name']=data['ingredient_name'].str.split('/')
data=data.explode('ingredient_name')
data.shape
# Out:
# (6991, 4)

# %%
data['ingredient_name']=data['ingredient_name'].str.split('-')
data=data.explode('ingredient_name')
data.shape
# Out:
# (8437, 4)

# %%
data=data[data['ingredient_name']!='']
data.shape
# Out:
# (8304, 4)

# %%
data=data[~data['ingredient_name'].isna()]
data.shape
# Out:
# (8304, 4)

# %%
data['ingredient_name']=data['ingredient_name'].str.strip()
data.shape
# Out:
# (8329, 4)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.head()
# Out:
#    recipe_id                                        recipe_href  \
# 0      11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 1      11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 2       2761  /rezept/478153/Auberginenroellchen-mit-Kaese.html
# 3      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
# 4      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
#
#                                              name  \
# 0                     pfeffer aus der mühle weiss
# 1         paprikaschote frisch rotklein gewürfelt
# 2              evtl. schwarze oliven zumgarnieren
# 3                             butter für die form
# 4  gelb flossen thunfischtranchen a ca. 150 gramm
#
#                            ingredient_name
# 0                  pfeffer der mühle weiss
# 1  paprikaschote frisch rotklein gewürfelt
# 2       evtl. schwarze oliven zumgarnieren
# 3                                   butter
# 4         gelb flossen thunfischtranchen a

# %%
long_ingr_list=list(set(data['ingredient_name'].values.tolist()))
len(long_ingr_list)
# Out:
# 5521

# %%
long_ingr_list.sort()

# %%
long_ingr_list
# Out:
# ['%x228 kräuter%x',
#  '%x22rachenputzer%x22aus dem glas',
#  '%x2c',
#  '* schmecktaber auch miter gut',
#  '********* mach 2steuck',
#  '*räusper hab ich noch imschrank gef',
#  '..... rinder',
#  '1',
#  '1 1',
#  '1 becher',
#  '1 davonrettichkresse',
#  '1 dose',
#  '1 dosewilliamsbirnen',
#  '1 flasche für denschweinebraten',
#  '1 flaschefür den koch',
#  '1 glasfür den koch %x2c',
#  '1 karotte',
#  '1 kleinekonserve',
#  '1 mürbteigaus dem kb',
#  '1 pck',
#  '1 rolle',
#  '1 teeloeffel vonallen',
#  '1 tl sambal oelek',
#  '1 tüteentspricht 5',
#  '1 z.b. rùf',
#  '10 blätter',
#  '10 stueckohe haut  nehme sieohne knochen',
#  '100gr. rosinen',
#  '12ib',
#  '12knödel',
#  '15 minuten bei 180 grad',
#  '15 ohne kopf',
#  '15 schalotten',
#  '15 stueck',
#  '16 dünne scheiben',
#  '16 l wasser od. suppe',
#  '1biozitrone',
#  '1grosse',
#  '1orange',
#  '1teelöffel kräuter derprovence getrocknet',
#  '1zerdrückte= 3 ganze',
#  '1zitrone',
#  '2',
#  '2 backpulver',
# ...

# %%
#

# %%
# E

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\be\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list.sort()
ingr_list

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\betwas\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list
# Out:
# ['etwas ingwer fein gehackt',
#  'etwas crema di balsamico',
#  'etwas sahne zum kochen',
#  'etwas öl für dietortenplatte',
#  'etwas öl zum anbraten',
#  'etwas fett für die form',
#  'etwas parmesan nach wunsch',
#  'etwas abrieb von einerbio',
#  'etwas fett zum anbraten',
#  'etwas fleur de sel',
#  'etwas geriebenen käse zumüberbacken',
#  'etwas braunen zucker zumbestreuen',
#  'etwas antauenlassen',
#  'etwas kalte milch zumbestreichen',
#  'etwas von der füllung fürtupfer auf der torte',
#  'etwas saft davon ca. 3el',
#  'etwas fett für die form',
#  'etwas mehl zum ausrollen',
#  'etwas mehl zum ausrollen',
#  'etwas öl für die pfanne',
#  'etwas paniermehl nach bedarf',
#  'etwas fett für dieauflaufform',
#  'etwas essig',
#  'etwas von dem pfefferfondaus dem glas zum abschmecken',
#  'etwas fett zum backen',
#  'etwas öl zum braten',
#  'etwas saft von denherzmuscheln',
#  'etwas öl zum anbraten',
#  'etwas olivenöl zum anbraten',
# ...

# %%
for index,row in data.iterrows():
    if re.search(r'^\besgeht\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bes\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\besgehen\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\berdbeeren\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Erdbeeren'

# %%
for index,row in data.iterrows():
    if re.search(r'^\berbsen\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Erbsen'

# %%
for index,row in data.iterrows():
    if re.search(r'^\beigelbe\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Ei'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bei\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Ei'

# %%
for index,row in data.iterrows():
    if re.search(r'^\beben\w+',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\beher\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# D

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bd\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list.sort()
ingr_list
# Out:
# ['dabeibitte die mengenangabe desherstellers beachten',
#  'dannselber %x22teure%x22amarenakirschen drauszaubern...keine hexerei',
#  'dany sahne nuss nougatgeschmack',
#  'dass cocktailsaucewegen der scampis sehrpassend ist',
#  'datteltomaten',
#  'datteltomaten der doseohne saft',
#  'davon 2 für diefilets',
#  'davon die schalefein geraspelt',
#  'davon die schalefein geraspelt',
#  'davon evtl. brauner zucker',
#  'dazu empfehle ich saucehollandaise',
#  'dazu gabs noch grünebuschbohnen........kartoffeln',
#  'decke mit dem embleme vom fc',
#  'deine',
#  'deko',
#  'deko',
#  'deko',
#  'deko',
#  'deko',
#  'deko erdbeere minzblattgebräunte mandeln',
#  'deko nach eigenem geschmack röschen kleineherzchen',
#  'deko scheiben vonfrühlingszwiebeln basilikumblatt',
#  'deko zum garnieren obst',
#  'deko zum verzieren für diepupse',
#  'dem teig kommenungefähr 2 raus',
#  'den bodenmit backpier auslegen',
#  'den bratensatz von denschaschliks',
#  'den dotter',
# ...

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bdörrfleisch\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# []

# %%
for index,row in data.iterrows():
    if (re.search(r'^\bdarf\b',row.ingredient_name)!=None) or (re.search(r'^\bdanke\b',row.ingredient_name)!=None):
        #print(row)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdamit\w+',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdamit\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdörrfleisch\w+',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Dörrfleisch'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdörrfleisch\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Dörrfleisch'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdill\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Dill'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdas\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(inplace=True,drop=True)

# %%
# C
# r'\bs\w+'

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bc\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list.sort()
print(ingr_list)
# Out:
# ['ca 1 esslöffel johanisbeergelee', 'ca 1 kl milch', 'ca 100 gr blaue weintraubenhalbiert', 'ca lau warme milch', 'ca. 1', 'ca. 1', 'ca. 1 handvoll frischejohannisbeeren', 'ca. 1 tl salz', 'ca. 12 min. ved', 'ca. 150 gramm puderzucker', 'ca. 350 gfrische pflaumen', 'ca. 360 gnetto', 'ca. 400 g%x2citalienischefenchelbratwurst%x2cersatzweise grobebratwürste', 'ca. 6el brauner zucker', 'ca. ein halberkürbis', 'ca. einachtel', 'ca. nussgross', 'ca.3', 'cachaca', 'cafe de paris', 'café de paris gewürz', 'candurin goldpulver hierhatte ich daskaramellfarbene', 'cappuccino', 'cappuccino', 'cappuccinopulver vonnescafé für 1 tasse', 'cappucinopuler milkaweisse schokolade von jacobs', 'captain morgan', 'caramel schokoriegel von gut', 'castel franco la rossa', 'cd mit fetziger musik z. b.mamma mia', 'champignonköpfe', 'champions mit ganzen köpfen', 'chateau de mornag wein zumsteak', 'chen knollenselleriein grobe e geschnitten', 'chen rote paprikasehr klein geschnitten', 'cherrytomaten fuer die d
# ...

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bchili con\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['chili con carne gewürz vonknorr', 'chili con carne gewürz', 'chili con carne', 'chili con carn pulver', 'chili con carne instant z.b.knorr']

# %%
for index,row in data.iterrows():
    if re.search(r'^\bchili con\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chili con carne'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bcreme fraiche\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Crème fraîche'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bcreme fraich\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Crème fraîche'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bcrème fraîche\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Crème fraîche'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bcreme fine\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Creme fine'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bcremefine\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Creme fine'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchilisosse\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chilisauce'

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'\bchiliöl\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['chiliöl mit kräutern derprovence', 'etwas chiliöl zumeinpinseln der backform', 'chiliöl mit kräutern derprovence zum anbraten', 'etwas chiliöl zumeinpinseln der backform', 'chiliöl', 'chiliöl mit kräutern derprovence']

# %%
for index,row in data.iterrows():
    if re.search(r'\bchiliöl\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chiliöl'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchilli rot\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chili rot'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchili grün\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chili grün'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchili rot\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chili rot'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchillieschote\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Peperoncino'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchili schoten\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Peperoncino'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchilischoten\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Peperoncino'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchilischote\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Peperoncino'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchillischote\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Peperoncino'

# %%
for index,row in data.iterrows():
    if re.search(r'\bchedar\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Cheddar_Kaese'

# %%
for index,row in data.iterrows():
    if re.search(r'\bcheddar\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Cheddar_Kaese'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bchampignons\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Champignon'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bchampignon\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Champignon'

# %%
# meinem kochbuch/mein kb 
# delete all in someone's kochbuch

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'\bkochbuch\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['rote sosse s. mein kochbuch', 'aioli siehe im kochbuch', 'beilage rotkohl- siehe bittein meinem kochbuch', 'paprikagemüsesauce s.rezept im kochbuch', 'rezept milchreis inmeinem kochbuch', 'geschmolzene kartoffeln steht im kochbuch', 'hefeteig siehe mein kochbuch', 'x22emis chili-würzcreme%x22 ------ siehe mein kochbuch', 'hefeteig mit gelingtricksiehe mein kochbuch', 'quicheteig herstellung siehemein kochbuch', 'steht in meinem kochbuch', 'frittierte auberginen stehen im kochbuch', 'überbackene tomaten stehen im kochbuch', 'salz/ bärlauchsalz ausmeinem kochbuch', 'warmer kartoffelsalat [sieheim kochbuch', 'würzbutter %x22café de paris%x22aus meinem kochbuch', 'schälchen hackfleischsosse- s. kochbuch %x22bolognese%x', 'kräuterbutter - sieherezept in meinem kochbuch', 'xtrick%x22siehe mein kochbuch =d', 'reis mit gebratenenreisnudeln - rezept inmeinem kochbuch']

# %%
# B

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bbrühe\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['brühe von kohlrabi kochen', 'brühe vom kohlrabi für dieschwitze', 'brühe vom gekochten huhn', 'brühe bei bedarf auch mehr', 'brühe vom garen desfleisches', 'brühe - evtl. einen teilmit weisswein ersetzen', 'brühe vom garen destafelspitzes', 'brühe - es geht aber auchmit etwas wasser u.insrentbrühe']

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbrühe\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Brühe'

# %%
for index,row in data.iterrows():
    if re.search(r'\bbrötchen\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Brot'

# %%
for index,row in data.iterrows():
    if re.search(r'\bbrot\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Brot'

# %%
for index,row in data.iterrows():
    if re.search(r'\bblätterteig\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Blätterteig'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbis\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Biskin'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbis\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbier\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Bier'

# %%
for index,row in data.iterrows():
    if re.search('^beifuss',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Beifuss'

# %%
for index,row in data.iterrows():
    if re.search('^bailey',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Baileys'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbaguette\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Baguette'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbacon\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Bacon'

# %%
# A

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bauf\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['auf keinen fall der dose', 'auf wunsch von elke egm...hier auch die zutaten unterzutaten...grins', 'auf dem foto ist jedoch florde sal', 'auf wunsch auch gemalen', 'auf einer seitemit schokolade überzogen']

# %%
for index,row in data.iterrows():
    if re.search(r'^\bapfel\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bapfel\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Apfel'

# %%
# bzw./da/damit/dann/das/davon/dazu/der/

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bdann\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['dann aber wenigerhaselnüsse nehmen', 'dann genügt auftauen an derluft', 'dann abersehr viel weniger', 'dann kann manihn toll anbraten']

# %%
for index,row in data.iterrows():
    if re.search(r'^\bdann\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bda\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbzw.\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# ei/eigelb/eiweiss

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'\beiweiss\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['eiweiss zu schnee geschlagen', 'eiweiss zu schnee schlagen', 'eiweiss von kleinen eiern', 'eiweiss - eiweiss von 8eiern', 'eiweiss - rest vom orangecurd', 'eiweiss von eben demselben', 'eiweiss geschlagen mit prisesalz', 'eiweiss von eiern gr. m', 'eiweiss von den 5 eiern', 'eischnee von 2 eiweiss']

# %%
for index,row in data.iterrows():
    if re.search(r'\beiweiss\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Ei'

# %%
for index,row in data.iterrows():
    if re.search(r'\beigelb\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Ei'

# %%
# bei/blattspinat/blätterteig/blætterteig

# %%
ingr_list=[]
for index,row in data.iterrows():
    if re.search(r'^\bblattspinat\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['blattspinat dem ofen siehe kb', 'blattspinat frisch tk gehtauch', 'blattspinat - rezept inmeinem kb', 'blattspinat gegart rezeptblattspinat dem ofen']

# %%
for index,row in data.iterrows():
    if re.search(r'^\bbei\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bblætterteig\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='blätterteig'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bblattspinat\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='spinat'

# %%
# balsamico/basilikum

# %%
ingr_list=[]
for index,row in long_ingr.iterrows():
    if re.search('^basilikum',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['basilikum in feine streifen', 'basilikumalles am besten frisch', 'basilikum frisch in streifen', 'basilikum frisch - ein paarblätter', 'basilikumblätter gross plus2 kleine', 'basilikum die blätter von 1topf', 'basilikumpesto sieherezept %x22trenette mit pesto%x', 'basilikum-nicht ganzenverbrauchen/ nach beliebig/aber dazu- reichlich']

# %%
for index,row in long_ingr.iterrows():
    if re.search('^basilikum',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='basilikum'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search('^balsamico',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='balsamico'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
long_ingr.head()
# Out:
#    recipe_id                                        recipe_href  \
# 0      11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 1      11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 2       2761  /rezept/478153/Auberginenroellchen-mit-Kaese.html
# 3      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
# 4      86439  /rezept/254348/Gelbflossen-Thunfisch-Tranchen-...
#
#                                              name  \
# 0                     pfeffer aus der mühle weiss
# 1         paprikaschote frisch rotklein gewürfelt
# 2              evtl. schwarze oliven zumgarnieren
# 3                             butter für die form
# 4  gelb flossen thunfischtranchen a ca. 150 gramm
#
#                            ingredient_name
# 0                  pfeffer der mühle weiss
# 1  paprikaschote frisch rotklein gewürfelt
# 2       evtl. schwarze oliven zumgarnieren
# 3                                   butter
# 4         gelb flossen thunfischtranchen a

# %%
# backofen/backpapier

# %%
ingr_list=[]
for index,row in long_ingr.iterrows():
    if re.search('^backpapier',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['backpapier für die form', 'backpapier%x2cporzellanschüsseln%x2c einen haarfön zumschmelzen der schokoladen', 'backpapier für das blech', 'backpapier für die form']

# %%
for index,row in long_ingr.iterrows():
    if re.search('^backofen',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
for index,row in long_ingr.iterrows():
    if re.search('^backpapier',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# auch

# %%
ingr_list=[]
for index,row in long_ingr.iterrows():
    if re.search('^auch',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['auch im bereichrussische lebensmittel', 'auch recht nett aus', 'auch4 kleine scheiben......natürlich auch für jedesandere fischfilet', 'aucherdbeeren wer die lieber mag', 'auch mit äpfeln seeehrlecker', 'auchblattspinat.... ich hatteheut nur noch rahmspinat imfroster', 'auch altbier für dieniederrheinfans', 'auch etwas mehr jedünner die pfannkuchenwerden sollen', 'auch für die form', 'auchnur mit fleisch gibt', 'auch meerrettich fürden senf', 'auch hier inmeinem kb']

# %%
for index,row in long_ingr.iterrows():
    if re.search('^auch',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
long_ingr.reset_index(inplace=True,drop=True)

# %%
# alles/aller/alle

# %%
for index,row in long_ingr.iterrows():
    if re.search('^alles',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
for index,row in long_ingr.iterrows():
    if re.search('^aller',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
for index,row in long_ingr.iterrows():
    if re.search('^alle',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
long_ingr.reset_index(inplace=True,drop=True)

# %%
# am besten

# %%
ingr_list=[]
for index,row in long_ingr.iterrows():
    if re.search('^am besten',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['am besten ist es wenn du ein 1 teeloeffel pumpkingewuerz kaufen kannst', 'am besten eherkleine festkochende', 'am besten mit fuss u. hals', 'am besten ausder schweiz', 'am besten schmeckt die sossemit den grossen', 'am bestenrand- als guteverwertungsmöglichkeit', 'am bestenrand- als guteverwertungsmöglichkeit', 'am besten einen leichtwürzigen scheibenkäse', 'am besten passenz.b. mangos', 'am bestenfrisch dem kühlregal', 'am bestenselbst frisch gemachte', 'am besten in jeweils scheiben', 'am besten in jeweils scheiben', 'am besten mitstückchen drin']

# %%
for index,row in long_ingr.iterrows():
    if re.search('^am besten',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
long_ingr.reset_index(inplace=True,drop=True)

# %%
# orange/zitrone/apfel/ananas/aprikosen/banane(n)/birne(n)/blumenkohl/butter/champignons

# %%
ingr_list=[]
for index,row in long_ingr.iterrows():
    if re.search(r'\bbutter\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
print(ingr_list)
# Out:
# ['butter für die form', 'butter zum aufmontieren inwürfeln eiskalt', 'butter u.margarine je 1/2 u', 'butter für das blech', 'butter für die form', 'butter zum backen der crepes', 'butter für die form', 'butter für die form', 'etwas butter für die form', 'butter - keine margarine', 'butter für die form', 'butter für die förmchen', 'butter - od. margarine', 'zusätzlich butter für dieflöckchen', 'butter für die form', 'weiche butter o. margarine', 'butter - gut gehäuft', 'butter für die muffin-from', 'butter zumeinfetten der form', 'butter für den reis', 'butter für die form', 'butter für die form', 'butter für die auflaufform', 'butter zum fetten derförmchen', 'butter für die form', 'zerlassene butter für dieform', 'weiche butter od. margarine', 'butter für die form', 'butter für die form', 'butter für die auflauf-form', 'butter für die form', 'butter für die form', 'butter zum ausfetten derauflaufform', 'butter für die form', 'butter für die form', 'butter - besser nochgänseschmalz', 
# ...

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\bbutter\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='butter'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search('- keine butter',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']=re.sub('- keine butter','',row.ingredient_name)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\bblumenkohl\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='blumenkohl'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\bbirne\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='birne'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\bbanane\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='banane'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\baprikosen\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='aprikosen'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\bananas\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='ananas'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\bzitrone\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='zitrone'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search(r'\borange\b',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='orange'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
# abgeriebene

# %%
abgeriebene_list=[]
for index,row in long_ingr.iterrows():
    if re.search('abgeriebene',row.ingredient_name)!=None:
        abgeriebene_list.append(row.ingredient_name)
print(abgeriebene_list)
# Out:
# ['zitrone - wenig abgeriebeneschale', 'zitrone * 1/4 nurabgeriebene schale', 'abgeriebene schale von 1unbehandelten zitrone', 'abgeriebene schale einerunbehandelten zitrone', 'abgeriebene schale von 1/2bio-zitrone', 'abgeriebene schale von 1bio-zitrone', 'abgeriebene schale einerhalben zitrone', 'abgeriebene schale von 1/2bio-zitrone', 'abgeriebene schale 1 zitrone', 'abgeriebene schale von 1unbehandelten zitrone', 'abgeriebene schale von 1bio-zitrone', 'abgeriebene schale von 1/2bio-zitrone', 'zitrone - nur dieabgeriebene schale', 'unbehandelte zitrone /abgeriebene schale', 'etwas abgeriebeneschale von 2 unbehandeltenorangen', 'abgeriebene schale von 1zitrone', 'abgeriebene schale von 1zitrone', 'abgeriebene schale von 1unbehandelten zitrone', 'abgeriebene schale von 1orange', 'abgeriebene schale von 1/2bio-zitrone', 'abgeriebene schale von 1/2bio-zitrone', 'abgeriebene schale von einerzitrone', 'abgeriebene schale einerunbehandelten zitrone', 'abgeriebene schale von 2zitronen', 'ab
# ...

# %%
for index,row in long_ingr.iterrows():
    if re.search('^abgeriebene schale von',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']=re.sub('abgeriebene schale von ','',row.ingredient_name)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
for index,row in long_ingr.iterrows():
    if re.search('^abgeriebene schale',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']=re.sub(r'abgeriebene schale ','',row.ingredient_name)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
# delete numbers

# %%
zahl_list=[]
for index, row in long_ingr.iterrows():
    if re.search('^[0-9]',row.ingredient_name)!=None:
        #print(row)
        zahl_list.append(row.ingredient_name)
print(zahl_list)
# Out:
# ['1 % 19 kcal', '6 scheiben für diemuffinform', '1 knolle knobiin öl 14 tage dunkelstehen lassen', '1 knolle knobiin öl 14 tage dunkelstehen lassen', '1in dünne ringe geschnitten', '2 - 3 p', '1 knolle inolivenöl 14 tage dunkelstellen', '1 knolle inolivenöl 14 tage dunkelstellen', '3 böden- 28 ø', '1zimtstange u. 4 weitere zurdekoration']

# %%
for index, row in long_ingr.iterrows():
    if re.search('^[0-9]',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
long_ingr.reset_index(drop=True,inplace=True)

# %%
# ^aber

# %%
for index, row in long_ingr.iterrows():
    if re.search('^aber',row.ingredient_name)!=None:
        long_ingr.drop(index,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
long_ingr.reset_index(drop=True,inplace=True)

# %%
for index, row in long_ingr.iterrows():
    if re.search('100% saft',row.ingredient_name)!=None:
        long_ingr.loc[index,'ingredient_name']='saft'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
eier_list=[]
for index, row in long_ingr.iterrows():
    if re.search(r'\beier\b',row.ingredient_name)!=None:
        #print(row)
        eier_list.append(row.ingredient_name)
print(eier_list)
# Out:
# ['eier freiland gr. m', 'eier am besten bio', 'eier - marianne war fleissig', 'eier / 1 prise salz', 'eier grösse m zimmerwarm', 'eier - leicht geschlagen', 'eier getrennt - grösse m', 'vollei sind ungewähr 5mittlere eier', 'eier für den eierstich', 'eier - am besten inbio-qualität', 'eier - bei eiernockerl', 'eier bei mir wiederenteneier', 'eier hatte enteneier gehenaber auch normale', 'eier - klasse m', 'eier freiland gr. m', 'ca. 4 grosse eier', 'eier je nach grösse', 'eier der freilandhaltung-viel selen', 'eier plus 2 eigelb', 'eier die sind beimfrühstück übrig geblieben', 'eier dotter / klar', 'eier die entleerten von obennehmen', 'eier hartgekocht in scheibengeschitten', 'eier-vinaigrette - siehe kb', 'eier freiland hart gekocht', 'eier - backeier nehmen', 'eier - als ganze', 'eier grösse m zimmerwarm', 'eier getrennt in eigelb', 'eier von hildes töchtern', 'eier freiland vonglücklichen hühnern', 'eier freiland grösse m', 'eier freiland - hart gekocht', 'eier hartgekocht in spa
# ...

# %%
for index, row in long_ingr.iterrows():
    if re.search(r'\beier\b',row.ingredient_name)!=None:
        #print(row)
        long_ingr.loc[index,'ingredient_name']='eier'
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
