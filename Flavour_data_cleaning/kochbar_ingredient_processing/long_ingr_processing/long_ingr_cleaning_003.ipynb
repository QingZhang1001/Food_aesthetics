# %%
import pandas as pd
import numpy as np
import re

# %%
data=pd.read_csv('datasets/long_ingr_data/long_ingr_004.csv',index_col=0)
data.shape
# Out:
# (7723, 4)

# %%
data.tail()
# Out:
#       recipe_id                                        recipe_href  \
# 7718      62102  /rezept/426547/Spaghetti-Puffer-mit-Kraeuterqu...
# 7719      26194                  /rezept/264389/Berliner-Brot.html
# 7720      26194                  /rezept/264389/Berliner-Brot.html
# 7721      26194                  /rezept/264389/Berliner-Brot.html
# 7722      47140                  /rezept/391537/Sauerrahm-Dip.html
#
#                                name            ingredient_name
# 7718               quark 40 % i. tr              quark 40 i tr
# 7719   mit schale gemahlene mandeln   schale gemahlene mandeln
# 7720      schwach gehäufter el zimt  schwach gehäufter el zimt
# 7721  ein paar tropfen warmeswasser  paar tropfen warmeswasser
# 7722           saft von 1/2 zitrone                    zitrone

# %%
data['ingredient_name']=data['ingredient_name'].str.strip()
data.dropna(inplace=True)
data.reset_index(drop=True,inplace=True)
data.shape
# Out:
# (7871, 4)

# %%
data.tail()
# Out:
#       recipe_id                                        recipe_href  \
# 7610      62102  /rezept/426547/Spaghetti-Puffer-mit-Kraeuterqu...
# 7611      26194                  /rezept/264389/Berliner-Brot.html
# 7612      26194                  /rezept/264389/Berliner-Brot.html
# 7613      26194                  /rezept/264389/Berliner-Brot.html
# 7614      47140                  /rezept/391537/Sauerrahm-Dip.html
#
#                                name                ingredient_name  \
# 7610               quark 40 % i. tr                          Quark
# 7611   mit schale gemahlene mandeln   mit schale gemahlene mandeln
# 7612      schwach gehäufter el zimt      schwach gehäufter el zimt
# 7613  ein paar tropfen warmeswasser  ein paar tropfen warmeswasser
# 7614           saft von 1/2 zitrone                        zitrone
#
#      ingredient_namt
# 7610             NaN
# 7611             NaN
# 7612             NaN
# 7613             NaN
# 7614             NaN

# %%
data.to_csv('datasets/long_ingr_data/long_ingr_003.csv') # 08.10.2020

# %%
data.to_csv('datasets/long_ingr_data/long_ingr_004.csv') # 12.10.2020

# %%
data.to_csv('datasets/long_ingr_data/long_ingr_005.csv') # 13.10.2020(#Z)

# %%
data=pd.read_csv('datasets/long_ingr_data/long_ingr_005.csv',index_col=0)
data.shape
# Out:
# (7384, 6)

# %%
data.tail()
# Out:
#       recipe_id                                        recipe_href  \
# 7379      62102  /rezept/426547/Spaghetti-Puffer-mit-Kraeuterqu...
# 7380      26194                  /rezept/264389/Berliner-Brot.html
# 7381      26194                  /rezept/264389/Berliner-Brot.html
# 7382      26194                  /rezept/264389/Berliner-Brot.html
# 7383      47140                  /rezept/391537/Sauerrahm-Dip.html
#
#                                name                ingredient_name  \
# 7379               quark 40 % i. tr                          Quark
# 7380   mit schale gemahlene mandeln   mit schale gemahlene mandeln
# 7381      schwach gehäufter el zimt      schwach gehäufter el zimt
# 7382  ein paar tropfen warmeswasser  ein paar tropfen warmeswasser
# 7383           saft von 1/2 zitrone                        zitrone
#
#      ingredient_namt row_ingreident_name
# 7379             NaN                 NaN
# 7380             NaN                 NaN
# ...

# %%
# Z
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bz\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['zalm',
#  'zander naturfilets',
#  'zanderfilet ..... bei mirwaren es zwei schöne grossestücke... die ich jeweilshalbiert habe',
#  'zartbitter geschmack',
#  'zartbitter je nach geschmack',
#  'zartbitter schokolade',
#  'zartbitterschokolade für inden teig',
#  'zartherbe schokolade z. b.milka',
#  'zboetker',
#  'zehe gepresst.....nicht für meine liebeedelgard',
#  'zehe knobi sehr fein gehackt',
#  'zehe knoblauch sehr feingehackt',
#  'zerbröselte waffeln die ichmit dem waffeleisen gemachthabe',
#  'zerdrueckt einer presse',
#  'zerkleinerte spaghetti',
#  'zerlasssene weisseschokolade',
#  'zerstossenerscharfer paprika',
#  'zickelfleisch ambesten die keule',
#  'ziegencamembert ausfrankreich',
#  'ziegenkäse [bevorzugt mitblüten bzw. kräutern',
#  'ziegenkäserolle pikantz.b.sainte',
#  'ziehbutter%x2c da müsst ihrmal den bäcker euresvertrauens fragen',
#  'zigeunersauce z.b. von heinz',
#  'zimmerwarme nicht zu weichebutter',
#  'zimmt bei bedarf mehr',
#  'zimt',
# ...

# %%
for index,row in data.iterrows():
    if re.search(r'^\bzu 1\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bzutat weg\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
data[data['ingredient_name']=='zutaten für 5 gläser']['recipe_href'].values
# Out:
# array(['/rezept/223646/Blaubeerkonfituere.html'], dtype=object)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bzutaten\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index,row in data.iterrows():
    if re.search(r'^\bzwiebel\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'row_ingreident_name']='Zwiebel'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bzwiebeln\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'row_ingreident_name']='Zwiebel'

# %%
# Y
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\by\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['yufka']

# %%
# X
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bx\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['x22emis chili', 'xenheiten', 'xtricksiehe mein kochbuch =d']

# %%
for index, row in data.iterrows():
    if re.search(r'^\bx22emis chili\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Chilli'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bxenheiten\b',row.ingredient_name)!=None) or (re.search(r'^\bxtricksiehe mein kochbuch =d\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# W
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bw\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['waadtländer',
#  'wacholderbeere zerdrückt',
#  'wacholderschinken',
#  'wachsbohnen',
#  'waffelröllchen fürdie kanonen',
#  'wahlweiseorangen',
#  'waldbeerenmischung',
#  'waldmeister',
#  'waldpilz sauce von knorr',
#  'waller',
#  'walnussgr',
#  'walnussöl zum anbraten desfleisches',
#  'walnüsse',
#  'warmer kartoffelsalat [sieheim kochbuch',
#  'warmer tomatensalat siehe kb',
#  'warmes wasser',
#  'washalt zu bekommen ist',
#  'wasser',
#  'wasser alternativ diehälfte rotwein',
#  'wasser für den guss',
#  'wasser für den reis',
#  'wasser für den sirup',
#  'wasser für den teig',
#  'wasser für die hefe',
#  'wasser gern mit gekörnterbrühe versetzt',
#  'wasser heiss',
#  'wasser je nach topfgrösse',
#  'wasser kann man mitmolke ersetzen',
#  'wasser lauwarm',
#  'wasser mit vegeta',
#  'wasser nicht zu kalt',
#  'wasser od. brühe',
#  'wasser od. hühnerbrühe',
#  'wasser od. suppe',
#  'wasser senf salz pfefferessig',
#  'wasser versetzt mit etwasbrühe',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bwer\b',row.ingredient_name)!=None) or (re.search(r'^\bwer\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bwenn\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bwenn\w+',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bweil\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bwas\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bware\w+',row.ingredient_name)!=None) or (re.search(r'^\bware\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bwar\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bwahlweise\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# V
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bv\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['vanille',
#  'vanille aroma',
#  'vanille aroma flüssig vondr.öttker',
#  'vanille pudding',
#  'vanille puddingpulver für milch',
#  'vanille pur [siehe meinerezepte',
#  'vanille wafers',
#  'vanille%x2c auchrumaroma',
#  'vanillearoma',
#  'vanilleback von dr. oe',
#  'vanilleeis',
#  'vanilleeis am besten selbstherstellen',
#  'vanillegeschmack',
#  'vanillepudding backfest zurkalten zubereitung',
#  'vanillepudding gibt es jetztspeziell für obstböden alsunterlage',
#  'vanillepuddingpulver',
#  'vanillepuddingpulver für milch',
#  'vanillepuddingpulver mit 100gr.',
#  'vanillepuddingpulver zumkochen für 1',
#  'vanillesahnelikör',
#  'vanillesauce',
#  'vanillesaucenpulver zumkochen für 1',
#  'vanilleschote',
#  'vanilleschote ausgekratzt alternativ vanillepulver ausder mühle',
#  'vanilleschote evtl. noch 4zum dekorieren',
#  'vanilleschote lagert',
#  'vanilleschote nur den mark',
#  'vanillesosse austrockenprodukt ohne kochen',
#  'vanillesosse ohne kochen vondr. oetker',
# ...

# %%
data[data['ingredient_name']=='von der roten spitzpaprika']['recipe_href'].values
# Out:
# array(['/rezept/437746/Reste-Geroestel-1.html'], dtype=object)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bvorgegart\b',row.ingredient_name)!=None) or (re.search(r'^\bvorher\b',row.ingredient_name)!=None) or (re.search(r'^\bvorrat\b',row.ingredient_name)!=None) or (re.search(r'^\bvorsicht\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bvon\b',row.ingredient_name)!=None:
        print(row.ingredient_name)
# Out:
# von der grünen seite
# von denabgetropften kirschen
# von dem saft der pfirsiche
# von der füllung fürtupfer auf der torte
# von der spitzpaprika
# von dem pfefferfondaus dem glas
# von der letztenernte dem garten
# von ruf
# von der roten spitzpaprika
# von den stielen gezupftekräuter
# von der möhre gewürfelt
# von 1zitrone den saft
# von alnatura
# von der ananasaus der dose
# von derkonserve
# von dem olivenöl dertomaten

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bvon meinem\b',row.ingredient_name)!=None) or (re.search(r'^\bvon meinen\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bveganer\b',row.ingredient_name)!=None) or (re.search(r'^\bvegeta\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# U
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bu\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['um das kirschwassergleichmässig auf demtortenboden',
#  'um imeierschneider zerkleinernauch für andere füllungen',
#  'umdrehungen schwarzerpfeffer der mühle',
#  'uncle bens süss sauer extragemüse',
#  'ungar. salami in scheiben',
#  'ungarische paprikapaste=nyers daralt csipöspaprika',
#  'ungarnladen.de',
#  'ungefaehr 5 tassen nehme grosse',
#  'ungesüsst',
#  'unser bohnengemüse siehe kb',
#  'ursprünglich hatte ich nochvor']

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bungefaehr\b',row.ingredient_name)!=None) or (re.search(r'^\bungesüsst\b',row.ingredient_name)!=None) or (re.search(r'^\bursprünglich\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# T
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bt\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['tabasco',
#  'tabasco geht auch ohne',
#  'tabasco gehtaber auch',
#  'taco',
#  'taco mix von don enrico',
#  'tafel schokolade zumbeispiel von milka',
#  'tafelspitz',
#  'tafelspitz vom jungbullen',
#  'tagliatelle',
#  'tagliatellezubereiten',
#  'taleggio käse in stùcken',
#  'tarteform mit demdurchmesser von',
#  'tasmanischer bergpfeffer ausder mühle',
#  'tasse himbeer balsam essigvom fass',
#  'tasse mit inhaltals mass',
#  'tasse sour cream nachdem kochen',
#  'tasse steviazucker von nordzucker',
#  'tassen reis nach geschmack',
#  'teel zitronigfruchtiges curry',
#  'teelöffel gelbecurrypaste nach geschmack',
#  'teelöffel italienischekräuter getrocknet',
#  'teig',
#  'teig für 2 böden',
#  'teig für den boden',
#  'teig für die schlutzkrapfen',
#  'teig mit sosse',
#  'teig nach meinemrezept %x22pasta',
#  'teig reicht für 4 crêpes',
#  'teig wird sonst zu fest',
#  'teig x',
#  'teigblätter',
#  'teil alkohol von mon cherioben 6 stk',
#  'teilen',
#  'tello fein',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\btl\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\btl\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\btk\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\btk\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\btipp\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\btief\w+',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# S
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bs\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['safranmayonaise a’lamanfred – rezept steht inmeinem kb',
#  'saft',
#  'saft der sauerkirschen essind',
#  'saft einer frischen zitone',
#  'saft einer halbenausgepressten limette',
#  'saft hebe ich für eis auf',
#  'saft zumbeträufeln des vogels',
#  'saftaufheben für den teig',
#  'sahne',
#  'sahne =',
#  'sahne = 2 becher',
#  'sahne geschlagen für diedeko',
#  'sahne geschlagen mit 20gzucker',
#  'sahne geschlagen nachabkühlung unterheben',
#  'sahne ich nehme immer nur500 gr sahne',
#  'sahne kochen vom herdnehmen',
#  'sahne mit mind. gehalt',
#  'sahne nach bedarf',
#  'sahne plus boullion kräuter',
#  'sahne weihenstephan nur50%f fett',
#  'sahne z.b. rama cremefine',
#  'sahne überlassen vombecher für liasion',
#  'sahneresatz',
#  'sahnesteif',
#  'sahntortenfix',
#  'saiten wie wir imschwäbischen sagen',
#  'saitenwürstchen hier sagtman',
#  'sal de flor rosmarin',
#  'salami',
#  'salami in dünnen scheiben',
#  'salami in feinen streifen',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsäuerlich\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']=re.sub(r'\bsäuerlich\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsud von den\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bsowie\b',row.ingredient_name)!=None) or (re.search(r'^\bsoviel\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsorte\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bsonst\b',row.ingredient_name)!=None) or (re.search(r'^\bsonst\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bsoll\b',row.ingredient_name)!=None) or (re.search(r'^\bsollte\w+',row.ingredient_name)!=None) or (re.search(r'^\bsolte\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bso\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bsofort\b',row.ingredient_name)!=None) or (re.search(r'^\bsofort\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bselbst gemacht\b',row.ingredient_name)!=None) or (re.search(r'^\bselbst gemacht\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bscharf\b$',row.ingredient_name)!=None) or (re.search(r'^\bscharf \...',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft einer\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bsaft einer\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft von\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bsaft von\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft von den\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bsaft von den\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft von einer\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bsaft von einer\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft einer halben\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bsaft einer halben\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft.*zitrone?\b$',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Zitrone'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft von [0-9]\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bsaft von [0-9]\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft von [0-9] bio\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsaft davon\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bsiehe\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# R
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\br\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['rachenputzeraus dem glas',
#  'radieschen frisch',
#  'radieschen frisch auseigenem anbau',
#  'radieschen frisch inscheiben schneiden',
#  'radieschen frisch instreifen geschnitten',
#  'ragout fin der dose',
#  'rahbarbar **natürlichaus dem eigenen garten',
#  'rahm',
#  'rama creme fine',
#  'rama cremefine',
#  'rama cremefine creme fraiche',
#  'rama cremefine pilze mitweissem balsamico',
#  'rama cremefine z kochen',
#  'rama cremefine zum kochenmit tomate',
#  'rama cremfine',
#  'rama cremfine 7%',
#  'rama culinesse',
#  'rama sahne',
#  'ramacreme fine',
#  'ramacremefine',
#  'rapsöl',
#  'rapsöl für die pfanne',
#  'rapsöl nit unbedingt dasbilligste',
#  'rapsöl zum anbratendes fisches',
#  'rapsöl zum anbratendes fleisches',
#  'rapsöl zum marinieren derschalotte',
#  'ras el hanout',
#  'ras el hanout gemörsert',
#  'rauchfleisch durch denfleischwolf drehen',
#  'rauchfleischod. wurst',
#  'rauchkäse m. essbarer rinde',
#  'rauten geschnitten',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\brewe\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\brest\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\braspelkäääääse magerz.b. von belight\b$',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Raspel Käse'

# %%
for index, row in data.iterrows():
    if re.search(r'^\brezept.*?kb\b$',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# Q
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bq\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['quark',
#  'quark 40 % i. tr',
#  'quark = topfen mager',
#  'quark für den knödelteig',
#  'quark für die creme',
#  'quark magerstufe',
#  'quarkcreme pflaume',
#  'quarkfein dessertcremeerdbeergeschmack von dr.oetker',
#  'quer  geschnitten',
#  'quicheteig herstellung siehemein kochbuch']

# %%
for index, row in data.iterrows():
    if re.search(r'^\bquicheteig\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Quicheteig'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bquer\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bquark\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Quark'

# %%
# P
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bp\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['pacific garnelen',
#  'paglietta',
#  'pak',
#  'palatschinken',
#  'palmin 100 % kokosfett 1würfel',
#  'palmzucker * ersatzweisebrauner zucker',
#  'pangasius filet',
#  'paniermehl  umfeuchtigkeit aufzunehmen',
#  'paniermehl für die form',
#  'paniermehl nach bedarf',
#  'paniertes fischfilet vomvortag z.b.',
#  'pankomehl für die panierung',
#  'papa arrugada',
#  'paprika',
#  'paprika cabanossi',
#  'paprika dem glasfür den farbtupfer',
#  'paprika edelsüss',
#  'paprika edelsüss nehme auchgerne das rauchpaprika',
#  'paprika edelsüss od. scharf',
#  'paprika farbe nach wahl',
#  'paprika gelb in streifen',
#  'paprika gelb kleine würfel',
#  'paprika gemischt in würfeln',
#  'paprika grün',
#  'paprika grün ...egal welchefarbe',
#  'paprika grün entkerntenthäutet kleingeschnitten',
#  'paprika grün frisch instreifen',
#  'paprika grün in kl.würfeln',
#  'paprika rot',
#  'paprika rot frisch instreifen',
#  'paprika rot in kl. würfeln',
#  'paprika rot in streifen',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bplus etwas\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bpfeffer schwarz\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='schwarz Pfeffer'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bpfeffer rot\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='rot Pfeffer'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bpfeffer grün\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='grün Pfeffer'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bpfeffer dermühle\b',row.ingredient_name)!=None) or (re.search(r'^\bpfeffer der mühle\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Pfeffer'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bpfeffer schwarz dermühle\b',row.ingredient_name)!=None) or (re.search(r'^\bpfeffer schwarz\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='schwarz Pfeffer'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bpfeffer der mühleschwarz\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='schwarz Pfeffer'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bpfeffer der mühle bunt\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='bunt Pfeffer'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bpfeffer der mühle grün\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='grün Pfeffer'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bpfeffer der mühle weiss\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='weiss Pfeffer'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bpfeffer bunt\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='bunt Pfeffer'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bpeterilie\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='petersilie'

# %%
# O
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bo\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['obst',
#  'obst frisch je nach saison',
#  'obst nach eigenem gusto',
#  'obst nach geschmack bzw.saison für die deko',
#  'obst nach wahl z.b.heidelbeeren',
#  'obst ohne saft ich hatteeine beerenmischung',
#  'obst zum belegen zbmandarinen wer möchte',
#  'obstkuchen boden',
#  'ochsenkotelett [= côte deboeuf',
#  'oel für die form',
#  'oel für die pfanne',
#  'oel von der einlage',
#  'ofenkartoffel gekocht',
#  'ofenkartoffel laut rezeptmit bild',
#  'ofenkartoffeln %x22hotpotatoes mein kb',
#  'oivenöl für die pfanne',
#  'olivdenöl für die pfanne',
#  'olive gefüllt mit paprika',
#  'oliven',
#  'oliven gefüllt mit paprika',
#  'oliven grün gefüllt mitpaprika',
#  'oliven grün mit paprikagefüllt',
#  'oliven grün ohne kern',
#  'oliven grün ohne kerne',
#  'oliven grün ohne stein',
#  'oliven in öl eingelegt ausdem antipastiregal',
#  'oliven mit paprika gefüllt',
#  'oliven schwarz',
#  'oliven schwarz in scheiben',
#  'oliven schwarz mit stein',
# ...

# %%
for index,row in data.iterrows():
    if (re.search(r'^\bolivdenöl\b',row.ingredient_name)!=None) or (re.search(r'^\boivenöl\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Olivenöl'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bolivenöl\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Olivenöl'

# %%
for index,row in data.iterrows():
    if re.search(r'^\bod\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\boptional\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bohne\b',row.ingredient_name)!=None) or (re.search(r'^\bohne\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# N
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bn\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['nacken vom schwein ohneknochen',
#  'nackenkoteletts mager',
#  'nase',
#  'natürlich füredelgard nicht',
#  'natürlich kann auch anderesgenommen werden',
#  'natürlich schwarzenpfeffer der mühle',
#  'natürlichergeschmacksverstärker',
#  'nehme aepfelwo gut backen',
#  'nehme ein bisschenmehr wen noetig',
#  'nehme ich kein paniermehlsondern mache etwasfleischfarce',
#  'nehmteinfach ein fruchtigscharfes chutney',
#  'nein nicht den partner',
#  'nektarinen marmelade',
#  'nelken im mörser zerstossen',
#  'nesquik für die dunkleteighälfte',
#  'neuterales öl',
#  'neutrales öl',
#  'neutrales öl für diepfanne',
#  'niedunkel nehmen',
#  'nimmt eingutes salz mit kräutern',
#  'nimmt man einfachden saft von den pfirsichen',
#  'noch durch einfeines siebstreichen',
#  'noch eine bananezum verzieren',
#  'noch etwas kuvertürezum verzieren',
#  'noch etwas mehl beimkneten',
#  'noch etwas rotepfefferbeeren zerstossen',
#  'noch etwaspassenden alkohol',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\bnr\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bnatürlich\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bnur\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bnicht\b',row.ingredient_name)!=None) or (re.search(r'^\bnicht\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bnach\w+',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bnach\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# M
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bm\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['madeira rot o. weiss',
#  'magere speckwürfelchen z.b.von belight',
#  'maggi',
#  'maggi fix für rouladen',
#  'maggi für nudel schinkengratin',
#  'maggi klare brühe',
#  'maggi puten topf mitfrischkäse',
#  'maggi tex mex salsa',
#  'maggi würze flüssig',
#  'maggikraut',
#  'maggiwürze',
#  'mahle ich mir immer in eineralten kaffeemühle',
#  'mais körner kleine abgetropft',
#  'mais tiefgefroren',
#  'maisstaerke ein bisschenmehr wenn es noetigist',
#  'maissyrup',
#  'majonäse livio mit limette',
#  'majoran',
#  'majoran frisch',
#  'majoran für diegarnitur',
#  'majoran od. 1',
#  'malibu',
#  'manchmal',
#  'mandarinen',
#  'mandarinen [ 2 kleine dosen',
#  'mandarinen spalten für diedeco',
#  'mandel süss gem. für denbelag',
#  'mandelblättchen',
#  'mandelblättchen = etwa einknappes päckchen',
#  'mandelblätter',
#  'mandelkrokant am bestenselber kochen',
#  'mandelmehl',
#  'mandelmehl ger. mandeln z.b.von rewe',
#  'mandeln',
#  'mandeln gemahlen [ohne haut',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\bmüssen\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmöglichst\b',row.ingredient_name)!=None) or (re.search(r'^\bmöglichst\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmuss\b',row.ingredient_name)!=None) or (re.search(r'^\bmuss\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmenge\b',row.ingredient_name)!=None) or (re.search(r'^\bmenge\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bmeins\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmein\b',row.ingredient_name)!=None) or (re.search(r'^\bmeine\b',row.ingredient_name)!=None) or (re.search(r'^\bmeinem\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmehr\b',row.ingredient_name)!=None) or (re.search(r'^\bmehr\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bmal\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bman kann\w+',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmag\b',row.ingredient_name)!=None) or (re.search(r'^\bmager\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bmache\b',row.ingredient_name)!=None) or (re.search(r'^\bmacht\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bmehl für\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Mehl'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bmehl\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Mehl'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bmankann\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bman kann\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# L
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bl\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['la s a g n e',
#  'lachs auf blattspinat vonknorr',
#  'lachs frisch mit haut',
#  'lachs frisch ohne haut',
#  'lachs geräuchert in dùnnescheiben',
#  'lachs in öl dem glas',
#  'lachs konserve in öl',
#  'lachs konserve in ölabgetropft',
#  'lachsfilet mit haut [gut',
#  'lachsfilet mit haut à',
#  'lachsforellenfilet a 250 grmit haut',
#  'lachssosse rest vom vortag',
#  'lake der grünen oliven',
#  'lake von den gewürzgurken',
#  'lamm gemischt',
#  'lammfleisch',
#  'lammfleisch frisch in stuckegeschniten',
#  'lammkeule... vom schlachtermeines vertrauens',
#  'lammkoteletts doppeltgeschnitten a 80',
#  'lammlachs frisch vomtürkischen metzger meinesvertrauens',
#  'lasagne im kb',
#  'lasagneplatten ohnevorkochen',
#  'latte macchiato getränk ausdem kühlregal',
#  'lauch',
#  'lauch den unteren teil',
#  'lauch in feinen ringen',
#  'lauch in feinen streifen',
#  'lauch in scheibchen',
#  'lauch in sehr feinenscheibchen',
#  'lauch nur das weisse',
#  'lauch stangen',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\blänglich\b$',row.ingredient_name)!=None) or (re.search(r'^\blängs halbiert\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'\bfür\w+',row.ingredient_name)!=None:
        print(row.ingredient_name)
# Out:
# von der füllung fürtupfer auf der torte
# fürcrazychili darfs gern etwasmehr sein
# herbe sahne schokolade fürdie füllmasse
# sossenpulver vanille für1
# trockener rotwein in guterqualität [sehr wichtig fürden saucengeschmack
# milch zum einweichen fürsemmel
# creme fraiche fürdeko
# für1
# für1
# salz  fürinnen
# eis zauber fürjoghurteis
# natürlich füredelgard nicht
# zwiebel grob gewürfelt fürdie backform
# blaue farbe fürdie trauben
# kuvertüre vollmilch fürdie kleinen eierschalen
# knoblauchzehen gepresst füralle knobiliebhaber
# haselnüsse gemahlen fürdie form
# frischkäse laktosefrei fürdie dekoration
# hartweizengriess [steht fürleicht körnigeteigkonsistenz
# pralinenform für15
# mandeln gemahlen.....fürdie form
# frischkäse ab jetzt fürfüllung
# gepresste knobizehen fürdie marinade
# gehacktenknoblauch genommen . füredeltraud einefrühlingszwiebel
# 1 kaktusfeige fürden glasrand
# weisse gelantine fürdie creme
# salatquick fürspeckkartoffeln z.b. ostmann
# ...

# %%
# K
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bk\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['kabeljaurückenfilet frischvon der nordsee',
#  'kaese nach wahlam stueck',
#  'kaffee',
#  'kaffeefilter',
#  'kaffir',
#  'kakao',
#  'kakao menge nach geschmack',
#  'kakaopulver',
#  'kakaopulver [evtl. mit zimtvermischen',
#  'kakaopulver für die teller',
#  'kalahari salz der mühle',
#  'kalbfleisch würfeliggeschnitten',
#  'kalbfleisch z.b nuss in  breite streifenschneiden',
#  'kalbsbrust vom metzgertasche hineinschneidenlassen',
#  'kalbshaxe in dicken scheiben',
#  'kalbskotelett frisch vommetzger meines vertrauenes',
#  'kalbsleber',
#  'kalbsrückensteaks à 180',
#  'kalt = 6 tllöslicher kaffee',
#  'kalt anrührenfür 1',
#  'kaltangerührt',
#  'kalte holzasche demkamin buche',
#  'kalte milch',
#  'kalte sahne bzw. fürallergiker schlagfix laktosefrei',
#  'kaltes fett für die form',
#  'kaltes roastbeef vom vortag[es waren noch',
#  'kaltes wasser nach bedarf',
#  'kaltes wasser nach bedarf nach',
#  'kandis für die deko ..mengenach geschmack',
#  'kandiszucker fein',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkräftig\b$',row.ingredient_name)!=None) or (re.search(r'^\bkrumeln\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkleine r\b$',row.ingredient_name)!=None) or (re.search(r'^\bkleine tasse\b$',row.ingredient_name)!=None) or (re.search(r'^\bkleine würfel\b$',row.ingredient_name)!=None) or (re.search(r'^\bkleinewürfel\b$',row.ingredient_name)!=None) or (re.search(r'^\bkleingewürfelt\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkleingewürfelt\b$',row.ingredient_name)!=None) or (re.search(r'^\bklein gehackt\b$',row.ingredient_name)!=None) or (re.search(r'^\bklein gewürfelt\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkl\b',row.ingredient_name)!=None) or (re.search(r'^\bkl. pkg. junger \b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bklein.*?tes\b',row.ingredient_name)!=None) or (re.search(r'^\bklein.*?tten\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkeine\b',row.ingredient_name)!=None) or (re.search(r'^\bkeine\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkein\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkartoffel\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Kartoffel'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkartoffeln\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Kartoffel'

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkann man\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bkann auch\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# J
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bj\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['jagdwurst von der pute',
#  'jalapeno dem eigenen garten',
#  'jalapeño grün in scheiben',
#  'jamon iberico puro bellota',
#  'jaroma',
#  'jaromakohlist besonders zart',
#  'jaromakohlkopf',
#  'java',
#  'je',
#  'je  frischen thymianudn rosmarin',
#  'je 1',
#  'je 1 bällchen vanilleeis',
#  'je 1 gr. prise muskat',
#  'je 1 kleines b',
#  'je 1 messerspitze gemahlenegewürznelken',
#  'je 1 msp. gemahlene nelken',
#  'je 1 msp. zimt',
#  'je 1 paprika rot',
#  'je 1 prise pfeffer',
#  'je 1 prise zimt',
#  'je 1 zwiebel frisch rot',
#  'je 2 gläschen pernod',
#  'je eine halbe rote',
#  'je eine mittelgrosse gelbe',
#  'je eine prise salz',
#  'je einen halben becher',
#  'je einen zweig rosmarin',
#  'je muffin 1',
#  'je nach eigenemgeschmack',
#  'je nach geschmacketwas mehr',
#  'je nach grösse',
#  'je nach grösse auch',
#  'je nach gustozartbitte',
#  'je nach konsistenz nochetwas semmelbrösel',
#  'je nach pfanne',
#  'je nach qualität',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bjeweils\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bjenach\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bje nachgrösse\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bje nachgeschmack\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bje.*?tl\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bje.*?tl\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bje nach geschmack\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bje nach geschmack\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bje nach geschmack darf esmehr sein\b',row.ingredient_name)!=None) or (re.search(r'^\bje nach geschmack auch mehr\b',row.ingredient_name)!=None) or (re.search(r'^\bje nach geschmack\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bje nach.*?gusto\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bjalfrezi\b',row.ingredient_name)!=None) or (re.search(r'^\bje etwa\b',row.ingredient_name)!=None) or (re.search(r'^\bje nach grösse\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# I
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bi\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ibiza gewürzsalz %x22mal rausdem haus%x',
#  'ibérico schinken',
#  'ibérico schinken instreifen geschnitten',
#  'ich hackte auch ein bisschenrote paperikaschote fuerfarbe',
#  'ich nehm auchgern lavendelzucker',
#  'ichsammel immer',
#  'ige tomaten',
#  'iglo del mare sind diebesten',
#  'ihnin ein netz ziehen lassen',
#  'immer noch mein eigener',
#  'imreformhaus erhältlich',
#  'indischecurrymischung zum mörsern',
#  'inermangelung einer frischenschote',
#  'ingwer',
#  'ingwer fein gehackt',
#  'ingwer fein gehackt nachgeschmack',
#  'ingwer frisch',
#  'ingwer frisch 3',
#  'ingwer frisch 4 kcal',
#  'ingwer frisch ca.  feingehackt',
#  'ingwer frisch ca. walnuss gross',
#  'ingwer frisch fein gehackt[nach geschmack',
#  'ingwer frisch grob gehackt',
#  'ingwer gleiche menge wieknoblauch',
#  'ingwer in kleine würfel',
#  'ingwer nach geschmeck mehr',
#  'ist der weinin dem man sein fleischgetaucht hat',
#  'ist eine indischemischung',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\binhalt\b',row.ingredient_name)!=None) or (re.search(r'^\binkleine\b',row.ingredient_name)!=None) or (re.search(r'^\binmeinem\b',row.ingredient_name)!=None) or (re.search(r'^\binnicht\b',row.ingredient_name)!=None) or (re.search(r'^\binsgesamt\b',row.ingredient_name)!=None) or (re.search(r'^\binstant\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bim\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\binfeine\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bin[0-9]\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bin\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# H
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bh\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['habanero',
#  'habas baby = dickebabybohnen',
#  'habedas kochwasser von denzucchinis genommen',
#  'habfrühlingszwiebeln genommen',
#  'hackbraten gewürzmischunglt. m. kb',
#  'hackbraten s. mein kb',
#  'hacken',
#  'hackennicht',
#  'hackepeter',
#  'hackepeterfertig gewürzt mitknoblauch',
#  'hackfleisch',
#  'hackfleisch  nehme amliebsten lammhack',
#  'hackfleisch %x22 half om half%x',
#  'hackfleisch 93',
#  'hackfleisch gemischt',
#  'hackfleisch gemischt bevorzuge rind',
#  'hackfleisch gemischt kannauch nur schwein',
#  'hackfleisch gemischt vommetzger meines vertrauenes',
#  'hackfleisch halb',
#  'hackfleisch rest vom pizza',
#  'hackfleisch vom metzgerdeines vertrauens',
#  'hackfleisch von der pute',
#  'hacksteak',
#  'hacoweiss für das wasser',
#  'hafer vollkornflockenbasis',
#  'haferflocken z. auststreuender backform',
#  'halbe flasche salsa sauce',
#  'halbe mettwurst in würfel',
#  'halbe pck. geriebener käse',
#  'halbe pfirsiche der dose',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bhätte\b',row.ingredient_name)!=None) or (re.search(r'^\bhätte\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bherzform\b',row.ingredient_name)!=None) or (re.search(r'^\bherz\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bhat\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bhatte\w+',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bhatte\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bhappy day\b',row.ingredient_name)!=None) or (re.search(r'^\bhart\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bhalb\b',row.ingredient_name)!=None) or (re.search(r'^\bhalbe prise\b',row.ingredient_name)!=None) or (re.search(r'^\bhalbieren\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bhabe\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bhab\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# G
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bg\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['galbaniorecchiette',
#  'galetta instant vanillepudding',
#  'galetta pudding pulver dr.oetker',
#  'gambas ohne schale gekocht',
#  'gambas ohne schale roh',
#  'gammelt nichts in derflasche',
#  'ganz fein gehobelt',
#  'ganz fein gekörnt',
#  'ganz frisch',
#  'ganz grob geriebenes hartesbrot',
#  'ganz mit haut frisch',
#  'ganz nachgeschmack',
#  'ganz wenig mozzarella',
#  'ganze haselnüsse für diegarnierung',
#  'ganze tomaten in saft',
#  'ganzerwürfel',
#  'garam masala = ind.gewürzmischung',
#  'garnelen ... dengarnelenring von lidlgenommen',
#  'garnelen frisch etwa 25',
#  'garnelen od. schrimps tk ichhatte schrimps',
#  'garnelen vakuum u. gegart',
#  'garnelenschwänze%x2c grösse13',
#  'garniren z.b. mit crema dibalsamico',
#  'gebratene entenbrust indünnen scheiben',
#  'gebratenen thunfisch',
#  'gedaut',
#  'gefiel es mir genau so',
#  'geflügel',
#  'geflügelfleischwurst',
#  'geflügelfond od.gemüsebrühe f. vegetarier',
# ...

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bgemischt\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['gemischt']

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bglas\b',row.ingredient_name)!=None) or (re.search(r'^\bglatt\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bgibt´s\b',row.ingredient_name)!=None) or (re.search(r'^\bgieb es\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bgibtes\b',row.ingredient_name)!=None) or (re.search(r'^\bgibts\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bgibt es\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bgezupft\b$',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bgeschält\b$',row.ingredient_name)!=None) or (re.search(r'^\bgespalten\b$',row.ingredient_name)!=None) or (re.search(r'^\bgeteilt in\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bgeschmack\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bgepopped\b$',row.ingredient_name)!=None) or (re.search(r'^\bgepresst\b$',row.ingredient_name)!=None) or (re.search(r'^\bgepuzt\b$',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bgemischt\b$',row.ingredient_name)!=None) or (re.search(r'^\bgemisch\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bgeht.*?ohne\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bganz fein\b',row.ingredient_name)!=None:
        #ingr_list.append(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
# F
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bf\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['fachgeschnitten fertigprodukt',
#  'farbe wieihr am liebsten mögt',
#  'farmers gemüse tk von iglo',
#  'fehlt aufdem foto',
#  'feige',
#  'feigen getrocknet in stck',
#  'fein gehackter majoran',
#  'feine crem zum kochen zb.milsani v.aldi',
#  'feine würfel',
#  'feine würstchen z.b. wiener',
#  'feingemahlenes mandeln',
#  'feinkörnig damitder kuchen etwas crunchywird',
#  'feldsalat frisch vom markt',
#  'feldsalatröschen mit etwasöl bestäubt',
#  'fenchelknollen',
#  'fenchelpfeifen von derknolle gelösst',
#  'fenchelsauce siehe rezept fenchelsuppe',
#  'ferrero rocher als deko',
#  'fertige mischung',
#  'fertige sternchenweihnachtdeko von ruf',
#  'fertiges chili con carne',
#  'fertiges grillhähnchen z.b.von %x22hahn im korb%x',
#  'fertiges pesto',
#  'fertiges vanille',
#  'fertigproduktzb. von pfanni',
#  'feste printe',
#  'festes weisses fischfiletnach geschmack',
#  'festkochend',
#  'festkochende kartoffeln inkleinen würfeln',
#  'feta',
# ...

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfür\b',row.ingredient_name)!=None:
        #ingr_list.append(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'\bfisolen\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']='Grüne bohnen'

# %%
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\bfett\b',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['fett ',
#  'fett  derformen',
#  'fett für das backblech',
#  'fett für das blech',
#  'fett für das mufinblech',
#  'fett für das waffeleisen',
#  'fett für den formboden',
#  'fett für die auflaufform',
#  'fett für die backform',
#  'fett für die fettpfanne',
#  'fett für die form',
#  'fett für die förmchen',
#  'fett für die muffinform',
#  'fett für die pfanne',
#  'fett für die springform',
#  'fett für die tarteform',
#  'fett u. mehl für die form',
#  'fett u. paniermehl für dieform',
#  'fett zum anrösten zb rama',
#  'fett zum einfetten der form',
#  'fett zum einfetten derauflaufform']

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfalls\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfett\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']='Fett'

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfertig.*?t\b',row.ingredient_name)!=None:
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfein.*?te\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']=re.sub(r'\bfein.*?te\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfein.*?en$\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bfein.*?t\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']=re.sub(r'\bfein.*?t\b','',row.ingredient_name)

# %%
# E
ingr_list=[]
for index, row in data.iterrows():
    if re.search(r'^\be\w+',row.ingredient_name)!=None:
        ingr_list.append(row.ingredient_name)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ebuttercreme siehe meineanderen rezepte',
#  'eckerlkäs',
#  'edamer gerieben',
#  'edamer od. anderer käse',
#  'edeka',
#  'edelgard bitte verzeih mir',
#  'egerlinger',
#  'eier',
#  'eierlikör in den teig',
#  'eierstich frisch gemacht inkleine würfel geschnitten',
#  'eigelegtin öl mit kräutern',
#  'eiklar',
#  'eimach',
#  'ein bisschen für den fisch',
#  'ein blech für 12 muffins',
#  'ein geschenk',
#  'ein gestr. teel. salz',
#  'ein halber tlgerösteter knoblauch ausder dose',
#  'ein mittleres sieb war knappgefüllt',
#  'ein paar blätter kopfsalat',
#  'ein paar blätter pilzkraut',
#  'ein paar chiliflöckchennach gemschmack',
#  'ein paar frische erdbeerenzum verzieren',
#  'ein paar ganze haselnüsse',
#  'ein paar grob gehacktepistazien',
#  'ein paar kirschtomaten ',
#  'ein paar scheibchen speckdurchwachsen',
#  'ein paar schluckemineralwasser mitkohlensäure',
#  'ein paar spritzer maggi',
#  'ein paar spritzer tabasco',
# ...

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevent\.',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevent\.','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bev\.',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bev\.','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevt\.',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevt\.','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevtl',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevtl','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\beventuell\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\beventuell\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\betwas',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'^\betwas','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\betwa',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'^\betwa','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\betw\.',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\betw\.','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevtl\.\b',row.ingredient_name)!=None):
        print(row.ingredient_name)
        #data.loc[index,'ingredient_name']=re.sub(r'\bevtl\.\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevtl\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevtl\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevtl\. \b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevtl\. \b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bevtl\. [0-9]+\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevtl\. [0-9]+\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bexport\b',row.ingredient_name)!=None):
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bein rest\b',row.ingredient_name)!=None) or (re.search(r'^\bein schuss\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bein wenig\b',row.ingredient_name)!=None:
        data.loc[index,'ingredient_name']=re.sub(r'\bein wenig\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\betwa [0-9]+\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\betwa [0-9]+\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\betwas\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\betwas\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\bevtl\. etwas\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bevtl\. etwas\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\beventuell etwas\b',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\beventuell etwas\b','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if re.search(r'^\beventuell etwas\w+',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub('eventuell etwas','',row.ingredient_name)

# %%
for index, row in data.iterrows():
    if (re.search(r'\bein muss\b',row.ingredient_name)!=None) or (re.search(r'\beigene tk\b',row.ingredient_name)!=None) or (re.search(r'\beigenanbau\b',row.ingredient_name)!=None) or (re.search(r'\beigeneherst\b',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if (re.search(r'^\bextra\b',row.ingredient_name)!=None) or (re.search(r'^\bextra\w+',row.ingredient_name)!=None):
        #print(row.ingredient_name)
        data.drop(index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
for index, row in data.iterrows():
    if re.search(r'\bzu.*?en\b$',row.ingredient_name)!=None:
        #print(row.ingredient_name)
        data.loc[index,'ingredient_name']=re.sub(r'\bzu.*?en\b','',row.ingredient_name)
