# %%
import pandas as pd
import numpy as np
import re

# %%
three_ingr_df=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/en_three_ingr_001.csv',index_col=0)
three_ingr_df.shape
# Out:
# (3047, 2)

# %%
three_ingr_df
# Out:
#                                          parse_ingr  \
# 0                                            kapern
# 1     rindsschnitzelod. dünngeschnittenerrostbraten
# 2                                              hefe
# 3                                      stck. ingwer
# 4                       neutrales öl z.b.maiskeimöl
# ...                                             ...
# 3042                                  hähnchen ohne
# 3043                maggi helle sosse%xbasissosse%x
# 3044                obstkuchenboden entwedergekauft
# 3045                               kräuter gemischt
# 3046                       knoblauch salz vermischt
#
#                                  en_ingr
# 0                                  caper
# 1                                   beef
# 2                                  yeast
# 3                            pcs. ginger
# 4                               corn_oil
# ...                                  ...
# 3042                             chicken
# ...

# %%
ingr_list=[]
for index,row in three_ingr_df.iterrows():
    if re.search(r'^d',row.en_ingr)!=None:
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))    
ingr_list.sort()
ingr_list
# Out:
# ['daisy',
#  'dandelion',
#  'date',
#  'dates',
#  'deer',
#  'deer meat',
#  'dessert sauce vanilla',
#  'diamond ice magic fruits',
#  'dickmanns caramel',
#  'dickmanns coco cabana',
#  'dill',
#  'dill -',
#  'dill,parsley,tarragon',
#  'dip sauces',
#  'disaronno',
#  'do not rub cucumber',
#  'dough',
#  'dough crépes',
#  'dough light',
#  'dressing',
#  'duck',
#  'dumplings',
#  'dumplings boiled potatoes',
#  'dumplings pfanni']

# %%
three_ingr_df[three_ingr_df['en_ingr']=='cake pop']
# Out:
#     parse_ingr   en_ingr
# 628   cake pop  cake pop

# %%
whole_change_dict={'chicken meat':'chicken',
    'chanterelle water':'chanterelle','cheese herbs':'herb_cheese','chicken in':'chicken',
    'cambert':'camembert_cheese','cappucchino':'cappuccino','cappuchino':'cappuccino',
    'cake magic% xsauermelk% x by lumara':'cake_magic','cake magic strawberry lumara':'cake_magic',
    'cake cream':'cream','cake icing% xlemon% x':'lemon_icing','cake leftovers e.g. biscuit cake':'cake',
    'cyrry':'curry','cutlets':'meat','curry paste red madras':'curry_paste','curry red hot':'curry','curry spice':'curry','curryketchup':'curry_ketchup',
'cucuma turmeric powder':'cucuma_turmeric','curry maharadja':'curry','curry ketchup chili':'curry_ketchup',
'cream cremafine':'cremafine','crush mustard seeds':'mustard','crème légère herbs':'herb_creme_legere',
'cookies chocolate chips':'chocolate_cookie','cream cocoa':'creme_de_cacao',
'coconut rusks normal rusks':'coconut_zwieback','comb chop marinated':'lamb','comb roast bones':'roasted_pork',
'coconut confectionery% xc zbraffaellos':'coconut_chocolate','coconut liqueur malibu':'coconut_liqueur',
'citro-back':'citro_back','cocoa e.g.':'cocoa','coconut / coconut flakes':'coconut','coconut balls raffaello':'coconut_chocolate',
'chocolate chips white':'chocolate','chocolate toblerone':'chocolate','chocolate tart cream':'chocolate_herb_cream',
'chocolate white':'chocolate','chocolate,cereal':'chocolate_cereal','chocolate chip cookies':'chocolate_cookie',
'chocolate crispy cereal':'chocolate_cereal','chocolate crispy muesli':'chocolate_cereal',
'chili threads':'chili','chilies':'chili','chocolate beans':'chocolate','chocolate covered wafer rolls':'chocolate_waffle',
'chili sauce tomatoes':'chili_tomato_chili','chili spice oil s.':'chili_spice','chili sweet and sour sauce':'sweet_sour_chili_sauce',
'chili fuego':'chili','chili pod':'chili','chili pods':'chili','chili pul piber':'chili','chili red':'chili',
'chicken salad im':'chicken_salad','chicory perennials':'chicory','chilies':'chili',
'chicken medallions and turkey if necessary':'chicken','chicken ministeaks':'chicken','chicken minute schnitzel':'chicken',
'cherry groats':'rote_grütze','chervil bulbs':'chervil','chicken leg breast':'chicken',
'champions':'agaricus','cheese cream cream flavor':'cream_cheese','cherry date tomatoes':'cherry_tomato',
'cappucchino viennese melange':'cappucchino','cappuchino powder':'cappuchino','champions brown':'agaricus',
'aubergine':'eggplant','alpro soya cuisine':'soy_cuisine','alpro soy cuisine':'soy_cuisine',
'almond pudding powder':'almond_pudding','almond biscuits amaretto':'amaretti_di_saronno',
'butter greasing':'butter','buffer sugar':'sugar','brussel_sprout':'brussels_sprout',
'boiled beef':'boiled_beef','barbarian duck breast magretde canard':'duck','biscuit base':'sponge_cake',
'biscuit orange biscuit':'orange_biscuit','black spanish olives':'olive','blood orange':'orange',
'blue cheese goat':'blue_cheese','boiled ham':'ham','boiled ham rim':'ham','boiled potato':'potato',
'bread dumpling bread':'bread','bread flour':'wheat','bread spread herbs':'herb_spread',
'bruchettina im':'bruchettina','brunch casual herbs':'brunch_herb','brunch cream cheese paprika peppers':'paprika_pepper_cream_cheese',
'brunch paprika pepperoni':'paprika_pepper_cream_cheese','brunch spread paprika peppers':'paprika_pepper_cream_cheese',
'brunch paprika chilli':'chili_cream_cheese','brunch x':'brunch_spread','brunch “sweet thai chili% x':'sweet_chili_cream_cheese',
'butter_herb':'herb_butter','café de paris':'cafe de paris'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in three_ingr_df.iterrows():
    if re.search(r'^p',row.en_ingr)!=None:
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))    
ingr_list.sort()
ingr_list
# Out:
# ['pacific prawns',
#  'pad thaii sauce',
#  'padadies ceme vanilla',
#  'pak choi',
#  'pak choi mustard cabbage',
#  'pall potatoes',
#  'palm heart',
#  'palm palm oil',
#  'palmin',
#  'palmin coconut oil',
#  'pamigianoreggiano',
#  'pan_loaf',
#  'panettone italian cake',
#  'pangasius',
#  'papaya',
#  'paprika',
#  'paprika antipasti',
#  'paprika noble sweet ... salt',
#  'paprika noble sweet hungary',
#  'paprika orange',
#  'paprika paste acir beaver',
#  'paprika paste turks',
#  'paprika powder',
#  'paprika powder sweet',
#  'paprika powder% xla vera% x',
#  'paprika pulp = piros arany',
#  'paprika pulp sevkoc',
#  'paprika sausage cuts',
#  'paprika stuffed olives',
#  'paprika sweet',
#  'paprika yellow',
#  'paprika% xsweet pepper% x',
#  'paprika_cheese',
#  'paprika_pepper_cream_cheese',
#  'paprika_powder',
#  'paris potatoes / gouged ball cutters',
#  'parma_ham',
#  'parmean',
#  'parsley',
#  'parsley,chili,salt',
#  'parsnip',
#  'parüren roe deer',
# ...

# %%
three_ingr_df[three_ingr_df['en_ingr']=='miracel whip legere']
# Out:
#                parse_ingr              en_ingr
# 2920  miracel whip légère  miracel whip legere

# %%
whole_change_dict={'miracle whip majonaise':'mayonnaise','miracle whip mayonnaise':'mayonnaise',
'minisalimi bifi':'beef_snack','muesli% x crispy chocolate brittle':'muesli',
'marinate soy sauce':'soy_sauce','mayonnaisse':'mayonnaise','minimar bars':'chocolate_bar',
'maggie fix rolls':'Fix_für_Rouladen','maggi wort':'spice','maggi texicana salsa':'salsa',
'maggi spice meat':'spice','maggi no. seasoning':'spice','maggi light sauce% x base sauce% x':'light_sauce',
'maggi fix hunter schnitzel':'Fix_für_Jäger_Sahne_Schnitzel','maggi hot seasoning sauce':'hot_spice',
'maggi farmers pot':'Fix_für_Bauern_Topf','maggi fix bolognese':'Fix_für_Spaghetti_Bolognese',
'marjoram - as substitute':'marjoram','melon kiwi':'kiwi','maggi broth':'broth',
'macis = mace':'mace','macis flowers':'mace','magarine':'margarine','margerine glaze':'margerine',
'lollipop silicone mold flowers':'candy','lovage - maggi herb':'lovage',
'liquid smoke hickory':'smoke_hickory','liquid wort maggi':'liquid_spice','little bit my vegetable stock powder':'vegetable_broth',
'kremefine':'cremefine','kohlrabi':'cabbage turnip','lemon flavor back':'citron_back',
'italian style pasta salad':'noodle_salad','knuckle pork knuckle)':'pork','krakauer sausages -':'krakauer_sausage',
'irish butter ice':'butter','italian vegetable also':'vegetable','italian pasta sauce fp':'pasta_sauce',
'honey acatzia':'honey','hot chili':'chili','ice water binding':'water','icing powder':'icing',
'herbs pizza seasoning':'herb_spice','herbs provence':'herbes_de_provence','heureka spice herbaria':'heureka_spice',
'herbs de provence':'herbes_de_provence','herbs italian arttk':'italian_herb','herbs mediterranean':'mediterranean_spices',
'herbal herbs':'herb','herbal iglo':'herb','herbs créme fraîche':'herb_creme_fraiche',
'herb marinade':'herb','herb spice% xcafe deparis% x':'cafe_de_paris','herb vinegar tarragon':'herb_vinegar,tarragon',
'herb de provence':'herbes_de_provence','herb herbs k':'herb','herb igloo':'herb','herb sauce e.g. maggi':'herb_sauce',
'hanuta cuts':'hanuta','head radicchio':'radicchio','hellensossenbinder':'sauce_thickener','hellensossenbinder':'sauce_thickener',
'hake a.':'hake','ham filling':'ham','ham filling rana':'ham','hamburger rolls ones':'bread',
'grilled chicken spice / parika noble sweet':'chicken_spice','grümmel-kandis feinerkandis':'sugar',
'gorgonzola spinach':'gorgonzola_cheese,spinach','gravad salmon herb mustard sauce':'salmon,mustard',
'garam_masala':'garam_marsala','grains seeds':'grains','gold powder candurin':'gold powder',
'fond beef':'beef','french broad beans':'french_bean','fruits strawberries':'strawberry',
'deer meat':'deer','dessert sauce vanilla':'vanilla_sauce','dill -':'dill','dough crépes':'crepes',
'dough light':'dough','fatty butter oils':'butter_oil','fettucine':'fettuccine_pasta',
'fix pasta and ham gratin':'Fix_für_nudel_schinken_gratin','flakes butter':'butter','flakes yogurt butter':'yogurt_butter',
'flash casting':'blitzguss','fleckerl austrian noodle':'fleckerl_pasta','fleischglace':'broth',
'flesh':'meat','flomenschmalz':'lard','flor de atlântico':'salt','flour butter':'butter',
'flour':'wheat','flour - lots magnesium':'spelt','flour ...':'bread_crumbs','fold herb':'herb'}

# %%
for k,v in whole_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in three_ingr_df.iterrows():
    if re.search(r'^p',row.en_ingr)!=None:
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))    
ingr_list.sort()
ingr_list
# Out:
# ['pacific prawns',
#  'pad thai sauce',
#  'padadies ceme vanilla',
#  'pak choi',
#  'pak_choi',
#  'pall potatoes',
#  'palm heart',
#  'palm_oil',
#  'pan_loaf',
#  'panettone',
#  'pangasius',
#  'papaya',
#  'paprika',
#  'paprika antipasti',
#  'paprika paste acir beaver',
#  'paprika paste turks',
#  'paprika powder',
#  'paprika powder sweet',
#  'paprika powder% xla vera% x',
#  'paprika pulp = piros arany',
#  'paprika pulp sevkoc',
#  'paprika,olive',
#  'paprika_cheese',
#  'paprika_pepper_cream_cheese',
#  'paprika_powder',
#  'paprika_sausage',
#  'parma_ham',
#  'parmean',
#  'parmesan_cheese',
#  'parsley',
#  'parsley,chili,salt',
#  'parsnip',
#  'pasta',
#  'pasta dough',
#  'pasta mia trinangoliharlequin',
#  'pasta spice',
#  'pasta_dough',
#  'pasta_sauce',
#  'pastis',
#  'pastry magic [from sparpremium',
#  'pastry magic by johanna maier',
#  'pea',
#  'pea,carrot',
#  'pea,paprika',
#  'peach',
#  'peach halves',
#  'peaches',
#  'peanut butter',
# ...

# %%
three_ingr_df[three_ingr_df['en_ingr']=='purple hearts']
# Out:
#             parse_ingr        en_ingr
# 839  milka lila herzen  purple hearts

# %%
whole_change_dict={'purple hearts':'chocolate','quince jelly s.kb vonheidibirn':'quince_jelly','quittengelee':'quince_jelly','quick sandwichcremea&#39;la manfred':'cream',
'pumpkin hokkaido':'hokkaido_pumpkin','pumpkin seed oil':'pumpkin_seed_oil',
'pulp tomato':'tomato','pumpernickel bread':'rye_bread','pumpkin hokaido derorangerot':'hokkaido_pumpkin',
'prunes stone':'prune','pudding powder':'pudding','pul beaver':'chili','pulbiber':'chili',
'prosciutto cotto - boiled ham':'prosciutto_ham','prosciutto italian ham air-dried':'prosciutto_ham',
'prickly pear [only juice':'pear_juice','prinzenrolle biscuits chocolate biscuits':'chocolate_biscuit',
'poultry stock':'poultry_chicken','powder rum':'rum','pr. sugar':'sugar','preserving sugar':'sugar',
'poultry liver chicken':'chicken_liver','poultry meat':'poultry','poultry sausage garlic':'poultry_garlic_sausage ',
'poppy back':'mohn_back','poppy-baked schwartau':'mohn_back','pot meat':'meat',
'plumb':'plum','pod paprika':'chili','pomegranate syrup nareksisi':'pomegranate juice',
'plum groats cinnamon':'plum,cinnamon','plum jam apple':'plum_jam,apple','plums plums':'plum',
'pizza seasoning':'pizza_spice','pk. feta':'feta_cheese','pkg. quimi':'quimi','plantains / plantanes':'plantain',
'piri piri oil':'piri_piri','pita bag wholemeal':'pita_bread','pizza dough diamond':'pizza_dough',
'pink berries':'rose_pepper','pink pepper berries':'rose_pepper','pink_peppercorn':'paprika',
'pineapple and apple':'pineapple,apple','pineapple juice-the':'pineapple juice',
'piel de sapo melon':'melon','pimenton ahumado':'pimento','pine pumpkin seeds':'pumpkin_seed',
'piccolini farfalle':'farfalle_pasta','pickled peppers':'bell_pepper','pickles':'gherkin',
'pepperoni% xc':'chili','percorino':'pecorino_cheese','pfffer':'pepper','philadelphia cheese':'cream_cheese',
'pepper white':'white_pepper','pepper% xc allspice':'pepper,allspice','pepperoni red cream cheese filling':'chili_cream_cheese',
'pepper salt sugar':'pepper,salt,sugar','pepper tasmanian':'tasmanian_pepperberry','pepper up':'pepper',
'pepper red':'chili','pepper salt':'pepper,salt','pepper salt paprika powder':'pepper,salt,paprika_powder',
'pepper marinade':'pepper','pepper orange pepper':'bell_pepper','pepper parsley':'pepper,parsley',
'pepper /':'pepper','pepper and salt':'pepper,salt','pepper herbs':'pepper_herb','pepper herbs derprovence':'pepper_herb',
'peperonis red cream cheese filling':'chili_cream_cheese','pepper ... spices':'pepper',
'peperoncini':'chili','peperoncino aglio olio-dried':'peperoncino_aglio_olio',
'penne al peperoncino':'peperoncino_aglio_olio','penne rigate':'penne_pasta','penne rigate “bambini':'penne_pasta',
'peas goods':'pea','peas u. carrots':'pea,carrot','peas u. paprika':'pea,paprika','peas yellow':'pea',
'pears poached invanilla syrup':'pear,vanilla_syrup','peas -tk-ware':'peas','peas carrots':'pea,carrot',
'pad thaii sauce':'pad thai sauce','pak choi mustard cabbage':'pak_choi','palm palm oil':'palm_oil',
'palmin':'coconut_oil','palmin coconut oil':'coconut_oil','pamigianoreggiano':'parmesan_cheese',
'panettone italian cake':'panettone','paprika noble sweet ... salt':'sweet_paprika,salt',
'paprika noble sweet hungary':'sweet_paprika','paprika orange':'bell_pepper','paprika sausage cuts':'paprika_sausage',
'paprika stuffed olives':'paprika,olive','paprika sweet':'paprika_powder','paprika yellow':'bell_pepper',
'paprika% xsweet pepper% x':'paprika_powder','paris potatoes / gouged ball cutters':'potato',
'parüren roe deer':'deer','passed jam jam':'jam','passed juice':'juice','pasta conchiglie':'conchiglie_pasta',
'pasta dough ad refrigerated counter':'pasta_dough','pasta made durum wheat semolina':'pasta',
'pastis de marseille [aniseed schnapps]':'pastis','pasta mia trinangoliharlekin':'pasta',
'pasta ticolore fusili':'fusilli_pasta','patros mediterane herbs':'mediterranean_herb','pck vanilla sugar':'vanilla_sugar',
'pcs. ginger':'ginger','pear-dusters boviste':'stump_puffball','pear-wedge dessert':'pear_dessert',
'pearl onions / silver onions':'onion'}

# %%
for k,v in whole_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
part_change_dict={'chicken seasoning':'chicken_spice','herb butter':'herb_butter',
'dickmanns':'dickmanns','miracel whip':'miracle_whip','miracel wip':'miracle_whip',
'miracle whip':'miracle_whip','miracle wip':'miracle_whip','paprika paste':'paprika_paste',
'paprika powder':'paprika_powder','paprika pulp':'paprika_pulp','pastry magic':'pastry magic',
'pie crust':'pie_crust','pimientos':'piquillo_pepper','pita bread':'pita_bread',
'poppy seed':'poppy_seed','potato dumplings':'kartoffel_knödel','potato flour':'potato_flour',
'poultry seasoning':'chicken_spice','prosecco':'prosecco','qimiq':'qimiq','quark':'quark',
'quimiq':'qimiq'}

# %%
def replace_ingr(k,v,ingredient):
    if re.findall(k,ingredient):
        return v
    else:
        return ingredient

# %%
for k,v in part_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
# ^pesto,^potatoes,

# %%
for index,row in three_ingr_df.iterrows():
    if re.search(r'^potatoes',row.en_ingr)!=None:
        #print(row.en_ingr)
        three_ingr_df.loc[index,'en_ingr']='potatoes'

# %%
for index,row in three_ingr_df.iterrows():
    if re.search(r'^pesto',row.en_ingr)!=None:
        #print(row.en_ingr)
        three_ingr_df.loc[index,'en_ingr']='pesto'

# %%
delete_words=['boiled','export','greasing','in','fix','omegrown','clear','own','add','pacific','pall','halves',
'stuck','zbunter','mild-spicy','piece','pinch','plenty','ringlets']

# %%
def del_words(ingredient):
    no_words=' '.join([c for c in ingredient.split() if c not in delete_words])
    return no_words

# %%
three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:del_words(x))

# %%
delete_parts=['can be added','to boil','extract fox','in glasses','photo edited']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:del_part(part,x))

# %%
whole_delete=['but','butaris','chili shaker','core housing','do not rub cucumber','egg vegetables','fake leg',
'fischer','fol epi extremely fine','fries','fry liquid','grams /','giottos on top it','master',
'maggi-fix', 'pearls','pearls etc.','peterle / b','pickled pickle preserve.','pie spice see',
'piping bag star spout','pizzakit','porcelain','pot cake help','potato gratin sauce is in',
'powder','prescriptionist']

# %%
three_ingr_df=three_ingr_df[~three_ingr_df['en_ingr'].isin(whole_delete)]
three_ingr_df=three_ingr_df[three_ingr_df['en_ingr']!='']
three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].str.strip()
three_ingr_df.dropna(inplace=True)
three_ingr_df.reset_index(drop=True,inplace=True)
three_ingr_df.shape
# Out:
# (3022, 2)

# %%
three_ingrs=list(set(three_ingr_df['en_ingr'].values.tolist()))
len(three_ingrs)
# Out:
# 1259

# %%
# change chili

# %%
for index,row in three_ingr_df.iterrows():
    if re.search(r'chilli',row.en_ingr)!=None:
        # print(row.en_ingr)
        three_ingr_df.loc[index,'en_ingr']=re.sub('chilli','chili',row.en_ingr)

# %%
# check the last time

# %%
ingr_list=[]
for index,row in three_ingr_df.iterrows():
    if re.search(r'^z',row.en_ingr)!=None:
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))    
ingr_list.sort()
ingr_list
# Out:
# ['zander', 'zaziki', 'zucchini', 'zulu_dipp', 'zwieback']

# %%
three_ingr_df[three_ingr_df['en_ingr']=='wine spirit% pharmacy']
# Out:
#                    parse_ingr                en_ingr
# 2435  weingeist % derapotheke  wine spirit% pharmacy

# %%
whole_change_dict={'zaziki':'tzatziki','williams christ pears':'pear','wooden board apple':'apple','xin fu noodles':'noodle',
'vegetable cream on stock':'vegetable_cream','wheat grain north':'wheat','white tiger prawns':'prawn',
'turkish yogurt':'turkish_yoghurt','turmeric pasta water':'turmeric_pasta',
'tomatoes /':'tomato','turkish damlasakiz-turkish barely aces':'falim_kaugummi_damla',
'sweet soy sauce':'soy sauce','sweet spicy paprika':'paprika','tahini sesame':'tahini',
'sweet red paprika':'paprika','sweet rols hazelnut':'hazelnut','sweet sour sauce':'sweet_sour_sauce',
'sweet_sour_chili':'sweet_sour_chili_sauce','sweet pepper powder':'paprika','sweet peppers':'bell_pepper',
'sweet chili sauce':'chili_sauce','sweet corn':'corn','sweet paprika':'paprika',
'summer blossom honey':'honey','summer grits':'fruit','summer vegetable tube':'vegetable','supreme corn chickens':'chicken',
'sugar edge':'sugar','sugar loaf salad chiccore':'cabbage','sugar to':'sugar',
'sud cauliflower':'cauliflower_stock','sud pickle':'gherkin','sud schäufele':'schäufele',
'still mineralwater':'water','strawberry morocco':'strawberry','strudel pastry sheets':'phyllo_dough',
'sprinkle chocolate z':'chocolate','sprinkle herbs% xspring herbs% x':'herb','steirischerberg cheese':'cheese',
'spoon bicuits':'ladyfinger','spoon bisquit':'ladyfinger','spring salad':'vegetable',
'spinach igloo':'spinach','spinach pellets':'spinach','spinach ricotta tortelloni':'spinach_ricotta_tortellini',
'spinach blub':'spinach','spinach cream':'cream_spinach','spinach happens':'spinat_passiert',
'spices-pepper':'pepper','spiced broth milk':'broth,milk','spinach also tk ware':'spinach',
'spice speculoos':'spekulatius_spice','spiced ketchup shashlik hela':'spice_ketchup',
'spanish smoked paprika':'paprika','spatzln':'spaetzle','spice aglio olioe´peperocino':'peperoncino_aglio_olio',
'smoked salt':'salt','soy yogurt':'soy_yoghurt','spanish paprika smoke flavor':'paprika',
'smoked blood sausage':'smoked_sausage','smoked cured ham in double pack':'smoked_ham',
'silesian cucumber':'gherkin','single malt whiskey':'whiskey','small% xc orichiette':'orecchiette',
'seasoning':'spice','seasoning meat':'meat_spice','seasoning salt':'spice_salt','seasoning syrup':'spice_syrup',
'seasoned salt chili':'salt_chili_spice','seasoned spinach igloo':'seasoned spinach',
'sea-salt':'sea','seasoned potato':'kartoffelspalten_spice','seasoned salt':'herb_salt',
'schwartau vanilla back':'vanilla_back','schweppes californian citrus summer':'lemon_soft_drink',
'salad% xlollo rosso% x':'lettuce','sauce heinz':'exotic_sauce','sauce maggi':'sauce','sausage salad sausage':'salad_sausage',
'ramaculinesse]':'culinesse','rama cremefine':'cremefine','raspberry aperitiv vinegar':'raspberry_vinegar',
'raspberry fruit spread':'raspberry_spread','raspelkäse gratinkäse':'cheese','ratatouille powder picture':'Fix_fur_ratatouille',
'raz hanout':'ras_el_hanout','razor tip nutmeg':'nutmeg','ready-to-bake poppy seed filling':'poppy_seed',
'real lavender lavender flowers':'lavender','reblochon de savoie':'reblochon_cheese','red beans':'kidney_bean',
'red beet':'beet','red berries':'berry','red berry':'berry','red cake topping, strawberry flavor':'strawberry_topping',
'red curry paste':'curry_paste','red fruit':'fruit','red juice':'juice','red tortelloni radicchio':'cabbage',
'redpepper':'bell_pepper','rib':'pork','ribisel currants':'currant',
'ribisel-marmelade = red currant jam passed through':'red_currant_jam','rice porridge sugar':'rice_porridge,sugar',
'rice thailand':'rice','rice waffles - st':'waffle','royal pearl black':'black_rice',
'rainbow trout':'trout'}

# %%
for k,v in whole_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
part_change_dict={'red apple':'apple','red cabbage':'cabbage','smoked ham':'smoked_ham','vanilla dessert sauce':'vanilla_sacue'}

# %%
for k,v in part_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
delete_parts=['all kinds','- non-diabetics can course']

# %%
for part in delete_parts:
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:del_part(part,x))

# %%
whole_delete=['rama','red jam to put together','refractory molds','shaggy','silicone baking mat silpat',
'sugar coleur','sugar flowers','tahiti','to be replaced','vegetable slicer','wide coated',
'winter magic fa. grafschafter','wine spirit% pharmacy']

# %%
three_ingr_df=three_ingr_df[~three_ingr_df['en_ingr'].isin(whole_delete)]
three_ingr_df=three_ingr_df[three_ingr_df['en_ingr']!='']
three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].str.strip()
three_ingr_df.dropna(inplace=True)
three_ingr_df.reset_index(drop=True,inplace=True)
three_ingr_df.shape
# Out:
# (3009, 2)

# %%
three_ingrs=list(set(three_ingr_df['en_ingr'].values.tolist()))
len(three_ingrs)
# Out:
# 1158

# %%
three_ingrs.sort()
three_ingrs
# Out:
# ['.......',
#  '/ which is needed',
#  'Caper',
#  'Fix_fur_ratatouille',
#  'Fix_für_Bauern_Topf',
#  'Fix_für_Jäger_Sahne_Schnitzel',
#  'Fix_für_Rouladen',
#  'Fix_für_Spaghetti_Bolognese',
#  'Fix_für_nudel_schinken_gratin',
#  'agaricus',
#  'agave syrup',
#  'ajvar',
#  'allspice grains',
#  'almond',
#  'almond_butter',
#  'almond_flake',
#  'almond_flour',
#  'almond_oil',
#  'almond_pudding',
#  'almonds',
#  'amaretti_di_saronno',
#  'amarettini',
#  'amaretto',
#  'anchovies',
#  'anchovy',
#  'anise spice',
#  'annis garlic dip',
#  'apple',
#  'apple compote',
#  'apple juice',
#  'apple syrup',
#  'apple_cider',
#  'apple_sauce',
#  'apples',
#  'apricot',
#  'apricots',
#  'artichoke, herb_oil',
#  'artichokes',
#  'arugula',
#  'asian_spice',
#  'asparagus',
#  'avocado',
#  'back bones',
#  'bacon',
#  'badita decoco',
#  'baguette',
#  'baharat',
#  'baileys',
#  'baked_potato,sour_cream',
#  'baking brownies',
#  'baking malt',
#  'baking pudding cream',
# ...

# %%
three_ingr_df[three_ingr_df['en_ingr']=='/ tlly cloves']
# Out:
#                 parse_ingr        en_ingr
# 1234  / tlgemahlene nelken  / tlly cloves

# %%
whole_change_dict={'- food starch':'starch','- ginger powder':'ginger_powder','- milk':'milk',
'-salmon-spinach quiche autumn salad':'salmon,spinach,quiche',
'-summer truffle':'truffle','/ milk':'milk','/ rambal olek':'sambal_oelek',
'/ rosemary':'rosemary','[horseradish]':'horseradish',
'[max. % almonds':'almond','-fold herbal':'herb','/ tlly cloves':'clove',
'/lemon':'lemon','/orange':'orange'}

# %%
for k,v in whole_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in three_ingr_df.iterrows():
    if re.search(r'^z',row.en_ingr)!=None:
        ingr_list.append(row.en_ingr)
ingr_list=list(set(ingr_list))    
ingr_list.sort()
ingr_list
# Out:
# ['zander', 'zucchini', 'zulu_dipp', 'zwieback']

# %%
three_ingr_df[three_ingr_df['en_ingr']=='wammerl belly-meat']
# Out:
#                        parse_ingr             en_ingr
# 1965  wammerl bauchfleischgekocht  wammerl belly-meat

# %%
whole_change_dict={'anise spice':'anise','allspice grains':'allspice','annis garlic dip':'garlic_sauce','back bones':'bone',
'baking sheets':'waffle','baking brownies':'brownie','baking malt':'malt','baking pudding cream':'cream',
'blossom honey':'honey','dumplings potatoes':'potato','gelier-fix':'gelier_fix',
'golden corn hacienda':'corn','golden henne liquor':'liqueur','géramont yogurt':'yoghurt',
'obstwasser spirit':'fruit_soft_drink','orange baking':'orange_back','oregano over it':'oregano',
'oriental orange spice':'orange_spice','padadies ceme vanilla':'vanilla_cream','parmean':'parmesan_cheese',
'pasta mia trinangoliharlequin':'cat_food','pastry magic':'mehlspeisenzaube','potato dumpling made dumpling powder':'raspeball',
'pul biber -turkish spice':'chili','pumpkin hokaido derorangerote':'hokkaido_pumpkin',
'quimi':'qimiq','smoked cured ham double pack':'smoked_ham','viennese':'wiener_sausage',
'walnuts european':'walnut','wammerl belly-meat':'pork_belly','white onion':'onion','white onions':'onion',
'yeast germ':'yeast','yogurt':'yoghurt','yogurt_butter':'yoghurt_butter'}

# %%
for k,v in whole_change_dict.items():
    three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
delete_words=['glasses']

# %%
three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].apply(lambda x:del_words(x))

# %%
whole_delete=['/ which is needed','.......','potato gratin sauce is']

# %%
three_ingr_df=three_ingr_df[~three_ingr_df['en_ingr'].isin(whole_delete)]
three_ingr_df=three_ingr_df[three_ingr_df['en_ingr']!='']
three_ingr_df['en_ingr']=three_ingr_df['en_ingr'].str.strip()
three_ingr_df.dropna(inplace=True)
three_ingr_df.reset_index(drop=True,inplace=True)
three_ingr_df.shape
# Out:
# (3006, 2)

# %%
three_ingr_df
# Out:
#                                          parse_ingr            en_ingr
# 0                                            kapern              caper
# 1     rindsschnitzelod. dünngeschnittenerrostbraten               beef
# 2                                              hefe              yeast
# 3                                      stck. ingwer             ginger
# 4                       neutrales öl z.b.maiskeimöl           corn_oil
# ...                                             ...                ...
# 3001                                  hähnchen ohne            chicken
# 3002                maggi helle sosse%xbasissosse%x        light_sauce
# 3003                obstkuchenboden entwedergekauft  fruie_sponge_cake
# 3004                               kräuter gemischt              herbs
# 3005                       knoblauch salz vermischt        garlic,salt
#
# [3006 rows x 2 columns]

# %%
# add lemma_ingr

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/IW_student/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
lemmatizer=WordNetLemmatizer()

# %%
three_one_ingr=three_ingr_df[three_ingr_df['en_ingr'].str.split().str.len()==1]
three_one_ingr.shape
# Out:
# (2701, 2)

# %%
three_one_ingr['tag']='n'
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
three_one_ingr['lemma_ingr']=three_one_ingr.apply(lambda x:lemmatizer.lemmatize(x.en_ingr,x.tag),axis=1)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
three_one_ingr.reset_index(drop=True,inplace=True)

# %%
three_one_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_003.csv')

# %%
three_one_ingr
# Out:
#                                          parse_ingr            en_ingr tag  \
# 0                                            kapern              caper   n
# 1     rindsschnitzelod. dünngeschnittenerrostbraten               beef   n
# 2                                              hefe              yeast   n
# 3                                      stck. ingwer             ginger   n
# 4                       neutrales öl z.b.maiskeimöl           corn_oil   n
# ...                                             ...                ...  ..
# 2696                                  hähnchen ohne            chicken   n
# 2697                maggi helle sosse%xbasissosse%x        light_sauce   n
# 2698                obstkuchenboden entwedergekauft  fruie_sponge_cake   n
# 2699                               kräuter gemischt              herbs   n
# 2700                       knoblauch salz vermischt        garlic,salt   n
#
#              lemma_ingr
# 0                 caper
# ...

# %%
three_long_ingr=three_ingr_df[three_ingr_df['en_ingr'].str.split().str.len()>1]
three_long_ingr.shape
# Out:
# (305, 2)

# %%
three_long_ingr['last_ingr']=three_long_ingr['en_ingr'].str.split().str[-1]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
three_long_ingr['tag']='n'
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
three_long_ingr['last_ingr']=three_long_ingr.apply(lambda x:lemmatizer.lemmatize(x.last_ingr,x.tag),axis=1)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
three_long_ingr['lemma_ingr']=three_long_ingr['en_ingr'].str.split().str[0]+' '+three_long_ingr['last_ingr']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
three_long_ingr.drop('last_ingr',axis=1,inplace=True)
three_long_ingr.reset_index(drop=True,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
three_long_ingr
# Out:
#                          parse_ingr                en_ingr tag  \
# 0                       sauerkirsch            sour cherry   n
# 1                   farfalle nudeln         farfalle pasta   n
# 2                      erdnusscreme           peanut cream   n
# 3              cherry_tomato,tomato  cherry_tomato, tomato   n
# 4                         eiszauber              ice magic   n
# ..                              ...                    ...  ..
# 300                     gewürz reis            spiced rice   n
# 301                     kürbiskerne          pumpkin seeds   n
# 302              frucht buttermilch       fruit buttermilk   n
# 303  hausmacher blutwurst schneiden          black pudding   n
# 304                     perlgraupen           pearl barley   n
#
#                 lemma_ingr
# 0              sour cherry
# 1           farfalle pasta
# 2             peanut cream
# 3    cherry_tomato, tomato
# 4                ice magic
# ..                     ...
# ...

# %%
three_long_ingr.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_004.csv')
