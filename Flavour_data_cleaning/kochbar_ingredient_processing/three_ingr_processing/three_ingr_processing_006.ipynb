# %%
import pandas as pd
import numpy as np
import re

# %%
three_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_003.csv',index_col=0)
three_ingr.shape
# Out:
# (15478, 5)

# %%
three_ingr
# Out:
#        recipe_id                                        recipe_href  \
# 0          25386                 /rezept/423974/I-Zwiebelsauce.html
# 1           2761  /rezept/478153/Auberginenroellchen-mit-Kaese.html
# 2          88913  /rezept/374410/Vorspeise-gemischtes-marinierte...
# 3          88913  /rezept/374410/Vorspeise-gemischtes-marinierte...
# 4          88913  /rezept/374410/Vorspeise-gemischtes-marinierte...
# ...          ...                                                ...
# 17262      26194                  /rezept/264389/Berliner-Brot.html
# 17263      52554  /rezept/357278/Kaese-Lauch-Hackfleisch-Suppe.html
# 17265      70511  /rezept/401481/Kartoffelsuppe-mit-Waldpilzen.html
# 17266      70511  /rezept/401481/Kartoffelsuppe-mit-Waldpilzen.html
# 17267      40552         /rezept/281466/Bueffett-Schinkentorte.html
#
#                                    name                   ingredient_name  \
# 0                 pfeffer aus der mühle                 pfeffer der mühle
# ...

# %%
done_ingr_001=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_001.csv',index_col=0)
done_ingr_002=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_002.csv',index_col=0)
done_ingr_003=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_003.csv',index_col=0)
done_ingr_004=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_004.csv',index_col=0)
done_ingr_005=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_ingr_done_005.csv',index_col=0)

# %%
print(done_ingr_001.shape)
print(done_ingr_002.shape)
print(done_ingr_003.shape)
print(done_ingr_004.shape)
print(done_ingr_005.shape)
# Out:
# (2679, 5)
# (1790, 5)
# (2701, 4)
# (305, 4)
# (4, 5)

# %%
done_ingr_003.head()
# Out:
#                                       parse_ingr   en_ingr tag lemma_ingr
# 0                                         kapern     caper   n      caper
# 1  rindsschnitzelod. dünngeschnittenerrostbraten      beef   n       beef
# 2                                           hefe     yeast   n      yeast
# 3                                   stck. ingwer    ginger   n     ginger
# 4                    neutrales öl z.b.maiskeimöl  corn_oil   n   corn_oil

# %%
done_ingr_004.head()
# Out:
#              parse_ingr                en_ingr tag             lemma_ingr
# 0           sauerkirsch            sour cherry   n            sour cherry
# 1       farfalle nudeln         farfalle pasta   n         farfalle pasta
# 2          erdnusscreme           peanut cream   n           peanut cream
# 3  cherry_tomato,tomato  cherry_tomato, tomato   n  cherry_tomato, tomato
# 4             eiszauber              ice magic   n              ice magic

# %%
done_ingr=pd.concat([done_ingr_003,done_ingr_004],axis=0,ignore_index=True)
done_ingr.shape
# Out:
# (3006, 4)

# %%
done_ingr.drop('tag',axis=1,inplace=True)

# %%
done_ingr['parse_ingr']=done_ingr['parse_ingr'].str.strip()

# %%
done_ingr
# Out:
#                                          parse_ingr           en_ingr  \
# 0                                            kapern             caper
# 1     rindsschnitzelod. dünngeschnittenerrostbraten              beef
# 2                                              hefe             yeast
# 3                                      stck. ingwer            ginger
# 4                       neutrales öl z.b.maiskeimöl          corn_oil
# ...                                             ...               ...
# 3001                                    gewürz reis       spiced rice
# 3002                                    kürbiskerne     pumpkin seeds
# 3003                             frucht buttermilch  fruit buttermilk
# 3004                 hausmacher blutwurst schneiden     black pudding
# 3005                                    perlgraupen      pearl barley
#
#             lemma_ingr
# 0                caper
# 1                 beef
# 2                yeast
# 3               ginger
# ...

# %%
three_ingr_df=pd.merge(three_ingr,done_ingr,on='parse_ingr',how='inner')
three_ingr_df.shape
# Out:
# (13820, 7)

# %%
three_ingr_df
# Out:
#        recipe_id                                       recipe_href  \
# 0          25386                /rezept/423974/I-Zwiebelsauce.html
# 1          62191       /rezept/470947/Pasta-mit-Lachswuerfeln.html
# 2          16244           /rezept/162919/Blutwurst-Carpaccio.html
# 3          85607       /rezept/477491/Endivien-Kartoffelsalat.html
# 4          94998     /rezept/188319/Asiatische-Haehnchenbrust.html
# ...          ...                                               ...
# 13815      67360       /rezept/400241/Gebratene-Kokos-Bananen.html
# 13816      61982                   /rezept/397267/Eiertonnato.html
# 13817      89364      /rezept/324304/Fleisch-HAWAII-SCHNITZEL.html
# 13818      70124  /rezept/357898/Tonkabohnen-Orangen-Tiramisu.html
# 13819      45986              /rezept/327216/Cevapcici-Dracul.html
#
#                                          name  \
# 0                       pfeffer aus der mühle
# 1                   frisch gemahlener pfeffer
# ...

# %%
done_ingr_001.head()
# Out:
#     recipe_id                                        recipe_href  \
# 1       11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 14      62191        /rezept/470947/Pasta-mit-Lachswuerfeln.html
# 18      16244            /rezept/162919/Blutwurst-Carpaccio.html
# 29      55350                  /rezept/434434/Baerlauchsenf.html
# 34      65515  /rezept/424867/Gebratener-Lachs-mit-warmen-Kra...
#
#                              name                ingredient_name  \
# 1      emmentaler klein gewürfelt     emmentaler klein gewürfelt
# 14  dr.oetker crème fraîchetomate  dr.oetker crème fraîchetomate
# 18         olivenöl kalt gepresst         olivenöl kalt gepresst
# 29         olivenöl extra vergine         olivenöl extra vergine
# 34         olivenöl extra vergine         olivenöl extra vergine
#
#          parse_ingr
# 1   emmental_cheese
# 14    creme_fraiche
# 18        olive_oil
# 29        olive_oil
# 34        olive_oil

# %%
done_ingr_002.head()
# Out:
#    recipe_id                                        recipe_href  \
# 0      55097   /rezept/383143/Saftiges-Salat-Specksandwich.html
# 1      35091                   /rezept/495439/Party-Gratin.html
# 2      67498  /rezept/494472/Avocado-Frischkaese-Dip-mit-Mac...
# 3      55350                  /rezept/434434/Baerlauchsenf.html
# 4      65515  /rezept/424867/Gebratener-Lachs-mit-warmen-Kra...
#
#                            name           ingredient_name    parse_ingr
# 0  pfeffer aus der mühleschwarz  pfeffer der mühleschwarz  black_pepper
# 1  pfeffer aus der mühleschwarz  pfeffer der mühleschwarz  black_pepper
# 2  pfeffer aus der mühleschwarz  pfeffer der mühleschwarz  black_pepper
# 3  pfeffer aus der mühleschwarz  pfeffer der mühleschwarz  black_pepper
# 4  pfeffer aus der mühleschwarz  pfeffer der mühleschwarz  black_pepper

# %%
done_ingr_005.head()
# Out:
#        recipe_id                                        recipe_href  \
# 2141       17713  /rezept/314810/Putenmedaillons-mit-Kraeuter-Ka...
# 4215       49443  /rezept/397927/bunter-Salat-trifft-Kaese-und-E...
# 4558       17937  /rezept/376977/Fruehlingsgemuesereis-mit-Haehn...
# 14109      17679              /rezept/298758/Einfach-nur-Salat.html
#
#                  name ingredient_name parse_ingr
# 2141    tk - 8kräuter   tk - 8kräuter  8_kräuter
# 4215    tk - 8kräuter   tk - 8kräuter  8_kräuter
# 4558   tk - 8-kräuter  tk - 8-kräuter  8_kräuter
# 14109   tk -8 kräuter   tk -8 kräuter  8_kräuter

# %%
done_ingr=pd.concat([done_ingr_001,done_ingr_002,done_ingr_005],axis=0)
done_ingr.shape
# Out:
# (4473, 5)

# %%
done_ingr['en_ingr']=done_ingr['parse_ingr']
done_ingr['lemma_ingr']=done_ingr['parse_ingr']

# %%
done_ingr.head()
# Out:
#     recipe_id                                        recipe_href  \
# 1       11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 14      62191        /rezept/470947/Pasta-mit-Lachswuerfeln.html
# 18      16244            /rezept/162919/Blutwurst-Carpaccio.html
# 29      55350                  /rezept/434434/Baerlauchsenf.html
# 34      65515  /rezept/424867/Gebratener-Lachs-mit-warmen-Kra...
#
#                              name                ingredient_name  \
# 1      emmentaler klein gewürfelt     emmentaler klein gewürfelt
# 14  dr.oetker crème fraîchetomate  dr.oetker crème fraîchetomate
# 18         olivenöl kalt gepresst         olivenöl kalt gepresst
# 29         olivenöl extra vergine         olivenöl extra vergine
# 34         olivenöl extra vergine         olivenöl extra vergine
#
#          parse_ingr          en_ingr       lemma_ingr
# 1   emmental_cheese  emmental_cheese  emmental_cheese
# 14    creme_fraiche    creme_fraiche    creme_fraiche
# ...

# %%
three_ingr_df.head()
# Out:
#    recipe_id                                    recipe_href  \
# 0      25386             /rezept/423974/I-Zwiebelsauce.html
# 1      62191    /rezept/470947/Pasta-mit-Lachswuerfeln.html
# 2      16244        /rezept/162919/Blutwurst-Carpaccio.html
# 3      85607    /rezept/477491/Endivien-Kartoffelsalat.html
# 4      94998  /rezept/188319/Asiatische-Haehnchenbrust.html
#
#                         name            ingredient_name parse_ingr en_ingr  \
# 0      pfeffer aus der mühle          pfeffer der mühle    pfeffer  pepper
# 1  frisch gemahlener pfeffer  frisch gemahlener pfeffer    pfeffer  pepper
# 2      pfeffer aus der mühle          pfeffer der mühle    pfeffer  pepper
# 3      pfeffer aus der mühle          pfeffer der mühle    pfeffer  pepper
# 4      pfeffer aus der mühle          pfeffer der mühle    pfeffer  pepper
#
#   lemma_ingr
# 0     pepper
# 1     pepper
# 2     pepper
# 3     pepper
# 4     pepper

# %%
three_ingr_df=pd.concat([three_ingr_df,done_ingr],axis=0,ignore_index=True)
three_ingr_df.shape
# Out:
# (18293, 7)

# %%
three_ingr_df.sort_values('recipe_id',inplace=True)
three_ingr_df.reset_index(drop=True,inplace=True)

# %%
three_ingr_df
# Out:
#        recipe_id                                        recipe_href  \
# 0             25        /rezept/419371/Spaghettata-alla-Hannah.html
# 1             25        /rezept/419371/Spaghettata-alla-Hannah.html
# 2             40       /rezept/194933/Himbeer-Mascarpone-Creme.html
# 3             65  /rezept/490981/Chocolate-Habanero-Minze-Pesto....
# 4             89  /rezept/433770/blattspinat-erbsen-topf-mit-bul...
# ...          ...                                                ...
# 18288     118103                 /rezept/397671/Spaetzlepfanne.html
# 18289     118105            /rezept/336691/Steinpilzcremesuppe.html
# 18290     118105            /rezept/336691/Steinpilzcremesuppe.html
# 18291     118130    /rezept/168944/Schokoladenbuttercremetorte.html
# 18292     118131                     /rezept/231630/Goudasalat.html
#
#                                  name                 ingredient_name  \
# 0               pfeffer aus der mühle               pfeffer der mühle
# ...

# %%
three_ingr_df.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/three_ingr_data/three_done.csv')
