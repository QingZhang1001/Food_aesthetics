# %%
import pandas as pd
import numpy as np
import os
import re

# %%
ingr=pd.read_csv('kochbar_ingr_original.csv',index_col=0)
ingr.shape
# Out:
# (262842, 3)

# %%
ingr.dropna(inplace=True)
ingr.shape
# Out:
# (262842, 3)

# %%
ingr.tail()
# Out:
#         recipe_id                        recipe_href                  name
# 262837      47140  /rezept/391537/Sauerrahm-Dip.html               pfeffer
# 262838      47140  /rezept/391537/Sauerrahm-Dip.html             sauerrahm
# 262839      47140  /rezept/391537/Sauerrahm-Dip.html            mayonnaise
# 262840      47140  /rezept/391537/Sauerrahm-Dip.html   schnittlauch frisch
# 262841      47140  /rezept/391537/Sauerrahm-Dip.html  saft von 1/2 zitrone

# %%
# split the rows with ',' to multiple rows

# %%
ingr=ingr.join(pd.DataFrame(ingr['name'].str.split(',',expand=True).stack().reset_index(level=1,drop=True).rename('ingredient_name')))
ingr.shape
# Out:
# (281644, 4)

# %% [markdown]
# #### translation

# %%
ingr.reset_index(inplace=True,drop=True)

# %%
ingr.tail()
# Out:
#         recipe_id                        recipe_href                  name  \
# 281639      47140  /rezept/391537/Sauerrahm-Dip.html               pfeffer
# 281640      47140  /rezept/391537/Sauerrahm-Dip.html             sauerrahm
# 281641      47140  /rezept/391537/Sauerrahm-Dip.html            mayonnaise
# 281642      47140  /rezept/391537/Sauerrahm-Dip.html   schnittlauch frisch
# 281643      47140  /rezept/391537/Sauerrahm-Dip.html  saft von 1/2 zitrone
#
#              ingredient_name
# 281639               pfeffer
# 281640             sauerrahm
# 281641            mayonnaise
# 281642   schnittlauch frisch
# 281643  saft von 1/2 zitrone

# %%
# delete href in ingredient_name

# %%
for index,row in ingr.iterrows():
    if re.search('aus meinem kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('aus meinem kb.*','',row.ingredient_name)
        #print(row)

# %%
for index,row in ingr.iterrows():
    if re.search('ausmeinem kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ausmeinem kb.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('aus meinemkb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('aus meinemkb.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('siehe mein kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('siehe mein kb.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('siehemein kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('siehemein kb.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ausmeinem kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ausmeinem kb.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search(' nach imhbach ',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(' nach imhbach .*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('version 1',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('version 1.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('rezept lebkuchen vonheiropi',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('rezept lebkuchen vonheiropi.*','',row.ingredient_name)
    if re.search('nach imhbach',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('nach imhbach.*','',row.ingredient_name)
    if re.search('aus denkb-',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('aus denkb-.*','',row.ingredient_name)
    if re.search('hiermeine kräutergnocchi',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('hiermeine kräutergnocchi.*','',row.ingredient_name)
    if re.search('aus meinemkochbuch',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('aus meinemkochbuch.*','',row.ingredient_name)
    if re.search('eigene herstellung',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('eigene herstellung.*','',row.ingredient_name)
    if re.search('imkb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('imkb.*','',row.ingredient_name)   
    if re.search('siehe meinkb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('siehe meinkb.*','',row.ingredient_name)  
    if re.search('aus meinenkb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('aus meinenkb.*','',row.ingredient_name)   
    if re.search('aus kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('aus kb.*','',row.ingredient_name)
    if re.search('siehekochbuch',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('siehekochbuch.*','',row.ingredient_name)    
    if re.search('vonrezeptsammlerin',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('vonrezeptsammlerin.*','',row.ingredient_name) 
    if re.search('-rzunter',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('-rzunter.*','',row.ingredient_name) 
    if re.search('von chrissi720',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('von chrissi720.*','',row.ingredient_name) 
    if re.search('siehe-',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('siehe-.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('nachdiesem',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('nachdiesem.*','',row.ingredient_name)
    if re.search('von chirssi720',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('von chirssi720.*','',row.ingredient_name)
    if re.search('vonchirssi720',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('vonchirssi720.*','',row.ingredient_name) 
    if re.search('nach chrissi720',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('nach chrissi720.*','',row.ingredient_name)
    if re.search('meine tomatensosse fürpizza',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('meine tomatensosse fürpizza.*','',row.ingredient_name)
    if re.search('rest - hier',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('rest - hier.*','',row.ingredient_name) 
    if re.search('musste weg',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('musste weg.*','',row.ingredient_name)
    if re.search('selbstgemacht',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('selbstgemacht','',row.ingredient_name)
    if re.search('rest z.b.',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('rest z.b.*','',row.ingredient_name)
    if re.search('nach meinem rezeptsiehe kb',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('nach meinem rezeptsiehe kb.*','',row.ingredient_name) 
    if re.search('rest von densüssen brötchenhtt',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('rest von densüssen brötchenhtt.*','',row.ingredient_name)
    if re.search('rest von densüssen brötchenhtt',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('rest von densüssen brötchenhtt.*','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('siehe kochbuch',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('siehe kochbuch.*','',row.ingredient_name)
    if re.search('vonchrissi720',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('vonchrissi720.*','',row.ingredient_name)
    if re.search('http',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('http.*','',row.ingredient_name)

# %%
ingr['ingredient_name']=ingr['ingredient_name'].str.strip()

# %%
# delete the row where 'ingredient_name' is ''

# %%
ingr=ingr[ingr['ingredient_name']!='']

# %%
ingr.dropna(inplace=True)

# %%
ingr.shape
# Out:
# (281494, 4)

# %%
ingr.reset_index(inplace=True,drop=True)

# %%
ingr.tail()
# Out:
#         recipe_id                        recipe_href                  name  \
# 281489      47140  /rezept/391537/Sauerrahm-Dip.html               pfeffer
# 281490      47140  /rezept/391537/Sauerrahm-Dip.html             sauerrahm
# 281491      47140  /rezept/391537/Sauerrahm-Dip.html            mayonnaise
# 281492      47140  /rezept/391537/Sauerrahm-Dip.html   schnittlauch frisch
# 281493      47140  /rezept/391537/Sauerrahm-Dip.html  saft von 1/2 zitrone
#
#              ingredient_name
# 281489               pfeffer
# 281490             sauerrahm
# 281491            mayonnaise
# 281492   schnittlauch frisch
# 281493  saft von 1/2 zitrone

# %%
ingr.to_csv('datasets/ingr_del_http.csv')

# %%
# Try to delete the numbers in the recipes (re:[0-9]+)

# %%
ingr.shape
# Out:
# (281494, 4)

# %%
ingr.head()
# Out:
#    recipe_id                                        recipe_href      name  \
# 0      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      salz
# 1      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    zucker
# 2      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      mehl
# 3      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...  olivenöl
# 4      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    wasser
#
#   ingredient_name
# 0            salz
# 1          zucker
# 2            mehl
# 3        olivenöl
# 4          wasser

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]',row.ingredient_name)!=None:
        print(row)
# Out:
# recipe_id                                       16685
# recipe_href        /rezept/298220/Kartoffelpizza.html
# name                 pfanni knödel halb halb-12knödel
# ingredient_name      pfanni knödel halb halb-12knödel
# Name: 537, dtype: object
# recipe_id                                                      56507
# recipe_href        /rezept/125261/Rosa-gebratene-Barbarieentenbru...
# name                                    barbarieentenbrust 350-400gr
# ingredient_name                              barbarieentenbrust 350-
# Name: 1268, dtype: object
# recipe_id                                                      50929
# recipe_href                          /rezept/52105/Kokos-Kuchen.html
# name               mehl u. margarine f. diekranzkuchenform 28 !!! cm
# ingredient_name    mehl u. margarine f. diekranzkuchenform 28 !!! cm
# Name: 1368, dtype: object
# recipe_id                                                      57671
# ...

# %%
# delete el/tl/esslofel/liter

# %%
# 1 el,ca 1/2esslöffel,ca. 5 esslöffel,ca.3 el, ca. 3 el

# %%
for index,row in ingr.iterrows():
    if re.search('ca [0-9]/[0-9]esslöffel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]/[0-9]esslöffel','',row.ingredient_name)
    if re.search('ca\. [0-9] esslöffel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9] esslöffel','',row.ingredient_name)
    if re.search('ca\.[0-9] el',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9] el','',row.ingredient_name)
    if re.search('ca\. [0-9] el',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9] el','',row.ingredient_name)   
    if re.search('[0-9] el',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9] el','',row.ingredient_name)

# %%
# delete cm

# %%
for index,row in ingr.iterrows():
    if re.search('à ca\. [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('à ca\. [0-9]+cm','',row.ingredient_name)
    if re.search('a´ca\. [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a´ca\. [0-9]+cm','',row.ingredient_name)
    if re.search('ca\. [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]cm+','',row.ingredient_name)
    if re.search('ca\. [0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+ cm','',row.ingredient_name) 
    if re.search('ca. [0-9]+ scheiben',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca. [0-9]+ scheiben','',row.ingredient_name)   
    if re.search('zu 1/2 to 1 cm stuecke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('zu 1/2 to 1 cm stuecke','',row.ingredient_name)
    if re.search('[0-9]+/ [0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+/ [0-9]+ cm','',row.ingredient_name)   
    if re.search('ca\. [0-9]+ cm - rest',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+ cm - rest','',row.ingredient_name)
    if re.search('ca\. [0-9]+-[0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+-[0-9]+ cm','',row.ingredient_name) 
    if re.search('[0-9]+ cm durchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cm durchmesser','',row.ingredient_name)        
    if re.search('[0-9]+-[0-9]cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+-[0-9]+cm','',row.ingredient_name)
    if re.search('[0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cm','',row.ingredient_name)
    if re.search('[0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+cm','',row.ingredient_name)      
    if re.search('ca\. [0-9]+-[0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+-[0-9]+cm','',row.ingredient_name)
    if re.search('ca\. [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+cm','',row.ingredient_name)
    if re.search('ca\. [0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+ cm','',row.ingredient_name)   
    if re.search('a [0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]+ cm','',row.ingredient_name) 
    if re.search('ca\.[0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]+ cm','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca/. [0-9]+ x [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca/. [0-9]+ x [0-9]+cm','',row.ingredient_name)
    if re.search('[0-9]+ x [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ x [0-9]+cm','',row.ingredient_name)
    if re.search('ca\. [0-9]+x[0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+x[0-9]+ cm','',row.ingredient_name)
    if re.search('[0-9]+x[0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+x[0-9]+cm','',row.ingredient_name)
    if re.search('[0-9]+ x[0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ x[0-9]+cm','',row.ingredient_name)   
    if re.search('[0-9]+ * [0-9]+ cmgross',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ * [0-9]+ cmgross','',row.ingredient_name)

# %%
# 22 cmdurchmesser, ca. 5 cm breit,in 1 cm.würfel, ca. 2x2 cmwürfel,in 6cm stücke geschnitten, 70 mm durchmesser,
# ca 5 mm dick, 2 x2 cm cirka, 5cm dick,ca.6cm dick,ca.16 scheiben

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+ cmdurchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cmdurchmesser','',row.ingredient_name)
    if re.search('ca\. [0-9]+ cm breit',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+ cm breit','',row.ingredient_name)
    if re.search('in [0-9]+ cm.würfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+ cm.würfel','',row.ingredient_name)
    if re.search('ca. [0-9]+x[0-9]+ cmwürfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca. [0-9]+x[0-9]+ cmwürfel','',row.ingredient_name)
    if re.search('in [0-9]+cm stücke geschnitten',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+cm stücke geschnitten','',row.ingredient_name)
    if re.search('[0-9]+ mm durchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ mm durchmesser','',row.ingredient_name) 
    if re.search('ca [0-9]+ mm dick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]+ mm dick','',row.ingredient_name)  
    if re.search('[0-9]+ x[0-9]+ cm cirka',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ x[0-9]+ cm cirka','',row.ingredient_name) 
    if re.search('[0-9]+cm dick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+cm dick','',row.ingredient_name)  
    if re.search('ca.[0-9]+cm dick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.[0-9]+cm dick','',row.ingredient_name)
    if re.search('ca.[0-9]+ scheiben',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.[0-9]+ scheiben','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+ x[0-9]+ cm cirka',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ x[0-9]+ cm cirka','',row.ingredient_name)
    if re.search('ca\. [0-9]+mm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+mm','',row.ingredient_name)
    if re.search('form [0-9]+ cmø',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('form [0-9]+ cmø','',row.ingredient_name)
    if re.search('[0-9]+x[0-9]+ cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+x[0-9]+ cm','',row.ingredient_name)
    if re.search('[0-9]+/[0-9]+ würfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+/[0-9]+ würfel','',row.ingredient_name)
    if re.search('[0-9]+ würfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ würfel','',row.ingredient_name) 
    if re.search('[0-9]+ cmdurchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cmdurchmesser','',row.ingredient_name)  
    if re.search('durchmesser [0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('durchmesser [0-9]+cm','',row.ingredient_name) 
    if re.search('[0-9]+ mmdurchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ mmdurchmesser','',row.ingredient_name)  
    if re.search('in[0-9]+-cm-streifen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+-cm-streifen','',row.ingredient_name)
    if re.search('in[0-9]+x[0-9]+-cm-stücken',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+x[0-9]+-cm-stücken','',row.ingredient_name) 
    if re.search('in[0-9]+-cm-würfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+-cm-würfel','',row.ingredient_name)

# %%
#2 x2 cm cirka, ca. 5mm, form 28 cmø, ca. 4x2 cm, 1/4 würfel,1 würfel, 22 cmdurchmesser, durchmesser 10cm,50 mmdurchmesser
# in3-cm-streifen,in4x4-cm-stücken, in2-cm-würfeln,3-cm-würfeln, in 2-cm-scheiben,in2-cm-streifen,2 cmlange stücke,
# durchmesser 50mm, in 2cm.stücke, in 1 cm streifen,  5 * 1 cmgross, in 5mmdicken streifen,in 1 cmwürfel geschnitten
# 16 cm durchmesser,in 5 cmstck.geschnitten,in2x2-cm-würfeln,in1/2-cm-scheiben,5 cmdick,
# ca. 3x3 cm gross, 7 cm durchmesser

# %%
for index,row in ingr.iterrows():
    if re.search('in[0-9]+-cm-streifen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+-cm-streifen','',row.ingredient_name)
    if re.search('in[0-9]+x[0-9]+-cm-stücken',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+x[0-9]+-cm-stücken','',row.ingredient_name)
    if re.search('in[0-9]+x[0-9]+-cm-würfeln',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+x[0-9]+-cm-würfeln','',row.ingredient_name)
    if re.search('in[0-9]+-cm-würfeln',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+-cm-würfeln','',row.ingredient_name)
    if re.search('[0-9]+-cm-würfeln',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+-cm-würfeln','',row.ingredient_name)
    if re.search('in [0-9]+-cm-scheiben',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+-cm-scheiben','',row.ingredient_name) 
    if re.search('in[0-9]+-cm-streifen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+-cm-streifen','',row.ingredient_name)
    if re.search('[0-9]+ cmlange stücke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cmlange stücke','',row.ingredient_name)
    if re.search('in [0-9]+cm\.stücke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+cm\.stücke','',row.ingredient_name)
    if re.search('in [0-9]+ cm streifen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+ cm streifen','',row.ingredient_name)
    if re.search('in [0-9]+mmdicken streifen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+mmdicken streifen','',row.ingredient_name) 
    if re.search('in [0-9]+ cmwürfel geschnitten',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+ cmwürfel geschnitten','',row.ingredient_name)  
    if re.search('in [0-9]+ cmstck.geschnitten',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in [0-9]+ cmstck.geschnitten','',row.ingredient_name) 
    if re.search('in[0-9]+/[0-9]+-cm-scheiben',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in[0-9]+/[0-9]+-cm-scheiben','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.3-4 cmdick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.3-4 cmdick','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca. 20 cmdurchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca. 20 cmdurchmesser','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+cm durchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+cm durchmesser','',row.ingredient_name)
    if re.search('[0-9]+ cmduchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cmduchmesser','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca/.[0-9]+ cmdick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca/.[0-9]+ cmdick','',row.ingredient_name)
    if re.search('[0-9]+ cm dick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cm dick','',row.ingredient_name)
    if re.search('[0-9]+ cm dick',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cm dick','',row.ingredient_name)
    if re.search('[0-9]+ cm lang',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cm lang','',row.ingredient_name)
    if re.search('ca/. [0-9]+ cmdurchmesser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca/. [0-9]+ cmdurchmesser','',row.ingredient_name)
    if re.search('ca/. [0-9]+ cmdurchmesse',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca/. [0-9]+ cmdurchmesse','',row.ingredient_name)
    if re.search('ca/. [0-9]+ cm breit',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca/. [0-9]+ cm breit','',row.ingredient_name)
    if re.search('durchmesser[0-9]+cm',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('durchmesser[0-9]+cm','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+/[0-9]+ cm scheiben',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+/[0-9]+ cm scheiben','',row.ingredient_name)
    if re.search('ca/.[0-9]+x[0-9]+ cmwürfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca/.[0-9]+x[0-9]+ cmwürfel','',row.ingredient_name)
    if re.search('[0-9]+ cm würfel',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ cm würfel','',row.ingredient_name)
    if re.search('-[0-9]+ cm langestreifen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('-[0-9]+ cm langestreifen','',row.ingredient_name) 
    if re.search('[0-9]+ mm durchmeeser',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ mm durchmeeser','',row.ingredient_name)

# %%
# delete xx% fett

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+% fett',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+% fett','',row.ingredient_name)
    if re.search('[0-9]+%fett',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+%fett','',row.ingredient_name)
    if re.search('[0-9]+ % fett',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ % fett','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9] +% fett',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9] +% fett','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+% kakao',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+% kakao','',row.ingredient_name)
    if re.search('[0-9]+%kakao',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+%kakao','',row.ingredient_name)
    if re.search('[0-9]+ % kakao',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ % kakao','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+ %kakao',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ %kakao','',row.ingredient_name)
    if re.search('[0-9]+ %fett',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ %fett','',row.ingredient_name)

# %%
# delte the unit ml/el/tl/liter(with ca.)

# %%
for index,row in ingr.iterrows():
    if re.search('á ca. [0-9]ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('á ca. [0-9]ml','',row.ingredient_name)
    if re.search('ca\.[0-9]+ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]+ml','',row.ingredient_name)
    if re.search('ca\. [0-9]+ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+ml','',row.ingredient_name)
    if re.search('ca\.[0-9]+ ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]+ ml','',row.ingredient_name)
    if re.search('ca\. [0-9]+ ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]+ ml','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('à [0-9]ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('à [0-9]ml','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('à [0-9] ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('à [0-9] ml','',row.ingredient_name)
    if re.search('à[0-9]ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('à[0-9]ml','',row.ingredient_name)
    if re.search('à [0-9]ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('à [0-9]ml','',row.ingredient_name)
    if re.search('á [0-9]ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('á [0-9]ml','',row.ingredient_name) 
    if re.search('a´[0-9] ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a´[0-9] ml','',row.ingredient_name)   
    if re.search('[0-9]+ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ml','',row.ingredient_name)
    if re.search(' [0-9]+ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(' [0-9]+ml','',row.ingredient_name)
    if re.search('[0-9]+ ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ ml','',row.ingredient_name)
    if re.search(' [0-9]+ ml',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(' [0-9]+ ml','',row.ingredient_name)

# %%
# delte the unit cm(with ca)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.*[0-9].*m$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.*[0-9].*m','',row.ingredient_name)

# %%
# delete the unit g/gr/gramm/kg(with ca)

# %%
for index,row in ingr.iterrows():
    if re.search('ca\. [0-9]*gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]*gramm','',row.ingredient_name)
    if re.search('ca\. [0-9]*gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]*gr','',row.ingredient_name)
    if re.search('ca\. [0-9]*g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]*g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca\. [0-9].*gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9].*gramm','',row.ingredient_name)
    if re.search('ca\. [0-9].*gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9].*gr','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca\. [0-9]* gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]* gramm','',row.ingredient_name)
    if re.search('ca\. [0-9]* gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]* gr','',row.ingredient_name)  
    if re.search('ca\. [0-9]* g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9]* g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca\.[0-9]*gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]*gr','',row.ingredient_name)
    if re.search('ca\.[0-9]*gr/st$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]*gr/st','',row.ingredient_name)
    if re.search('ca\.[0-9]*g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]*g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca\.[0-9]* gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]* gramm','',row.ingredient_name)
    if re.search('ca\.[0-9]* gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]* gr','',row.ingredient_name)
    if re.search('ca\.[0-9]* g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\.[0-9]* g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca [0-9]*gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]*gramm','',row.ingredient_name)
    if re.search('ca [0-9]*gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]*gr','',row.ingredient_name)
    if re.search('ca [0-9]*g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]*g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca [0-9]* gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]* gramm','',row.ingredient_name)
    if re.search('ca [0-9]* gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]* gr','',row.ingredient_name)  
    if re.search('ca [0-9]* g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca [0-9]* g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.*[0-9].*g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.*[0-9].*g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.*[0-9].*gr\.',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.*[0-9].*gr\.','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.*[0-9].*g ',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.*[0-9].*g ','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.*[0-9].*grann',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.*[0-9].*grann','',row.ingredient_name)

# %%
# delete the unit g/gr/gramm/kg(without ca, perhaps with a)

# %%
for index,row in ingr.iterrows():
    if re.search('á.*[0-9].*g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('á.*[0-9].*g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9].*g ',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9].*g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('a [0-9]+g$',row.ingredient_name)!=None: 
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]+g','',row.ingredient_name)
    if re.search('a [0-9]+gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]+gr','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+gramm','',row.ingredient_name)
    if re.search('[0-9]+gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+gr','',row.ingredient_name)
    if re.search('[0-9]+g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('etwa [0-9]+ gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('etwa [0-9]+ gramm','',row.ingredient_name)
    if re.search('etwa [0-9]+ gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('etwa [0-9]+ gr','',row.ingredient_name)
    if re.search('etwa [0-9]+ g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('etwa [0-9]+ g','',row.ingredient_name)
    if re.search('a [0-9]+ gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]+ gramm','',row.ingredient_name)
    if re.search('a [0-9]+ gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]+ gr','',row.ingredient_name)
    if re.search('a [0-9]+ g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]+ g','',row.ingredient_name)
    if re.search('[0-9]+ gramm$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ gramm','',row.ingredient_name)
    if re.search('[0-9]+ gr$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ gr','',row.ingredient_name)
    if re.search('[0-9]+ g$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ g','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('je. [0-9] gr.',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('je. [0-9] gr.','',row.ingredient_name)
    if re.search('a [0-9]gr.',row.ingredient_name)!=None:   
        ingr.loc[index,'ingredient_name']=re.sub('a [0-9]gr.','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ca.[0-9]+kg',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.[0-9]+kg','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('[0-9]+kg',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+kg','',row.ingredient_name)
    if re.search('[0-9]+ kg',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]+ kg','',row.ingredient_name)

# %%
ingr.to_csv('datasets/ingr_del_num.csv')

# %%
# delete stück

# %%
ingr=pd.read_csv('datasets/ingr_del_num.csv',index_col=0)

# %%
ingr=ingr[ingr['ingredient_name']!='']
ingr['ingredient_name']=ingr['ingredient_name'].str.strip()
ingr.dropna(inplace=True)
ingr.shape
# Out:
# (280788, 4)

# %%
stuck_list=[]
for index,row in ingr.iterrows():
    if re.search('stück',row.ingredient_name)!=None:
        stuck_list.append(row.ingredient_name)
set(stuck_list)
# Out:
# {'am besten mitstückchen drin',
#  'ananasstückchen',
#  'apfelkompott mit stückchen',
#  'bacalao rückenstück ohnegräten',
#  'cookies mit schokostückchen',
#  'daumenbreites stück ingwer',
#  'dinkelbrot mitkastanienstückchen',
#  'eier die sind beimfrühstück übrig geblieben',
#  'erdnussbutter mit stücken',
#  'frühstücksbacon',
#  'frühstücksfleisch',
#  'frühstücksfleisch konserve',
#  'frühstückshonig',
#  'frühstückspeck',
#  'gemüsestückchen nach wahl',
#  'gerechte stückegeschnitten',
#  'grösserestücken 1-2x durchschneiden',
#  'helle cookies mitschokostückchen',
#  'in kleinenstückchen',
#  'instückchen',
#  'kalte butter in kleinestückchen',
#  'kekse mitschokoladenstückchen',
#  'kleine stückchen butter',
#  'kleinen ananasstückchensowie apfelstückchen',
#  'lachsendstück für diesauce',
#  'mandarinenstückchen',
#  'mangostückchen zumgarnieren',
#  'margarinestückchen',
#  'marzipanstückchen',
#  'mini-stückchen chilischotegetrocknet',
#  'möhrenstückchen',
# ...

# %%
for index,row in ingr.iterrows():
    if re.search('ca\. [0-9] stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9] stück','',row.ingredient_name)
    if re.search('ca.[0-9] stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca.[0-9] stück','',row.ingredient_name)  
    if re.search('[0-9] stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9] stück','',row.ingredient_name) 
    if re.search('[0-9]stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('[0-9]stück','',row.ingredient_name) 
    if re.search('kleines stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('kleines stück','',row.ingredient_name)   
    if re.search('stück$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stück','',row.ingredient_name)
    if re.search('stückig',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stückig','',row.ingredient_name)
    if re.search('im stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('im stück','',row.ingredient_name)
    if re.search('grosses stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('grosses stück','',row.ingredient_name) 
    if re.search('^ein.*?stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('^ein.*?stück','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('frühstücksspeck',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('frühstücksspeck','bacon',row.ingredient_name)
    if re.search(r'\bin\b .*? stückegeschnitten',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bin\b .*? stückegeschnitten','',row.ingredient_name)
    if re.search(r'\bin\b .*?geschnitten',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bin\b .*?geschnitten','',row.ingredient_name) 
    if re.search(r'\bin\b .*?stückegebrochen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bin\b .*?stückegebrochen','',row.ingredient_name) 
    if re.search('instücke geschnitten',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('instücke geschnitten','',row.ingredient_name) 
    if re.search(r'\bin\b stückchen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bin\b stückchen(.*?)','',row.ingredient_name) 
    if re.search('einstückchen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('einstückchen','',row.ingredient_name)
    if re.search(r'\bein\b .*?stückchen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bein\b .*?stückchen','',row.ingredient_name) 
    if re.search(r'\bein\b .*?stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bein\b .*?stück','',row.ingredient_name)   
    if re.search('^stückchen',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stückchen','',row.ingredient_name) 
    if re.search('^stückige',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stückige','',row.ingredient_name)    
    if re.search('^stücke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stücke','',row.ingredient_name) 
    if re.search('^stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stück','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('am stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('am stück','',row.ingredient_name)
    if re.search('amstück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('amstück','',row.ingredient_name)
    if re.search('in stücken',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in stücken','',row.ingredient_name)  
    if re.search('in stücke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in stücke','',row.ingredient_name)
    if re.search('im stücke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('im stücke','',row.ingredient_name)
    if re.search('ca\. [0-9] kleine stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9] kleine stück','',row.ingredient_name)
    if re.search('ca\. [0-9] stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ca\. [0-9] stück','',row.ingredient_name)  
    if re.search('etwa [0-9] stück',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('etwa [0-9] stück','',row.ingredient_name) 
    if re.search('dose stückige',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('dose stückige','',row.ingredient_name) 
    if re.search('dose stückige',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('dose stückige','',row.ingredient_name)
    if re.search('gestückelte',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('gestückelte','',row.ingredient_name)
    if re.search('gestückelt',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('gestückelt','',row.ingredient_name)
    if re.search('stückige',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stückige','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search(r'\bin\b .*? stücke',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bin\b .*? stücke','',row.ingredient_name)
    if re.search('stücke$',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stücke','',row.ingredient_name)
    if re.search(r'\bstücke$\b',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bstücke$\b','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('in.*? stücke .*?',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in.*? stücke .*?','',row.ingredient_name)
    if re.search('stücke .*?',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('stücke .*?','',row.ingredient_name)
    if re.search('in.*?stücke.*?',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('in.*?stücke.*?','',row.ingredient_name)

# %%
ingr=ingr[ingr['ingredient_name']!='']
ingr['ingredient_name']=ingr['ingredient_name'].str.strip()
ingr.dropna(inplace=True)

# %%
ingr.shape
# Out:
# (280283, 4)

# %%
ingr.to_csv('datasets/ingr_del_stuck.csv')

# %% [markdown]
# ## Deal with the ingredient with long words(>=3)

# %%
ingr=pd.read_csv('datasets/ingr_del_stuck.csv',index_col=0)
ingr.shape
# Out:
# (280283, 4)

# %%
ingr.reset_index(inplace=True,drop=True)

# %%
ingr.head()
# Out:
#    recipe_id                                        recipe_href      name  \
# 0      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      salz
# 1      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    zucker
# 2      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      mehl
# 3      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...  olivenöl
# 4      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    wasser
#
#   ingredient_name
# 0            salz
# 1          zucker
# 2            mehl
# 3        olivenöl
# 4          wasser

# %%
ingr.tail()
# Out:
#         recipe_id                        recipe_href                  name  \
# 280278      47140  /rezept/391537/Sauerrahm-Dip.html               pfeffer
# 280279      47140  /rezept/391537/Sauerrahm-Dip.html             sauerrahm
# 280280      47140  /rezept/391537/Sauerrahm-Dip.html            mayonnaise
# 280281      47140  /rezept/391537/Sauerrahm-Dip.html   schnittlauch frisch
# 280282      47140  /rezept/391537/Sauerrahm-Dip.html  saft von 1/2 zitrone
#
#              ingredient_name
# 280278               pfeffer
# 280279             sauerrahm
# 280280            mayonnaise
# 280281   schnittlauch frisch
# 280282  saft von 1/2 zitrone

# %%
long_ingr=ingr[ingr['ingredient_name'].str.split().str.len()>=5]
long_ingr.shape
# Out:
# (2411, 4)

# %%
long_ingr.head()
# Out:
#       recipe_id                                        recipe_href  \
# 56        11059         /rezept/130203/Dr-Bello-s-Frikadellos.html
# 436       45230              /rezept/242380/Zimt-Apfel-Kuchen.html
# 578       57005                     /rezept/281248/Chilicreme.html
# 714        1878  /rezept/409007/Torte-Birne-Helene-Schoko-Butte...
# 1020      55182                 /rezept/404267/Krabbenruehrei.html
#
#                                                    name  \
# 56                          pfeffer aus der mühle weiss
# 436            rosinen nach geschmackeingeweicht in rum
# 578                   frischkäse geht auch mitfeta käse
# 714   wiener boden,,,diesmalgekauft mir fehlte die zeit
# 1020                         pfeffer aus der mühle bunt
#
#                                ingredient_name
# 56                 pfeffer aus der mühle weiss
# 436   rosinen nach geschmackeingeweicht in rum
# 578          frischkäse geht auch mitfeta käse
# ...

# %%
len(set(long_ingr['ingredient_name'].values.tolist()))
# Out:
# 2017

# %%
set(long_ingr['ingredient_name'].values.tolist())
# Out:
# {'mango frisch - sehr reif',
#  'thai hot green curry aus dergewürzmühle',
#  'muskat evtl. etwas mandanin zursaucenbindung',
#  'fächerdie halbe masse vom botenzubereiten',
#  'bei der kuvertür sind es',
#  'saure gurken kleingeschnitten je nachgeschmack',
#  'zuckermais gegart - gibt esfertig zu kaufen',
#  'was ihrgerade da habt an leckeressig',
#  'backpflaumen ohne stein 1/2std. einweichen',
#  'backfertiger frischteig 6croissants von kühlregeal',
#  'in rot wärefarblich schöner gewesen',
#  'kochsahne - finess von rama',
#  'ei-ersatz%x2c z.b  sojamehlmit  wasser vermischen',
#  'muskatnuss & pfefferaus der mühle',
#  'wacholderbeere zerdrückt /1zerdrückte= 3 ganze',
#  'kräuter nach wahl zumverfeinern der sauce',
#  'pilzekoepfe - drehe diestemme vorsichtig raus',
#  'schnittlauch - hab ich inder hektik auf dem bildvergessen',
#  'alternativ geht auch alsfrische variante  mango',
#  'tomaten gewürfelt sorrynicht in der richtigenreihenfolge',
# ...

# %%
# ingredients with 'aus'

# %%
for index,row in ingr.iterrows():
    if re.search(r'\baus\b .*?',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\baus\b .*?','',row.ingredient_name)

# %%
# ingredeints with 'in meinem kb'
for index,row in ingr.iterrows():
    if re.search(r'\bin\b.*?kb',row.ingredient_name)!=None:
        ingr.drop(index,inplace=True)

# %%
# ingredients with 'z.b.'
for index,row in ingr.iterrows():
    if re.search(r'z\. b\.',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'z\. b\. .*?','',row.ingredient_name)

# %%
# ingredients start with 'ich'
for index,row in ingr.iterrows():
    if re.search('^ich',row.ingredient_name)!=None:
        ingr.drop(index,inplace=True)

# %%
for index,row in ingr.iterrows():
    if (re.search('^habe ich',row.ingredient_name)!=None) or (re.search('^hatte ich',row.ingredient_name)!=None):
        ingr.drop(index,inplace=True)

# %%
for index,row in ingr.iterrows():
    if re.search('- ich.*?',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('- ich.*?','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search('ich habe',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub('ich habe.*?','',row.ingredient_name)

# %%
for index,row in ingr.iterrows():
    if re.search(r'\bca\b',row.ingredient_name)!=None:
        ingr.loc[index,'ingredient_name']=re.sub(r'\bca\b.*?','',row.ingredient_name)

# %%
ich_list=[]
for index,row in ingr.iterrows():
    if re.search(r'\bca\b [0-9]',row.ingredient_name)!=None:
        #ingr.loc[index,'ingredient_name']=re.sub('','',row.ingredient_name)
        ich_list.append(row.ingredient_name)
set(ich_list)
# Out:
# {'ca 1 esslöffel johanisbeergelee',
#  'ca 1 kl milch',
#  'ca 100 gr blaue weintraubenhalbiert',
#  'für ca 1 ltr sosse',
#  'je ca 1 tl maggikraut',
#  'kalbshaxen ca 2',
#  'knollensellerie ca 2*fein gehackt',
#  'paprika ca 3',
#  'reis gegart ca 3 st',
#  'rosinen ca 1 handvoll'}

# %%
ingr=ingr[ingr['ingredient_name']!='']
ingr['ingredient_name']=ingr['ingredient_name'].str.strip()
ingr.dropna(inplace=True)
ingr.shape
# Out:
# (280123, 4)

# %%
ingr.to_csv('datasets/ingr_del_ich.csv')

# %% [markdown]
# ## Deal with the ingredient with only 1 word
# #### 1. POS: Part of speech tagging
# #### 2. delete adj, verb

# %%
# find recipes with ingredients(len=1)

# %%
one_ingr=ingr[ingr['ingredient_name'].str.split().str.len()==1]
one_ingr.shape
# Out:
# (188343, 4)

# %%
one_ingr.tail()
# Out:
#         recipe_id                        recipe_href        name  \
# 280276      47140  /rezept/391537/Sauerrahm-Dip.html        salz
# 280277      47140  /rezept/391537/Sauerrahm-Dip.html      zucker
# 280278      47140  /rezept/391537/Sauerrahm-Dip.html     pfeffer
# 280279      47140  /rezept/391537/Sauerrahm-Dip.html   sauerrahm
# 280280      47140  /rezept/391537/Sauerrahm-Dip.html  mayonnaise
#
#        ingredient_name
# 280276            salz
# 280277          zucker
# 280278         pfeffer
# 280279       sauerrahm
# 280280      mayonnaise

# %%
one_ingr_set=set(one_ingr['ingredient_name'].values.tolist())
len(one_ingr_set)
# Out:
# 10812

# %%
one_ingr.to_csv('datasets/one_ingr.csv')
