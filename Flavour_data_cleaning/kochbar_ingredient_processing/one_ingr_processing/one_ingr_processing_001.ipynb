# %%
import pandas as pd
import numpy as np
import re

# %%
one_ingr=pd.read_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/one_ingr_data/one_ingr_004.csv',index_col=0)
one_ingr.shape
# Out:
# (183960, 4)

# %%
one_ingr[one_ingr['name']=='gemüsebrühe-pulver']
# Out:
#         recipe_id                                        recipe_href  \
# 1430     110419.0  /rezept/160162/Gefuellte-Katoffelkloesschen-in...
# 1553      64063.0  /rezept/466158/Couscous-Salat-Vegetarisch-Somm...
# 2287      66024.0            /rezept/230004/Suppen-Gemuesesuppe.html
# 3704      27525.0  /rezept/57719/Eier-mit-Erbsensauce-und-Pueree....
# 3785      30541.0     /rezept/21665/Linsen-Auflauf-mit-Sellerie.html
# ...           ...                                                ...
# 177246    32058.0        /rezept/465274/Rosenkohl-Broccolisuppe.html
# 178109    13582.0  /rezept/130072/Thueringer-Schichtkraut-Weisskr...
# 179383    32817.0  /rezept/349283/Gemuesecremsuppe-mit-Basilikumn...
# 180756    63996.0    /rezept/288560/Kartoffelsalat-mit-Kraeuter.html
# 181921    13995.0  /rezept/138924/Spaghetti-mit-Bolognese-a-la-Ch...
#
#                       name     ingredient_name
# 1430    gemüsebrühe-pulver  Gemüsebrühe-pulver
# ...

# %%
one_ingr[one_ingr['recipe_id']==25.0]
# Out:
#        recipe_id                                  recipe_href  \
# 71782       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
# 71783       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
# 71784       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
# 71785       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
# 71786       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
# 71787       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
# 71788       25.0  /rezept/419371/Spaghettata-alla-Hannah.html
#
#                                name     ingredient_name
# 71782                          salz                salz
# 71783                        zucker              zucker
# 71784                   tomatenmark         tomatenmark
# 71785                     spaghetti           spaghetti
# 71786            gemüsebrühe-pulver  Gemüsebrühe-pulver
# 71787                  tomatensauce        tomatensauce
# 71788  peperoncini,je nachgeschmack         peperoncini

# %%
one_ingr['recipe_id']=one_ingr['recipe_id'].astype(int)

# %%
one_ingr.head()
# Out:
#    recipe_id                                        recipe_href      name  \
# 0      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      salz
# 1      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    zucker
# 2      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...      mehl
# 3      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...  olivenöl
# 4      15155  /rezept/485268/Pretzel-Pretzel-Dogs-Laugenbret...    wasser
#
#   ingredient_name
# 0            salz
# 1          zucker
# 2            mehl
# 3        olivenöl
# 4          wasser

# %%
one_ingrs=list(set(one_ingr['ingredient_name'].values.tolist()))
len(one_ingrs)
# Out:
# 7519

# %%
one_ingrs.sort()
one_ingrs
# Out:
# ['-marmelade',
#  '1',
#  '1/',
#  '1ei',
#  '1ig',
#  '1lorbeerblatt',
#  '3pimentn',
#  '4',
#  '5',
#  '5-Gewürzepulver',
#  '6-kräuter',
#  '7-pfeffer-gewürz',
#  '8-kräuter',
#  '8-kräuter-mischung',
#  '8-kräutermischungtk',
#  '85',
#  'Ackerlauch',
#  'Agar',
#  'Almond',
#  'Anise',
#  'Apfel',
#  'Apfel_Balsamico',
#  'Apfelmus',
#  'Apfelsaft',
#  'Apple',
#  'Apple_Cider_Vinegar',
#  'Apricot',
#  'Armagnac_Brandy',
#  'Artichoke',
#  'Asparagus',
#  'Atlantic_Herring',
#  'Atlantic_Mackerel',
#  'Aubergine',
#  'Aufbacksbrot',
#  'Bacon',
#  'Baguette',
#  'Baguettes',
#  'Baiser',
#  'Baked_potato',
#  'Balsamico',
#  'Bamboo_Shoots',
#  'Banana',
#  'Barley',
#  'Basil',
#  'Beef',
#  'Beer',
#  'Berry',
#  'Birne',
#  'Biscuit',
#  'Bismarckhering',
#  'Bison',
#  'Black_Raspberry',
#  'Blätterteig',
#  'Borage',
#  'Bread',
#  'Brie_cheese',
#  'Broccoli',
#  'Brot',
#  'Brühwurst',
#  'Buckwheat',
#  'Butter',
#  'Butterfish',
#  'Cabage',
#  'Cabbage',
# ...

# %%
whole_delete=['1','1/','1ig','4','5','85']

# %%
one_ingr=one_ingr[~one_ingr['ingredient_name'].isin(whole_delete)]
one_ingr.reset_index(drop=True,inplace=True)

# %%
one_ingr.shape
# Out:
# (183950, 4)

# %%
one_ingr_done=one_ingr[one_ingr['ingredient_name'].str[0].str.isupper()]
one_ingr_done.shape
# Out:
# (17377, 4)

# %%
one_ingr_pending=one_ingr[one_ingr['ingredient_name'].str[0].str.islower()]
one_ingr_pending.shape
# Out:
# (166559, 4)

# %%
one_ingr_pending.reset_index(drop=True,inplace=True)

# %%
one_ingrs_pending=list(set(one_ingr_pending['ingredient_name'].values.tolist()))
len(one_ingrs_pending)
# Out:
# 7084

# %%
one_ingrs_pending.sort()
one_ingrs_pending
# Out:
# ['a',
#  'ace-saft',
#  'acht-kräuter',
#  'advocaat',
#  'aepfel',
#  'african-pepper',
#  'agartine',
#  'agavendicksaft',
#  'agavensirup',
#  'ahornsirup',
#  'aioli',
#  'ajvar',
#  'ajwar',
#  'akazienblüten',
#  'akazienhonig',
#  'alaska-seelachs',
#  'alba-öl',
#  'albaöl',
#  'alfalfasprossen',
#  'algen',
#  'alginat',
#  'alkohol',
#  'alpenmilchschokolade',
#  'alpenschinken',
#  'alsan',
#  'alt',
#  'altbier',
#  'altergryere-käse',
#  'altesgewürzamt',
#  'altmeister',
#  'altmeister-essig',
#  'altmeisteressig',
#  'alu-grillschalen',
#  'alz',
#  'amaranth',
#  'amarantmehl',
#  'amarena-eis',
#  'amarenakirschsirup',
#  'amaretti',
#  'amarettini',
#  'amaretto',
#  'amaretto-sirup',
#  'amarettosirup',
#  'amarula',
#  'amerettini',
#  'amicelli',
#  'ampelpaprika',
#  'anaheimchili',
#  'ananansaft',
#  'anananssaft',
#  'ananas',
#  'ananas-',
#  'ananas-cocos-saft',
#  'ananas-direktsaft',
#  'ananas-konfitüre',
#  'ananasabtopfgewicht',
#  'ananascurry',
# ...

# %%
# form one_ingr_dataset

# %%
one_pending_df=pd.DataFrame(one_ingrs_pending,columns=['ingredient_name'])
one_pending_df['parse_ingr']=one_pending_df['ingredient_name']
one_pending_df.shape
# Out:
# (7084, 2)

# %%
one_pending_df
# Out:
#                     ingredient_name                     parse_ingr
# 0                     weizenflocken                  weizenflocken
# 1              alpenmilchschokolade           alpenmilchschokolade
# 2                           ketchup                        ketchup
# 3                        pfirsische                     pfirsische
# 4                  marzipanrohmasse               marzipanrohmasse
# ...                             ...                            ...
# 7079                 tiefkühlgemüse                 tiefkühlgemüse
# 7080                      pizzakäse                      pizzakäse
# 7081                      kokosette                      kokosette
# 7082                      gurkensud                      gurkensud
# 7083  backfestevanillepuddingpulver  backfestevanillepuddingpulver
#
# [7084 rows x 2 columns]

# %%
one_pending_df[one_pending_df['ingredient_name']=='gemüsebrühe-pulver']
# Out:
#      ingredient_name parse_ingr
# 4352          dotter     dotter

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'^z',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['z.b-emmentaler',
#  'z.bsp.grafschafter',
#  'z.bsp.nutella',
#  'z.bsp.parmesan',
#  "za'atar",
#  'zahlen',
#  'zahnstocher',
#  'zander',
#  'zanderfilet',
#  'zanderfilets',
#  'zart',
#  'zartbiterschokolade',
#  'zartbitter',
#  'zartbitter-blockschokolade',
#  'zartbitter-kuvertüre',
#  'zartbitter-kuvertüre-chips',
#  'zartbitter-schokolade',
#  'zartbitter-schokoladentröpfchen',
#  'zartbitter-schokostreusel',
#  'zartbitterflocken',
#  'zartbitterkuvertüre',
#  'zartbitterschokolade',
#  'zartbitterschokoladegerieben',
#  'zartbitterschokoladekuvertüre',
#  'zartbitterschokoraspel',
#  'zartdinkel',
#  'zatziki',
#  'zebra',
#  'zehe',
#  'zehen',
#  'zeller',
#  'zelt',
#  'zerkleinert',
#  'zesten',
#  'zet',
#  'zhoug',
#  'zichorie',
#  'ziebeln',
#  'ziegenfrischkäse',
#  'ziegenfrischkäse-pralinen',
#  'ziegenfrischkäsegemacht',
#  'ziegenfrischkäsetaler',
#  'ziegengouda',
#  'ziegenjohurt',
#  'ziegenkäse',
#  'ziegenkäse-medaillons',
#  'ziegenkäserolle',
# ...

# %%
whole_delete=['zuckercouleur','zuckerdeko','zuckerdekor','zuckeren','zuckerperlchen','zuckerperlen',
'zahlen','zart','zehe','zehen','zeller','zelt','zerkleinert','zesten','zet','ziebeln','zt',
'weiches','weiss','weisse','weisser','wenig','wiener-','wild','wurzelwerk','würzig','z.bsp.grafschafter',
'vegan','veganer','versprudelt','verzierung','vomvortag','wachteln','wald','ware','warm','weich','weiche',
'tannenbaum-flasche','teil','tetrapack','theke','tiefkühl','us','us-spitz','vakuumverpackt','vani',
's','saison','salat.html','salzig','sauber','saure','schale','schalen','scharf','scharfe','schicht'
'rezept-rührteig','roh','roh/geräuchert','rohe','rot/gelb','rote/grüne','rote','roten','roter','rotes',
'passiert','passierter','pros','pur','qualität','r','reif','reife','rest','reste','rezept','rezept.html',
'meine','mit','mittel','most','natur','nesquik','nussig','obers','od.','packungen','palette','passieren',
'mehligesorte','mehligkochend','mehligkochende','mehligkochendesorte','mehr','mehrkornflocken','mehrkornmehl',
'n.','nach','nachwunsch','normal','r','s','tube','u.','us','xm','mich','mie','mid','mehlig','mehlige',
'lebensmittelfarben','lebensmittelfarberot','lgehackt','liebe','luft','läufe','löffel','m','msc','n',
'kurz','kurze','l','laden','lage','lardo','lassen', 'lauche','lax','lebensmittelfarbe',
'kochflüssigkeit','kochwasser','konfekt','konserve','konseve','konzentriert','kopf','kräftig','kräftige',
'klar','kle','klein','kleine','kleinere','knorr','knust','kochbeutel','kochen','kochend','kochendes',
'isomalt','jung','jus','junger','k','kalt','kandiert','kann','karton','kb','keim','kerne','kikkoman',
'hier', 'hkl','hol','holl','hugo','höher','ig','igen','in','indonesisch','inflöckchen','inm','inwuerfel','inöl',
'haut','hecht','heiss','heisse','heit','hell','helle','helles','herzbackform','herz','herzen','herzform',
'grünes','gut','guter','gutes','hack','halb','halbe','halbenb','hals','halsgrat','hart','hauptgericht',
'gramm','grammeln','granny´s','grieben','griffig','grob','grösse','gräten','grü','grün','grüner','grünerdekorzucker',
'geschnetzeltes','getrockne','getrocknet', 'getrocknete', 'ggf','glas','glatt','glatte','gold','gr',
'gefr','gelb','gelbe','gem','gemischte','gerieben','geräucherte','geschmack','geschmacks','geschnitten',
'fruchtig','fäden','fülle','füllung','für','fuego','g','gahackt','ganz','ganze','ge','geb','gee','geer',
'fino','flocken','flüssig','flüssigersüssstoff','flüssigkeit','form','freiland','frisch','frisch-',
'f','fein','feine','feld','fertig','fertige','fest','fet','fiengehackt','filet','filetköpfe','finesse',
'a','alt','alsan','alu-grillschalen','alz','andere','anderesorte','asc','asia-laden','asialaden','aufgelöstekuvertüre',
'aus','aussen','ausstechform','backform','backofen','be','beelitz','bitter','blatt','blaue','blätter',
'braten','braun','braune','brug','bug','ca','calciumchlorid','cappellini','cassis', 'chantre',
'cm','co','dagmar','dazu','deco','deko','dekor','delikatess','dem','demglas','demasiamarkt','demvorrat',
'den','derdose','derkühltheke','dermühle','derschale','derschulter','dick','dicke','dickestangen','dickmanns',
'die','dieform','diverses','dose','dosen','dosenware','dotter','dunkel','dunkle','dünn','dünne',
'e','ebly','ein','eingelegt','el','el-süss-sauer-ein','eln','elt','emu','en','enden','entkernt','eoi',
'ep','eputzt','er','er-ein-wahrer-fre','erbar','erlikör','ert','es','ersatz','ermann']

# %%
one_pending_df=one_pending_df[~one_pending_df['parse_ingr'].isin(whole_delete)]
one_pending_df.reset_index(drop=True,inplace=True)

# %%
whole_change_dict={'urnerCheese':'cheese','zuccch':'zucchini','zucchetti':'zucchini',
'tortilla':'corn_tortilla','tortillachips':'corn_tortilla','ursalz':'salt','urdinkelmehl':'wheat',
'tagliatelle':'tagliatelle_pasta','tagliolini':'tagliolini_pasta','tagliolini/bandnudeln':'tagliolini_pasta',
'saitenwürstchen':'saiten_sausage','salaz':'salt','salze':'salt','tabascosauce':'tabasco_sauce',
'rigatoni':'rigatoni_pasta','rigatoni-nudeln':'rigatoni_pasta','saalz':'salt','saiten':'saiten_sausage',
'ricotta':'ricotta_cheese','ricottakäse':'ricotta_cheese','rigatonelli':'rigatoni_pasta',
'raclette':'raclette_cheese','raclettekäse':'raclette_cheese','ras-el-hanout':'ras_el_hanout',
'prosciutto':'prosciutto_sausage','proscuitto':'prosciutto_sausage','quargel':'cheese','quargeln':'cheese',
'penne':'penne_pasta','penne--nudeln':'penne_pasta','penne-nudeln':'penne_pasta',
'paprikaedellsüss':'sweet_paprika_powder','paprikaedelsüss':'sweet_paprika_powder','paprikaedelsüss)':'sweet_paprika_powder',
'maisena':'starch','oystern-sauce':'oyster_sauce','oystersauce':'oyster_sauce','paprika-edelsüss':'sweet_paprika_powder',
'kalberwürste':'beef_sausage','koniak':'cognac','lerdammer':'leerdammer_cheese','yufkablätter':'yufka',
'jalapenos':'jalapeno_chili','jalapeño':'jalapeno_chili','kabanossi':'cabanossi_sausage',
'hierparmesan':'parmesan_cheese','hüttenkäse':'cottage_cheese','hollandaise':'hollandaise_sauce','hollondaise':'hollandaise_sauce',
'habanero':'habanero_chili','habaneroschote':'habanero_chili','hierminifarfalle':'farfalle_pasta',
'cabanossi':'cabanossi_sausage','cabanossis':'cabanossi_sausage','camembert':'camembert_cheese',
'canelloni':'cannelloni_pasta','cannelloni':'cannelloni_pasta','cantucchini':'cantuccini','cellentani':'cellentani_pasta',
'cervelat':'cervelat_sausage','cervelatwurst':'cervelat_sausage','cheddar':'cheddar_cheese',
'chester':'chester_cheese','chorizo':'chorizo_sausage','chourico':'chorizo_sausage','conchiglioni':'conchiglioni_pasta',
'creme-legere':'creme_legere','cremelegere':'creme_legere','cremefin':'cremefine','cremefraiche':'creme_fraiche',
'eapfel':'apple','engelshaar-pasta':'pasta','farfalle':'farfalle_pasta','feta':'feta_cheese',
'fettuccine':'fettuccine_pasta','fleischkäse':'cream_cheese','galantine':'gelatin','gelantine':'gelatin','gelatine':'gelatin',
'gouda':'gouda_cheese','graupen':'barley','grkrokant':'krokant','guindillas':'chili'}

# %%
def replace_whole_ingr(k,v,ingredient):
    if ingredient==k:
        return v
    else:
        return ingredient

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
keep_ingrs=list(whole_change_dict.values())

# %%
one_ingr_done=one_pending_df[one_pending_df['parse_ingr'].isin(keep_ingrs)]
one_ingr_done.shape
# Out:
# (93, 2)

# %%
one_ingr_done.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/one_ingr_data/one_ingr_done_001.csv')

# %%
one_pending_df=one_pending_df[~one_pending_df['parse_ingr'].isin(keep_ingrs)]
one_pending_df.reset_index(drop=True,inplace=True)
one_pending_df.shape
# Out:
# (6636, 2)

# %%
delete_parts=['abtopfgewicht','ringe','stuecke','wuerfel','anderes','streifen','delikatess-','delikatess','einlege','einige',
'ersatzw.','feinhackte','fertig-','fertig','gefüllten','gem.','gemischte','gerieben','getrocknete',
'ggf.','gr.','grieben','haushalts','blätter','kleine','lieblings-','getrocknet','-gemahlen','gehackt',
'schale','od.','tiefkühl','topf','z.b-','z.bsp.']

# %%
def del_part(part,ingredient):
    no_part=ingredient.replace(part,'')
    return no_part

# %%
for part in delete_parts:
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:del_part(part,x))

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'^a',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ace-saft',
#  'acht-kräuter',
#  'advocaat',
#  'aepfel',
#  'african-pepper',
#  'agartine',
#  'agavendicksaft',
#  'agavensirup',
#  'ahornsirup',
#  'aioli',
#  'ajvar',
#  'ajwar',
#  'akazienblüten',
#  'akazienhonig',
#  'alaska-seelachs',
#  'alba-öl',
#  'albaöl',
#  'alfalfasprossen',
#  'algen',
#  'alginat',
#  'alkohol',
#  'alpenmilchschokolade',
#  'alpenschinken',
#  'altbier',
#  'altergryere-käse',
#  'altesgewürzamt',
#  'altmeister',
#  'altmeister-essig',
#  'altmeisteressig',
#  'amaranth',
#  'amarantmehl',
#  'amarena-eis',
#  'amarenakirschsirup',
#  'amaretti',
#  'amarettini',
#  'amaretto',
#  'amaretto-sirup',
#  'amarettosirup',
#  'amarula',
#  'amerettini',
#  'amicelli',
#  'ampelpaprika',
#  'anaheimchili',
#  'ananansaft',
#  'anananssaft',
#  'ananas',
#  'ananas-',
#  'ananas-cocos-saft',
#  'ananas-direktsaft',
#  'ananas-konfitüre',
#  'ananascurry',
#  'ananasjoghurt',
#  'ananaskonserve',
#  'ananasminze',
#  'ananasring',
#  'ananassaft',
# ...

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'putenbrust',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# []

# %%
whole_change_dict={'roastbeef':'roasted_beef','rösti':'Rösti','rosenmehl':'wehat',
'rinderbraten':'roasted_beef','rinderbratenfond':'roasted_beef','rinderleber':'beef_liver',
'riesengrnelen':'shrimp','riessengarnelen':'shrimp','rinder-brühe':'beef_broth',
'rafaello':'raffaello','raffaelo':'raffaello','rauchwürstchen':'smoked_sausage','riesengarnelen':'shrimp',
'quittengelee':'quince_jelly','quittengellee':'quince_jelly','quitten-gelee':'quince_jelly','qittengelee':'quince_jelly',
'pfefffer':'pepper','salz-pfeffer-piment-lorbeer':'salt,pepper,pimento,bay',
'pfefer':'pepper','pfeffe':'pepper','pfeffeer':'pepper','pferffer':'pepper','pfgeffer':'pepper','pfeffet':'pepper',
'balsam':'balsamic_vinegar','balsamessig':'balsamic_vinegar','balsami':'balsamic_vinegar',
'balsamico':'balsamic_vinegar','balsamico-balsam':'balsamic_vinegar','balsamico-essenz':'balsamic_vinegar',
'balsamico-essig':'balsamic_vinegar','balsamico-mango-essig':'mango_balsamic_vinegar',
'balsamico-orange':'orange_balsamic_vinegar','balsamico-rosso':'balsamic_vinegar','balsamico-senf':'mustard_balsamic_vinegar', 
'balsamicoessig':'balsamic_vinegar','birnenbalsam':'pear_balsamic_vinegar','birnenbalsamico':'pear_balsamic_vinegar',
'brombeerbalsam':'blackberry_balsamic_vinegar','erdbeer-balsam':'strawberry_balsamic_vinegar',
'feigen-balsamico':'fig_balsamic_vinegar','feigenbalsamessig':'fig_balsamic_vinegar','haselnussbalsam':'hazelnut_balsamic_vinegar',
'himbeer-balsamico':'rapsberry_balsamic_vinegar','honig-balsamico':'honey_balsamic_vinegar',
'ingwer-trauben-balsam':'ginger_grape_balsamic_vinegar','kirschbalsamico':'cherry_balsamic_vinegar',
'mangobalsam':'mango_balsamic_vinegar','mangobalsamessig':'mango_balsamic_vinegar',
'orangenbalsamico':'orange_balsamic_vinegar','pflaumenbalsam-essig':'plum_balsamic_vinegar',
'sherry-balsamico':'sherry_balsamic_vinegar','waldhimbeer-balsam':'rapsberry_balsamic_vinegar',
'waldhimbeer-balsamico':'rapsberry_balsamic_vinegar','balsamico-dressing':'balsamic_vinegar',
'balsamico-creme':'balsamico_creme','balsamicocrem':'balsamico_creme','balsamicocreme':'balsamico_creme',
'dattel-balsam-creme':'date_balsamico_creme','dattel-balsamico-creme':'date_balsamico_creme',
'preiselbeer-balsam-creme':'lingonberry_balsamico_creme','ital.kräuter':'italian_herb','jodsalz':'salt',
'kanoblauchzehe':'garlic','knobizehe':'garlic','knobizehen':'garlic','lammgewürz':'lamb_spice',
'leerdamer':'leerdammer_cheese','leerdammer':'leerdammer_cheese','leerdammerkäse':'leerdammer_cheese',
'morarella':'mozzarella_cheese','morzarella':'mozzarella_cheese','mozarella-kugeln':'mozzarella_cheese',
'mozarellalakugeln':'mozzarella_cheese','mozzarella':'mozzarella_cheese',
'ochsenherztomaten':'toamto','spitzpaprikaschoten':'chili','pecan':'pecan','pellkartoffel':'potato',
'persilie':'parsley','pertersilie':'parsley','peterilien':'parsley','peterle':'parsley','peterli':'parsley',
'peters.':'parsley','petersiie':'parsley','petersilei':'parsley','petersilien-knoblauch-salz':'parsley,garlic,salt',
'petersilin':'parsley','petersille':'parsley','peterslie':'parsley','petesilie':'parsley',
'petrsilie':'parsley','petresilie':'parsley','fleischbällchen':'meat','hummerpaste':'lobster_paste',
'hähnchenleber':'chicken_liver','hähnchenwürzsalz':'chicken_liver','gauda':'gouda_cheese','gänseblümchen':'daisy'}

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
contain_change_dict={'basmati':'rice','fleischb':'meat_broth','forelle':'trout','gemueseb':'vegetable_broth',
'gemueseb':'vegetable_broth','gewürzgurk':'gherkin','gänse':'goose','herings':'herring',
'hirschhornsalz':'salt','hummer':'lobster','hähnchengewürz':'chicken_spice','hæhnchen':'chicken',
'hühnchen':'chicken','hühnerbrust':'chicken','kalbs':'veal','kaninchen':'rabbit','kartoffelbrei':'mashed_potato',
'kartoffelpü':'mashed_potato','kohlrabi':'kohlrabi','lachsfilet':'salmon','lachsko':'salmon',
'lauchst':'leek','macis':'nutmeg','pangasius':'iridescent_shark','paprikaschoten':'bell_pepper',
'parmesan':'parmesan_cheese','peterselie':'parsley','petersilie':'parsley','petersillie':'parsley',
'pfefferk':'pepper','putenbrust':'turkey','puten':'turkey','piment':'pimento','raffaello':'raffaello',
'rinderb':'beef_broth','rinderfond':'beef_broth','rindfleisch':'beef'}

# %%
def replace_ingr(k,v,ingredient):
    if re.findall(k,ingredient):
        return v
    else:
        return ingredient

# %%
for k,v in contain_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
contain_change_dict={'gänse':'goose','hähnchen':'chicken','hühnerb':'chicken_broth',
'seelach':'salmon','hühner':'chicken','rinder':'beef'}

# %%
for k,v in contain_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_ingr(k,v,x))

# %%
pending_ingrs=list(set(one_pending_df['parse_ingr'].values.tolist()))
len(pending_ingrs)
# Out:
# 6028

# %%
one_pending_df
# Out:
#        ingredient_name        parse_ingr
# 0              wirsing           wirsing
# 1       schinkensalami    schinkensalami
# 2             bouillon          bouillon
# 3                salat             salat
# 4     zucker-aprikosen  zucker-aprikosen
# ...                ...               ...
# 6631   rohrzuckersirup   rohrzuckersirup
# 6632    rosmarinbutter    rosmarinbutter
# 6633  curry-grillsauce  curry-grillsauce
# 6634         dijonsenf         dijonsenf
# 6635      limettensaft      limettensaft
#
# [6636 rows x 2 columns]

# %%
# ^lorbeer-->bay,^lamm-->lamb,^reh-->deer,

# %%
for index,row in one_pending_df.iterrows():
    if re.search(r'^lorbeer',row.parse_ingr)!=None:
        # print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='bay'

# %%
for index,row in one_pending_df.iterrows():
    if re.search(r'^lamm',row.parse_ingr)!=None:
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='lamb'

# %%
for index,row in one_pending_df.iterrows():
    if re.search(r'^reh',row.parse_ingr)!=None:
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='deef'

# %%
whole_delete=['et','etc','extra','gemahlen','html','keit','kräftigabgeschmeckt','kuchendeko','laktosefrei','leichtangeräuchert',
'leichtgeräuchert','leichtgesüsst','leichtzerquetscht','lein','leinentuch','pergament','rezept-rührteig',
'rezeptbisquitteig','richtige','rot','vorwiegend', 'vorspeise']

# %%
one_pending_df=one_pending_df[~one_pending_df['parse_ingr'].isin(whole_delete)]
one_pending_df.reset_index(drop=True,inplace=True)

# %%
one_pending_df.shape
# Out:
# (6614, 2)

# %%
keep_list_001=list(whole_change_dict.values())
keep_list_002=list(contain_change_dict.values())

# %%
keep_list=keep_list_001+keep_list_002
len(keep_list)
# Out:
# 137

# %%
one_ingr_done=one_pending_df[one_pending_df['parse_ingr'].isin(keep_list)]
one_ingr_done.shape
# Out:
# (547, 2)

# %%
#one_ingr_done.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/one_ingr_data/one_ingr_done_002.csv')

# %%
one_pending_df=one_pending_df[~one_pending_df['parse_ingr'].isin(keep_list)]
one_pending_df.reset_index(drop=True,inplace=True)
one_pending_df.shape
# Out:
# (6067, 2)

# %%
one_pending_df
# Out:
#        ingredient_name        parse_ingr
# 0              wirsing           wirsing
# 1       schinkensalami    schinkensalami
# 2             bouillon          bouillon
# 3                salat             salat
# 4     zucker-aprikosen  zucker-aprikosen
# ...                ...               ...
# 6062   rohrzuckersirup   rohrzuckersirup
# 6063    rosmarinbutter    rosmarinbutter
# 6064  curry-grillsauce  curry-grillsauce
# 6065         dijonsenf         dijonsenf
# 6066      limettensaft      limettensaft
#
# [6067 rows x 2 columns]

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'pudding',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ananascurry',
#  'anapurna-curry',
#  'curry',
#  'curry-',
#  'curry-bratwürste',
#  'curry-grillsauce',
#  'curry-paste',
#  'curry-pulver',
#  'curry-salz',
#  'curry-sauce',
#  'curry-öl',
#  'curry/paprika',
#  'currybutter',
#  'currygewürz',
#  'currygewürzmischung',
#  'curryketchup',
#  'currykraut',
#  'currynudeln',
#  'currypaste',
#  'currypowder',
#  'currypulve',
#  'currypulver',
#  'currysalz',
#  'currysauce',
#  'currysenf',
#  'currywurst',
#  'currywürste',
#  'curryöl',
#  'jaipur-curry',
#  'kashmir-curry',
#  'korma-currypaste',
#  'madras-currypulver',
#  'madrascurry',
#  'panang-currypaste',
#  'thai-currypulver',
#  'tomaten-curry-sauce',
#  'vindaloo-currypaste',
#  'zitronencurry']

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'pudding',row.parse_ingr)!=None) & (re.search(r'vanil',row.parse_ingr)!=None):
        # print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='vanilla_pudding'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'pudding',row.parse_ingr)!=None) & (re.search(r'va',row.parse_ingr)!=None):
        # print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='vanilla_pudding'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'pudding',row.parse_ingr)!=None) & (re.search(r'schoko',row.parse_ingr)!=None):
        # print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='chocolate_pudding'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'pudding',row.parse_ingr)!=None) & (re.search(r'sahne',row.parse_ingr)!=None):
        # print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='cream_pudding'

# %%
whole_change_dict={'zitronenpudding':'lemon_pudding','zitronenpuddingpulver':'lemon_pudding',
'erdbeerpuddingpulver':'strawberry_pudding','karamellpuddingpulver':'caramel_pudding',
'mandelpuddingpulver':'almond_pudding','mokkapudding':'mocha_pudding',
'möhrenpudding':'carrot_pudding','pudding-/saucenpulver/cremespeisenpulver':'cream_pudding',
'puddingcreme':'cream_pudding','puddingpulverhimbeergeschack':'raspberry_pudding',
'sckokoladenpudding':'chocolate_pudding','straciatellapuddingpulver':'stracciatella_pudding',
'v-pudding':'vanilla_pudding','galetta-pudding':'galetta_pudding','griesspudding':'semolina_pudding',
'kochpuddingpulver':'pudding','puddingpulver':'pudding','puddingvulver':'pudding','puddingpuver':'pudding'}

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'^a',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['ace-saft',
#  'acht-kräuter',
#  'advocaat',
#  'aepfel',
#  'african-pepper',
#  'agartine',
#  'agavendicksaft',
#  'agavensirup',
#  'ahornsirup',
#  'aioli',
#  'ajvar',
#  'ajwar',
#  'akazienblüten',
#  'akazienhonig',
#  'alba-öl',
#  'albaöl',
#  'alfalfasprossen',
#  'algen',
#  'alginat',
#  'alkohol',
#  'almond_pudding',
#  'alpenmilchschokolade',
#  'alpenschinken',
#  'altbier',
#  'altergryere-käse',
#  'altesgewürzamt',
#  'altmeister',
#  'altmeister-essig',
#  'altmeisteressig',
#  'amaranth',
#  'amarantmehl',
#  'amarena-eis',
#  'amarenakirschsirup',
#  'amaretti',
#  'amarettini',
#  'amaretto',
#  'amaretto-sirup',
#  'amarettosirup',
#  'amarula',
#  'amerettini',
#  'amicelli',
#  'ampelpaprika',
#  'anaheimchili',
#  'ananansaft',
#  'anananssaft',
#  'ananas',
#  'ananas-',
#  'ananas-cocos-saft',
#  'ananas-direktsaft',
#  'ananas-konfitüre',
#  'ananascurry',
#  'ananasjoghurt',
#  'ananaskonserve',
#  'ananasminze',
#  'ananasring',
#  'ananassaft',
# ...

# %%
# 'joghurt','konfitüre','marmelade','likör','saft'

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'likör',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['anislikör',
#  'aprikosenlikör',
#  'aprikosenlikör/marillenlikr',
#  'aprokosenlikör',
#  'französischerpfirsichlikör',
#  'hiervanille-eierlikör',
#  'himbeerlikör',
#  'himbeerwölkchenlikör',
#  'kirschbeerlikör',
#  'kirschlikör',
#  'kokoslikör',
#  'lemoncillo--ital.zitronenlikör',
#  'likör',
#  'likör/schnaps',
#  'liköre',
#  'limettenlikör',
#  'mandarinenlikör',
#  'mandellikör',
#  'marillenlikör',
#  'melonenlikör',
#  'mintlikör',
#  'minzelikör',
#  'nusslikör',
#  'orangenlikör',
#  'pfefferminzlikör',
#  'pfirsich-likör',
#  'pfirsichlikör',
#  'pflaumenlikör',
#  'sauerekirschlikör',
#  'schokoladenlikör',
#  'schokolikör',
#  'vanillelikör',
#  'weinbergpfirsichlikör',
#  'winterapfel-likör',
#  'zitronenlikör']

# %%
whole_change_dict={'winterapfel-likör':'apple_liqueur',
    'likör':'liqueur','likör/schnaps':'liqueur','weinbergpfirsichlikör':'peach_liqueur',
    'französischerpfirsichlikör':'peach_liqueur','lemoncillo--ital.zitronenlikör':'lemon_liqueur',
    'aprikosenlikör/marillenlikr':'apricot_liqueur','hiervanille-eierlikör':'vanilla_egg_liqueur',
    'apfellikör':'apple_liqueur','beeren-likör':'berry_liqueur','birnenlikör':'pear_liqueur',
'cappuccino-sahne-likör':'cappuccino_cream_liqueur','cremelikör':'cream_liqueur',
'dooleys-likör':'dooleys_liqueur','eierlikör':'egg_liqueur','eierlikörsahne':'egg_liqueur_liqueur',
'erdbeerlikör':'strawberry','galliano-likör':'galliano_liqueur','grenadine-likör':'grenadine_liqueur',
'haselnusslikör':'hazelnut_liqueur','haselnusslikör':'vanilla_egg_liqueur','italienischermandellikör':'almond_liqueur',
'johannisbeerlikör':'currant_liqueur','kaffeelikör':'coffee_liqueur','mangolikör':'mango_liqueur',
'maracujalikör':'passion_fruit_liqueur','mlkaffeelikör':'coffee_liqueur','sahnelikör':'cream_liqueur',
'sanddornlikör':'sea_buckthorn_liqueur'}

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'marmelade',row.parse_ingr)!=None) & (re.search(r'ribi',row.parse_ingr)!=None):
        print(row.parse_ingr)
        #one_pending_df.loc[index,'parse_ingr']='redcurrant_jam'

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'marmelade',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# []

# %%
whole_change_dict={'ermarmelade':'jam','hellemarmelade':'jam','marmelade':'jam','pfirsich-marmelade':'peach_jam',
    'aprkosenmarmelade':'apricot_jam','blaubeermarmelade':'blueberry_jam','brombeermarmelade':'blackberry_jam',
'erdbeermarmelade':'strawberry_jam','feigenmarmelade':'fig_jam','granatapfel-marmelade':'apple_jam',
'heidelbeermarmelade':'blueberry_jam','himbeermarmelade':'raspberry_jam','himmbeermarmelade':'raspberry_jam',
'ingwermarmelade':'ginger_jam','johannisbeermarmelade':'currant_jam','kirsch-marmelade':'cherry_jam',
'kirschmarmelade':'cherry_jam','mangomarmelade':'mango_jam','marillenmarmelade':'apricot_jam',
'möhrenmarmelade':'carrot_jam','pfirsich-maracuja-marmelade':'peach_passion_fruit_jam',
'pfirsichmarmelade':'peach_jam','pflaumen-lebkuchen-amarettomarmelade':'plum_amaretto_jam',
'pflaumenmarmelade':'plum_jam','sauerkirschmarmelade':'sour_cherry_jam','tomatenmarmelade':'tomato_jam',
'waldfruchtmarmelade':'fruit_jam','weichselmarmelade[sauerkirschmarmelade':'sour_cherry_jam',
'zitronenmarmelade':'lemon_jam','zwetschgenmarmelade':'plum_jam'}

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'marmelade',row.parse_ingr)!=None) & (re.search(r'ribi',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='redcurrant_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'marmelade',row.parse_ingr)!=None) & (re.search(r'prei',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='lingonberry_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'marmelade',row.parse_ingr)!=None) & (re.search(r'or',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='orange_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'marmelade',row.parse_ingr)!=None) & (re.search(r'hagebutten',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='rose_hip_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'marmelade',row.parse_ingr)!=None) & (re.search(r'aprik',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='apricot_jam'

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'konfitüre',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['zwetschgenkonfitüre']

# %%
whole_change_dict={'ananas-konfitüre':'pineapple_jam','bratapfel-konfitüre':'apple_jam',
                   'kiwi-stachelbeerkonfitüre':'kiwi_gooseberry_jam',
                  'blaubeerkonfitüre':'blueberry_jam','hagebuttenkonfitüre':'rose_hip_jam',
                  'marillenkonfitüre':'apricot_jam','pfirsich-maracuja-konfitüre':'peach_passion_fruit_jam',
                  'konfitüre':'jam','zwetschgenkonfitüre':'plum_jam'}

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'konfitüre',row.parse_ingr)!=None) & (re.search(r'preis',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='lingonberry_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'konfitüre',row.parse_ingr)!=None) & (re.search(r'orangen',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='orangen_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'konfitüre',row.parse_ingr)!=None) & (re.search(r'kirsch',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='cherry_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'konfitüre',row.parse_ingr)!=None) & (re.search(r'himbeer',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='raspberry jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'konfitüre',row.parse_ingr)!=None) & (re.search(r'apri',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='apricot_jam'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'konfitüre',row.parse_ingr)!=None) & (re.search(r'erdbeer',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='strawberry_jam'

# %%
ingr_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'saft',row.parse_ingr)!=None:
        ingr_list.append(row.parse_ingr)
ingr_list=list(set(ingr_list))
ingr_list.sort()
ingr_list
# Out:
# ['saftig']

# %%
whole_change_dict={'ersaft':'juice','melon_saft':'melon_juice','saft':'juice',
    'osaft':'juice','saft':'juice','senfgurken-saft':'mustard_cucumber_juice',
    'ace-saft':'juice','gurkensaft':'cucumber_juice','mlo-saft':'juice','o-saft':'saft',
    'möhrensaft':'carrot_juice','erdbeersaft':'strawberry_juice','fruchtsaft':'juice','fruchtssaft':'juice',
    'litschisaft':'lychee_juice','karpernsaft':'carp juice','limonensaft':'lime_juice',
    'ananas-cocos-saft':'pineapple_coco_juice','erdbeerkirschsaft':'strawberry_cherry_juice',
'aprikosensaft':'apricot_juice','artischokensaft':'artichoke_juice','bananensaft':'banana_juice',
'birnensaft':'pear_juice','blaubeersaft':'blueberry_juice','brombeersaft':'blackberry_juice',
'clemtinensaft':'clementine_juice','cranberrysaft':'cranberry_juice','grapefruitsaft':'grapefruit_juice',
'heidelbeersaft':'blueberry_juice','himbeersaft':'raspberry_juice','karottensaft':'carrot_juice',
'mangosaft':'mango_juice','maracujasaft':'passion_fruit_juice','marakujasaft':'passion_fruit_juice',
'melonensaft':'melon_saft','organgensaft':'orange_juice','pfirsichsaft':'peach_juice',
'pflaumensaft':'plum_juice','rababersaft':'rhubarb_juice','rhabarbersaft':'rhubarb_juice',
'rote-bete-saft':'beetroot_juice','sanddornsaft':'sea_buckthorn_juice','stachelbeersaft':'gooseberry_juice',
 'tomatensaft':'toamto_juice','traubensaft':'grape_juice','bratensaft':'gravy','bratensaft-pulver':'gravy',
'elsaft':'juice'}

# %%
for k,v in whole_change_dict.items():
    one_pending_df['parse_ingr']=one_pending_df['parse_ingr'].apply(lambda x:replace_whole_ingr(k,v,x))

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'ag',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='agave syrup'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'kir',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='cherry_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'ana',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='pineapple_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'erbee',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='strawberry_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'sauer',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='sour_cherry_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'lime',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='lime_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'apfe',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='apple_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'zit',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='lemon_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'ora',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='orange_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'joha',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='currant_juice'

# %%
for index,row in one_pending_df.iterrows():
    if (re.search(r'saft',row.parse_ingr)!=None) & (re.search(r'mand',row.parse_ingr)!=None):
        #print(row.parse_ingr)
        one_pending_df.loc[index,'parse_ingr']='mandarin_juice'

# %%
# whole delete
# 'saftig',

# %%
pending_ingrs=list(set(one_pending_df['parse_ingr'].values.tolist()))
len(pending_ingrs)
# Out:
# 5748

# %%
liqueur_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'_liqueur',row.parse_ingr)!=None:
        liqueur_list.append(row.parse_ingr)
liqueur_list=list(set(liqueur_list))
liqueur_list
# Out:
# ['cappuccino_cream_liqueur',
#  'grenadine_liqueur',
#  'coffee_liqueur',
#  'vanilla_egg_liqueur',
#  'passion_fruit_liqueur',
#  'galliano_liqueur',
#  'lemon_liqueur',
#  'dooleys_liqueur',
#  'apricot_liqueur',
#  'egg_liqueur',
#  'berry_liqueur',
#  'apple_liqueur',
#  'almond_liqueur',
#  'sea_buckthorn_liqueur',
#  'egg_liqueur_liqueur',
#  'pear_liqueur',
#  'peach_liqueur',
#  'cream_liqueur',
#  'currant_liqueur',
#  'mango_liqueur']

# %%
juice_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'_juice',row.parse_ingr)!=None:
        juice_list.append(row.parse_ingr)
juice_list=list(set(juice_list))
juice_list
# Out:
# ['pineapple_coco_juice',
#  'melon_juice',
#  'apricot_juice',
#  'passion_fruit_juice',
#  'grape_juice',
#  'rhubarb_juice',
#  'toamto_juice',
#  'beetroot_juice',
#  'strawberry_cherry_juice',
#  'mustard_cucumber_juice',
#  'gooseberry_juice',
#  'banana_juice',
#  'raspberry_juice',
#  'mango_juice',
#  'artichoke_juice',
#  'blueberry_juice',
#  'cherry_juice',
#  'clementine_juice',
#  'pineapple_juice',
#  'strawberry_juice',
#  'pear_juice',
#  'apple_juice',
#  'peach_juice',
#  'grapefruit_juice',
#  'lychee_juice',
#  'cranberry_juice',
#  'cucumber_juice',
#  'plum_juice',
#  'mandarin_juice',
#  'sea_buckthorn_juice',
#  'blackberry_juice',
#  'lime_juice',
#  'lemon_juice',
#  'orange_juice',
#  'currant_juice',
#  'carrot_juice']

# %%
jam_list=[]
for index,row in one_pending_df.iterrows():
    if re.search(r'_jam',row.parse_ingr)!=None:
        jam_list.append(row.parse_ingr)
jam_list=list(set(jam_list))
jam_list
# Out:
# ['fruit_jam',
#  'redcurrant_jam',
#  'pineapple_jam',
#  'tomato_jam',
#  'mango_jam',
#  'blueberry_jam',
#  'rose_hip_jam',
#  'raspberry_jam',
#  'orange_jam',
#  'kiwi_gooseberry_jam',
#  'strawberry_jam',
#  'blackberry_jam',
#  'peach_jam',
#  'plum_jam',
#  'plum_amaretto_jam',
#  'lingonberry_jam',
#  'lemon_jam',
#  'carrot_jam',
#  'ginger_jam',
#  'fig_jam',
#  'apricot_jam',
#  'cherry_jam',
#  'apple_jam',
#  'orangen_jam',
#  'peach_passion_fruit_jam',
#  'sour_cherry_jam',
#  'currant_jam']

# %%
keep_list=liqueur_list+juice_list+jam_list

# %%
one_ingr_done=one_pending_df[one_pending_df['parse_ingr'].isin(keep_list)]
len(one_ingr_done)
# Out:
# 154

# %%
one_ingr_done.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/one_ingr_data/one_ingr_done_003.csv')

# %%
one_pending_df=one_pending_df[~one_pending_df['parse_ingr'].isin(keep_list)]
len(one_pending_df)
# Out:
# 5913

# %%
one_pending_df=one_pending_df[one_pending_df['parse_ingr']!='saftig']

# %%
pending_ingrs=list(set(one_pending_df['parse_ingr'].values.tolist()))
len(pending_ingrs)
# Out:
# 5664

# %%
one_pending_df.to_csv('~/work/food_flavor/kochbar_ingredient_preprocessing/datasets/one_ingr_data/one_ingr_pending_001.csv')
